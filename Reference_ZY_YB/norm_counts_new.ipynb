# %%
import pandas as pd
counts = pd.read_csv('norm_counts.csv')
counts.head()
# Out:
#    paper_subject  reference_subject  norm_counts
# 0             10               10.0     0.000000
# 1             10               11.0     0.008153
# 2             10               12.0     0.000008
# 3             10               13.0     0.102940
# 4             10               15.0     0.000792

# %%
type(counts.iloc[0,0])
# Out:
# numpy.int64

# %%
counts['reference_subject'] = counts['reference_subject'].astype(int)
counts
# Out:
#      paper_subject  reference_subject  norm_counts
# 0               10                 10     0.000000
# 1               10                 11     0.008153
# 2               10                 12     0.000008
# 3               10                 13     0.102940
# 4               10                 15     0.000792
# 5               10                 16     0.005156
# 6               10                 17     0.000509
# 7               10                 19     0.000308
# 8               10                 20     0.000018
# 9               10                 22     0.000532
# 10              10                 23     0.000866
# 11              10                 24     0.052153
# 12              10                 25     0.000372
# 13              10                 26     0.001012
# 14              10                 27     0.064692
# 15              10                 28     0.132505
# 16              10                 29     0.003830
# ...

# %%
counts.to_csv('norm_counts_new.csv', index = False)
