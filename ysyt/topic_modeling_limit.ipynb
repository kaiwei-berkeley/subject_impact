# %%
import re
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os
import math

# %% [markdown]
# **Create dataframe that matches paper abstract with subjects **

# %%
paper_id = []
abstract = []

f = open('aminer_2015.txt','r',encoding = 'utf8')
f.readline()
for i, line in enumerate(f):
        if (i+2) % 250000 == 0:
            print('file '+file+': ',round((i+2)/1000000*100,1),"%")
        json_line = json.loads(line)
        if 'year' in json_line and 'keywords' in json_line and \
        'abstract' in json_line and 'lang' in json_line and \
        'references' in json_line and 'issn' in json_line:
            
            if json_line['lang'] == 'en' :
                
                ## store paper info, later use to get the subject of the paper
                paper_id.append(json_line['id'])
                abstract.append(json_line['abstract'])

                
f.close()

# %%
df= pd.DataFrame()
df['id'] = paper_id
df['abstract'] = abstract
df.set_index('id')
# Out:
#                                                                    abstract
# id
# 53e99796b7602d9701f5d979  The pHealth 2015 Conference is the 12th in a s...
# 53e99796b7602d9701f613ec  A graphical model is a probability distributio...
# 53e9979bb7602d9701f668c8  An inter-governmental body is encouraging the ...
# 53e997a2b7602d9701f74d6a  The most important results from the EU-sponsor...
# 53e997a2b7602d9701f75614  The Nursing and Midwifery Council is seeking t...
# 53e997a2b7602d9701f75a62                                          Contents.
# 53e997a2b7602d9701f75a78                                              cover
# 53e997a6b7602d9701f7c67e  The above comments on our previous paper are t...
# 53e997b2b7602d9701f91202  Machine learning's focus on ill-defined proble...
# 53e997b5b7602d9701f969d2  \n Die numerische Mathematik (kurz: Numerik) i...
# 53e997b9b7602d9701f9eead  Gold Standard allergen-specific immunotherapy ...
# 53e997c2b7602d9701fb3181  \n When working with chemicals which may be ha...
# 53e997c6b7602d9701fb50da  Metabolomic studies generate large quantities ...
# 53e997f1b7602d9701ff1755  Retinal images in the human eye are normally d...
# 53e997f1b7602d9701ff3a2d  Computer transposition of matrices larger than...
# 53e997f1b7602d9701ff3a2e                          First Page of the Article
# 53e997f1b7602d9701ff3a40  Thacker and Shendumikar 1 write that there is ...
# 53e997f5b7602d9701ffb1ce  From the Publisher:The design of knowledge sys...
# 53e997f8b7602d9701ffcd85  Human–computer interaction (HCI) is the study ...
# 53e997f9b7602d9702002dfd                          First Page of the Article
# 53e99822b7602d9702042c14  Skeletal stem cells (SSCs) reside in the postn...
# 53e99822b7602d970204416d  In this article we attempt a closer examinatio...
# 53e99827b7602d9702046f1d                                   Without Abstract
# 53e99827b7602d9702047011  We read with interest the report ‘Milky ascite...
# 53e99842b7602d970206b530  At a time when dealing with climate change iss...
# 53e99842b7602d970206e55d  Summary  The MEN syndromes continue to be the ...
# 53e99853b7602d970208892b  Injection of local anesthetic intraneurally oc...
# 53e998aab7602d97020e6892  Background Electroacupuncture (EA) at acupoint...
# 53e9a0d8b7602d97029be954  In Cyber-Physical Networked Systems (CPNS), th...
# 53e9a0d8b7602d97029c0a03  We consider the problem of estimating local se...
# ...                                                                     ...
# 55a6d1dd65ce054aad772e9a  Attempting to achieve long-lasting and stable ...
# 55a6d1dd65ce054aad772e9d  Rising atmospheric CO2 concentration (C a) is ...
# 55a6d1dd65ce054aad772ea4  The present study evaluated the differences in...
# 55aa3f0d65ce2a9b9e15fc13  Infrared spectroscopy is the technique of choi...
# 55aa484865ce2a9b9e15fc55  Mutant mitochondrial DNA (mtDNA) gives rise to...
# 55aa495765ce2a9b9e15fc5b  On 6 March 2015, the United States Food and Dr...
# 55aa4f3f65ce2a9b9e15fc80  Mammalian mitochondrial ribosomes (mitoribosom...
# 55aa553665ce2a9b9e15fcab  Methane is a key component in the global carbo...
# 55aa613965ce2a9b9e15fcfb  Measles is a highly contagious human disease. ...
# 55aa670465ce2a9b9e15fd1a  The Protoaurignacian culture is pivotal to the...
# 55aa6cb265ce2a9b9e15fd3d  Growing evidence has demonstrated the importan...
# 55aa76d865ce2a9b9e15fd95  Werner syndrome (WS) is a premature aging diso...
# 55aa9d6365ce2a9b9e15fe2e  Tobacco smoking is a risk factor for numerous ...
# 55aaa23d65ce2a9b9e15fe40  China is the world's largest producer, consume...
# 55aaa5f665ce2a9b9e15fe52  XRCC4 and XLF are two structurally related pro...
# 55aab5b865ce2a9b9e15fe96  The 26S proteasome is a key player in eukaryot...
# 55aaccef65ce2a9b9e15feb3  Incoming and outgoing solar radiation couple w...
# 55aacdf765ce2a9b9e15feb7  The 18-kilodalton translocator protein (TSPO),...
# 55aada4e65ce2a9b9e15fef7  Electric double layers (EDLs) of ionic liquids...
# 55aadb6765ce2a9b9e15feff  The C-terminal region of Clostridium perfringe...
# 55aae0b665ce2a9b9e15ff1d  The evolution of galaxies is connected to the ...
# 55aae12e65ce2a9b9e15ff1f  Cope’s rule proposes that animal lineages evol...
# 55aae51e65ce2a9b9e15ff70  Superhydrophobic self-cleaning surfaces are ba...
# 55aae52965ce2a9b9e15ff72  The mammalian cerebral cortex supports cogniti...
# 55aae5da65ce2a9b9e15ff89  Payments for Ecosystem Services (PES) mechanis...
# 53e99df0b7602d97026b112d  In this work, we formulate the problem of keyw...
# 53e99e13b7602d97026d39ec  In this paper, we address the problems of mode...
# 53e99e6ab7602d9702731d2f  This paper studies the simultaneous wireless i...
# 53e99faeb7602d9702883abc  It is of great interest to develop efficient w...
# 53e9a026b7602d97029074fa  In this paper, we deal with resource allocatio...
#
# [95421 rows x 1 columns]

# %%
df.head()
# Out:
#                          id                                           abstract
# 0  53e99796b7602d9701f5d979  The pHealth 2015 Conference is the 12th in a s...
# 1  53e99796b7602d9701f613ec  A graphical model is a probability distributio...
# 2  53e9979bb7602d9701f668c8  An inter-governmental body is encouraging the ...
# 3  53e997a2b7602d9701f74d6a  The most important results from the EU-sponsor...
# 4  53e997a2b7602d9701f75614  The Nursing and Midwifery Council is seeking t...

# %%
subject = pd.read_csv('paper_subject_match.csv',index_col = 'id')

# %%
subject.head()
# Out:
#                           paper_subject
# id
# 53e99784b7602d9701f3e13e           13.0
# 53e99784b7602d9701f3e4f2           13.0
# 53e9978db7602d9701f4f415           13.0
# 53e99792b7602d9701f56a86           27.0
# 53e99792b7602d9701f5b087            NaN

# %%
tm = pd.merge(df, subject, on = ['id'])

# %%
tm.head()
# Out:
#                          id  \
# 0  53e99796b7602d9701f5d979
# 1  53e99796b7602d9701f613ec
# 2  53e9979bb7602d9701f668c8
# 3  53e997a2b7602d9701f74d6a
# 4  53e997a2b7602d9701f75614
#
#                                             abstract  paper_subject
# 0  The pHealth 2015 Conference is the 12th in a s...            NaN
# 1  A graphical model is a probability distributio...            NaN
# 2  An inter-governmental body is encouraging the ...           10.0
# 3  The most important results from the EU-sponsor...            NaN
# 4  The Nursing and Midwifery Council is seeking t...           29.0

# %%
tm.isnull().sum()
# Out:
# id                  0
# abstract            0
# paper_subject    6180
# dtype: int64

# %%
len(tm)
# Out:
# 95421

# %%
tm = tm.dropna()

# %%
tm = tm.drop(columns = ['id'])

# %%
tm['paper_subject'] = tm['paper_subject'].apply(np.int64)

# %% [markdown]
# **Concatenate all abstracts having the same subject(group by subject)**

# %%
tm_all = tm.groupby('paper_subject').agg({'abstract':'-'.join})

# %%
tm_all.reset_index(level=0, inplace=True)

# %%
tm_all.head()
# Out:
#    paper_subject                                           abstract
# 0             10  An inter-governmental body is encouraging the ...
# 1             11  The total variation (TV) regularization method...
# 2             12  Technologies for automated detection of neonat...
# 3             13  Skeletal stem cells (SSCs) reside in the postn...
# 4             14  Despite the extensive application of Monte Car...

# %% [markdown]
# **Processing the abstract:**
# - Tokenization: Split the text into sentences and the sentences into words. Lowercase the words and remove punctuation
# - Words that have fewer than 3 characters are removed
# - All stopwords are removed
# - lemmatized — words in third person to first person, verbs in past and future tenses to present
# - Stemmed — words are reduced to their root form

# %%
#import sys
#!{sys.executable} -m pip install gensim
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2015)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/yihuan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v')) #lemmatize as verb, default is noun

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %% [markdown]
# An example of processing the words in the abstract:

# %%
stemmer = SnowballStemmer('english') #Create a new instance of a language specific subclass
doc_sample = tm_all[tm_all['paper_subject'] == 10].values[0][1]
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words[:10])
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample[:100]))
# Out:
# ['An', 'inter-governmental', 'body', 'is', 'encouraging', 'the', 'replacement', 'of', 'currency', 'with']
#
#
#  tokenized and lemmatized document:
# ['inter', 'government', 'bodi', 'encourag', 'replac', 'currenc', 'object', 'discoura']

# %% [markdown]
# The real processing of all the abstract, **takes time!**

# %%
processed_docs = tm_all['abstract'].map(preprocess)

# %%
processed_docs[11] #words processed in Economics, Econometrics and Finance
# Out:
# ['consid',
#  'problem',
#  'estim',
#  'local',
#  'sensor',
#  'paramet',
#  'local',
#  'paramet',
#  'sensor',
#  'observ',
#  'relat',
#  'linear',
#  'stochast',
#  'model',
#  'studi',
#  'gaussian',
#  'product',
#  'algorithm',
#  'wireless',
#  'network',
#  'gspawn',
#  'procedur',
#  'compar',
#  'popular',
#  'diffus',
#  'strategi',
#  'perform',
#  'network',
#  'paramet',
#  'estim',
#  'communic',
#  'cost',
#  'sensor',
#  'increas',
#  'increas',
#  'network',
#  'densiti',
#  'gspawn',
#  'allow',
#  'sensor',
#  'broadcast',
#  'messag',
#  'size',
#  'depend',
#  'network',
#  'size',
#  'densiti',
#  'make',
#  'suitabl',
#  'applic',
#  'wireless',
#  'sensor',
#  'network',
#  'gspawn',
#  'converg',
#  'mean',
#  'mean',
#  'squar',
#  'stabil',
#  'technic',
#  'suffici',
#  'condit',
#  'applic',
#  'gspawn',
#  'network',
#  'local',
#  'problem',
#  'line',
#  'sight',
#  'environ',
#  'numer',
#  'result',
#  'suggest',
#  'gspawn',
#  'converg',
#  'faster',
#  'general',
#  'diffus',
#  'method',
#  'lower',
#  'communic',
#  'cost',
#  'sensor',
#  'compar',
#  'root',
#  'mean',
#  'squar',
#  'error',
#  'express',
#  'clone',
#  'play',
#  'import',
#  'role',
#  'facial',
#  'express',
#  'synthesi',
#  'paper',
#  'novel',
#  'algorithm',
#  'propos',
#  'facial',
#  'express',
#  'clone',
#  'propos',
#  'algorithm',
#  'introduc',
#  'elast',
#  'model',
#  'balanc',
#  'global',
#  'local',
#  'warp',
#  'effect',
#  'impact',
#  'facial',
#  'featur',
#  'divers',
#  'peopl',
#  'minim',
#  'effect',
#  'geometr',
#  'warp',
#  'result',
#  'achiev',
#  'furthermor',
#  'muscl',
#  'distribut',
#  'base',
#  'model',
#  'propos',
#  'util',
#  'muscl',
#  'distribut',
#  'human',
#  'face',
#  'result',
#  'accur',
#  'facial',
#  'illumin',
#  'detail',
#  'addit',
#  'propos',
#  'distanc',
#  'base',
#  'metric',
#  'automat',
#  'select',
#  'optim',
#  'paramet',
#  'global',
#  'local',
#  'warp',
#  'effect',
#  'elast',
#  'model',
#  'suitabl',
#  'balanc',
#  'experiment',
#  'result',
#  'propos',
#  'algorithm',
#  'outperform',
#  'exist',
#  'method',
#  'elsevi',
#  'right',
#  'reserv',
#  'paper',
#  'consid',
#  'wireless',
#  'power',
#  'cooper',
#  'communic',
#  'network',
#  'consist',
#  'hybrid',
#  'access',
#  'point',
#  'sourc',
#  'relay',
#  'contrast',
#  'convent',
#  'cooper',
#  'network',
#  'sourc',
#  'relay',
#  'consid',
#  'network',
#  'emb',
#  'energi',
#  'suppli',
#  'need',
#  'reli',
#  'energi',
#  'harvest',
#  'signal',
#  'broadcast',
#  'cooper',
#  'inform',
#  'transmiss',
#  'base',
#  'node',
#  'refer',
#  'model',
#  'propos',
#  'harvest',
#  'cooper',
#  'protocol',
#  'sourc',
#  'relay',
#  'harvest',
#  'energi',
#  'downlink',
#  'work',
#  'cooper',
#  'uplink',
#  'sourc',
#  'inform',
#  'transmiss',
#  'consid',
#  'delay',
#  'limit',
#  'transmiss',
#  'mode',
#  'approxim',
#  'close',
#  'form',
#  'express',
#  'averag',
#  'throughput',
#  'propos',
#  'protocol',
#  'deriv',
#  'rayleigh',
#  'fade',
#  'channel',
#  'subsequ',
#  'analysi',
#  'extend',
#  'multi',
#  'relay',
#  'scenario',
#  'approxim',
#  'throughput',
#  'protocol',
#  'popular',
#  'relay',
#  'select',
#  'scheme',
#  'deriv',
#  'asymptot',
#  'analys',
#  'throughput',
#  'perform',
#  'consid',
#  'scheme',
#  'high',
#  'signal',
#  'nois',
#  'radio',
#  'provid',
#  'theoret',
#  'result',
#  'valid',
#  'numer',
#  'simul',
#  'impact',
#  'paramet',
#  'time',
#  'alloc',
#  'relay',
#  'number',
#  'relay',
#  'posit',
#  'throughput',
#  'perform',
#  'extens',
#  'investig',
#  'paper',
#  'propos',
#  'crowdsourc',
#  'base',
#  'framework',
#  'myopic',
#  'target',
#  'track',
#  'design',
#  'optim',
#  'incent',
#  'compat',
#  'mechan',
#  'wireless',
#  'sensor',
#  'network',
#  'contain',
#  'sensor',
#  'selfish',
#  'profit',
#  'motiv',
#  'typic',
#  'wsns',
#  'limit',
#  'bandwidth',
#  'fusion',
#  'center',
#  'distribut',
#  'total',
#  'number',
#  'bit',
#  'transmit',
#  'sensor',
#  'sensor',
#  'formul',
#  'consid',
#  'conduct',
#  'auction',
#  'solicit',
#  'bid',
#  'selfish',
#  'sensor',
#  'reflect',
#  'valu',
#  'energi',
#  'cost',
#  'furthermor',
#  'ration',
#  'truth',
#  'sensor',
#  'guarante',
#  'model',
#  'final',
#  'problem',
#  'formul',
#  'multipl',
#  'choic',
#  'knapsack',
#  'problem',
#  'mckp',
#  'solv',
#  'dynam',
#  'program',
#  'method',
#  'pseudo',
#  'polynomi',
#  'time',
#  'simul',
#  'result',
#  'effect',
#  'propos',
#  'approach',
#  'term',
#  'track',
#  'perform',
#  'lifetim',
#  'sensor',
#  'network',
#  'present',
#  'joint',
#  'channel',
#  'power',
#  'alloc',
#  'framework',
#  'downlink',
#  'transmiss',
#  'orthogon',
#  'frequenc',
#  'divis',
#  'multipl',
#  'access',
#  'ofdma',
#  'base',
#  'cellular',
#  'network',
#  'compos',
#  'macrocel',
#  'overlay',
#  'small',
#  'cell',
#  'framework',
#  'resourc',
#  'alloc',
#  'problem',
#  'macrocel',
#  'small',
#  'cell',
#  'formul',
#  'optim',
#  'problem',
#  'macrocel',
#  'formul',
#  'problem',
#  'awar',
#  'exist',
#  'small',
#  'cell',
#  'tier',
#  'problem',
#  'macrocel',
#  'perform',
#  'satisfi',
#  'data',
#  'rate',
#  'requir',
#  'macro',
#  'user',
#  'equip',
#  'mue',
#  'maxim',
#  'toler',
#  'interfer',
#  'small',
#  'cell',
#  'tier',
#  'alloc',
#  'channel',
#  'problem',
#  'macrocel',
#  'show',
#  'mix',
#  'integ',
#  'nonlinear',
#  'problem',
#  'minlp',
#  'prove',
#  'macrocel',
#  'solv',
#  'altern',
#  'optim',
#  'problem',
#  'yield',
#  'optim',
#  'solut',
#  'reduc',
#  'complex',
#  'small',
#  'cell',
#  'follow',
#  'idea',
#  'tier',
#  'awar',
#  'formul',
#  'optim',
#  'problem',
#  'account',
#  'admiss',
#  'control',
#  'aim',
#  'maxim',
#  'number',
#  'admit',
#  'user',
#  'simultan',
#  'minim',
#  'consum',
#  'bandwidth',
#  'similar',
#  'macrocel',
#  'optim',
#  'problem',
#  'small',
#  'cell',
#  'problem',
#  'show',
#  'minlp',
#  'obtain',
#  'optim',
#  'solut',
#  'minlp',
#  'problem',
#  'reli',
#  'convex',
#  'relax',
#  'addit',
#  'employ',
#  'dual',
#  'decomposit',
#  'techniqu',
#  'distribut',
#  'solut',
#  'small',
#  'cell',
#  'tier',
#  'numer',
#  'result',
#  'confirm',
#  'perform',
#  'gain',
#  'propos',
#  'formul',
#  'macrocel',
#  'tradit',
#  'resourc',
#  'alloc',
#  'base',
#  'minim',
#  'transmiss',
#  'power',
#  'show',
#  'formul',
#  'base',
#  'convex',
#  'relax',
#  'yield',
#  'similar',
#  'behavior',
#  'minlp',
#  'formul',
#  'distribut',
#  'solut',
#  'converg',
#  'solut',
#  'obtain',
#  'solv',
#  'correspond',
#  'convex',
#  'optim',
#  'problem',
#  'central',
#  'fashion',
#  'cellular',
#  'network',
#  'model',
#  'base',
#  'station',
#  'usual',
#  'assum',
#  'form',
#  'lattic',
#  'poisson',
#  'point',
#  'process',
#  'realiti',
#  'deploy',
#  'fulli',
#  'regular',
#  'complet',
#  'random',
#  'accord',
#  'paper',
#  'consid',
#  'general',
#  'class',
#  'motion',
#  'invari',
#  'model',
#  'analyz',
#  'behavior',
#  'outag',
#  'probabl',
#  'probabl',
#  'signal',
#  'interfer',
#  'plus',
#  'nois',
#  'ratio',
#  'sinr',
#  'smaller',
#  'threshold',
#  'threshold',
#  'go',
#  'zero',
#  'remark',
#  'slope',
#  'outag',
#  'probabl',
#  'function',
#  'threshold',
#  'essenti',
#  'motion',
#  'invari',
#  'point',
#  'process',
#  'slope',
#  'mere',
#  'depend',
#  'fade',
#  'statist',
#  'result',
#  'introduc',
#  'notion',
#  'asymptot',
#  'deploy',
#  'gain',
#  'character',
#  'horizont',
#  'success',
#  'probabl',
#  'point',
#  'process',
#  'high',
#  'reliabl',
#  'regim',
#  'success',
#  'probabl',
#  'near',
#  'demonstr',
#  'use',
#  'sinr',
#  'distribut',
#  'investig',
#  'outag',
#  'probabl',
#  'adg',
#  'differ',
#  'point',
#  'process',
#  'fade',
#  'statist',
#  'simul',
#  'molecular',
#  'communic',
#  'network',
#  'realis',
#  'communic',
#  'nanoscal',
#  'devic',
#  'molecular',
#  'communic',
#  'network',
#  'transmitt',
#  'receiv',
#  'communic',
#  'signal',
#  'molecul',
#  'receiv',
#  'signal',
#  'molecul',
#  'react',
#  'chain',
#  'chemic',
#  'reaction',
#  'produc',
#  'output',
#  'molecul',
#  'count',
#  'output',
#  'molecul',
#  'time',
#  'output',
#  'signal',
#  'receiv',
#  'output',
#  'signal',
#  'noisi',
#  'stochast',
#  'natur',
#  'diffus',
#  'chemic',
#  'reaction',
#  'paper',
#  'aim',
#  'characteris',
#  'properti',
#  'output',
#  'signal',
#  'model',
#  'transmiss',
#  'medium',
#  'transmitt',
#  'receiv',
#  'order',
#  'simplifi',
#  'analysi',
#  'model',
#  'transmitt',
#  'sequenc',
#  'specifi',
#  'number',
#  'molecul',
#  'emit',
#  'transmitt',
#  'time',
#  'paper',
#  'consid',
#  'receiv',
#  'reaction',
#  'mechan',
#  'revers',
#  'convers',
#  'linear',
#  'catalyt',
#  'approxim',
#  'respect',
#  'ligand',
#  'receptor',
#  'bind',
#  'enzymat',
#  'reaction',
#  'mechan',
#  'choos',
#  'consid',
#  'transmitt',
#  'diffus',
#  'ordinari',
#  'differenti',
#  'equat',
#  'describ',
#  'mean',
#  'behaviour',
#  'reaction',
#  'mechan',
#  'form',
#  'consid',
#  'behaviour',
#  'transmitt',
#  'signal',
#  'mean',
#  'varianc',
#  'number',
#  'output',
#  'molecul',
#  'receiv',
#  'reaction',
#  'mechan',
#  'differ',
#  'behaviour',
#  'deriv',
#  'analyt',
#  'express',
#  'mean',
#  'varianc',
#  'frequenc',
#  'properti',
#  'number',
#  'output',
#  'molecul',
#  'receiv',
#  'reaction',
#  'mechan',
#  'addit',
#  'revers',
#  'convers',
#  'abl',
#  'deriv',
#  'exact',
#  'probabl',
#  'distribut',
#  'number',
#  'output',
#  'molecul',
#  'model',
#  'allow',
#  'studi',
#  'impact',
#  'design',
#  'paramet',
#  'communic',
#  'perform',
#  'exampl',
#  'assum',
#  'receiv',
#  'enclos',
#  'membran',
#  'studi',
#  'impact',
#  'diffus',
#  'molecul',
#  'membran',
#  'communic',
#  'rformanc',
#  'paper',
#  'present',
#  'statist',
#  'chatter',
#  'detect',
#  'method',
#  'methodolog',
#  'base',
#  'studi',
#  'discret',
#  'wavelet',
#  'transform',
#  'scheme',
#  'statist',
#  'analysi',
#  'wavelet',
#  'transform',
#  'modulus',
#  'maxima',
#  'wtmm',
#  'wavelet',
#  'transform',
#  'modulus',
#  'maxima',
#  'point',
#  'wavelet',
#  'transform',
#  'signal',
#  'local',
#  'maxim',
#  'correspond',
#  'time',
#  'locat',
#  'noisi',
#  'machin',
#  'environ',
#  'wavelet',
#  'base',
#  'nois',
#  'method',
#  'includ',
#  'hybrid',
#  'threshold',
#  'function',
#  'level',
#  'depend',
#  'univers',
#  'threshold',
#  'rule',
#  'propos',
#  'dimension',
#  'chatter',
#  'index',
#  'vari',
#  'design',
#  'base',
#  'statist',
#  'analysi',
#  'wtmm',
#  'main',
#  'advantag',
#  'propos',
#  'chatter',
#  'index',
#  'includ',
#  'variat',
#  'rang',
#  'independ',
#  'process',
#  'paramet',
#  'machin',
#  'system',
#  'threshold',
#  'valu',
#  'suscept',
#  'cut',
#  'condit',
#  'chang',
#  'valu',
#  'relat',
#  'term',
#  'result',
#  'chatter',
#  'index',
#  'differ',
#  'machin',
#  'process',
#  'time',
#  'consum',
#  'recalibr',
#  'process',
#  'present',
#  'multipl',
#  'person',
#  'track',
#  'algorithm',
#  'base',
#  'combin',
#  'particl',
#  'filter',
#  'reciproc',
#  'veloc',
#  'obstacl',
#  'agent',
#  'base',
#  'crowd',
#  'model',
#  'infer',
#  'collis',
#  'free',
#  'veloc',
#  'predict',
#  'pedestrian',
#  'motion',
#  'addit',
#  'posit',
#  'veloc',
#  'track',
#  'algorithm',
#  'estim',
#  'intern',
#  'goal',
#  'desir',
#  'destin',
#  'desir',
#  'veloc',
#  'track',
#  'pedestrian',
#  'onlin',
#  'manner',
#  'remov',
#  'need',
#  'specifi',
#  'inform',
#  'furthermor',
#  'leverag',
#  'longer',
#  'term',
#  'predict',
#  'deriv',
#  'higher',
#  'order',
#  'aggreg',
#  'multipl',
#  'predict',
#  'differ',
#  'prior',
#  'time',
#  'step',
#  'yield',
#  'tracker',
#  'recov',
#  'short',
#  'term',
#  'occlus',
#  'spurious',
#  'nois',
#  'appear',
#  'model',
#  'experiment',
#  'result',
#  'track',
#  'algorithm',
#  'suitabl',
#  'predict',
#  'pedestrian',
#  'behavior',
#  'onlin',
#  'need',
#  'scene',
#  'prior',
#  'hand',
#  'annot',
#  'goal',
#  'inform',
#  'improv',
#  'track',
#  'real',
#  'world',
#  'crowd',
#  'scene',
#  'frame',
#  'rat',
#  'extract',
#  'latent',
#  'dimension',
#  'structur',
#  'high',
#  'dimension',
#  'data',
#  'paramount',
#  'import',
#  'time',
#  'infer',
#  'task',
#  'encount',
#  'data',
#  'analyt',
#  'increas',
#  'noisi',
#  'heterogen',
#  'incomplet',
#  'dataset',
#  'need',
#  'real',
#  'time',
#  'process',
#  'stream',
#  'data',
#  'pose',
#  'major',
#  'challeng',
#  'context',
#  'present',
#  'paper',
#  'permeat',
#  'benefit',
#  'rank',
#  'minim',
#  'scalabl',
#  'imput',
#  'miss',
#  'data',
#  'track',
#  'dimension',
#  'subspac',
#  'unravel',
#  'latent',
#  'possibl',
#  'multi',
#  'structur',
#  'incomplet',
#  'stream',
#  'data',
#  'rank',
#  'matrix',
#  'data',
#  'subspac',
#  'estim',
#  'propos',
#  ...]

# %%
dictionary = gensim.corpora.Dictionary(processed_docs) 
#Dictionary encapsulates the mapping between normalized words and their integer ids.

# %%
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 30:
        break
# Out:
# 0 aaet
# 1 aakr
# 2 aapoaii
# 3 ababa
# 4 abandon
# 5 abas
# 6 abcc
# 7 abdomen
# 8 abdomin
# 9 abduct
# 10 aberr
# 11 abil
# 12 abiogen
# 13 abiot
# 14 abl
# 15 ablat
# 16 abmd
# 17 abnorm
# 18 abolish
# 19 abort
# 20 abound
# 21 abras
# 22 abrog
# 23 abrupt
# 24 abscis
# 25 absenc
# 26 absent
# 27 absentia
# 28 absolut
# 29 absorb
# 30 absorpt

# %%
dictionary.filter_extremes(no_above=0.5)
# How should we limit? no_below = 15 returns empty list

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
# for each subject, create a dictionary reporting words and how many times those words appear

# %%
bow_corpus[11] #（id in dict, how many times of appearance
# Out:
# [(5, 2),
#  (7, 11),
#  (11, 1),
#  (21, 1),
#  (22, 1),
#  (26, 11),
#  (29, 3),
#  (30, 3),
#  (32, 5),
#  (37, 1),
#  (40, 1),
#  (41, 2),
#  (42, 2),
#  (46, 2),
#  (47, 3),
#  (49, 1),
#  (55, 4),
#  (57, 4),
#  (64, 4),
#  (66, 1),
#  (68, 6),
#  (71, 1),
#  (74, 8),
#  (75, 1),
#  (77, 2),
#  (82, 4),
#  (86, 29),
#  (89, 5),
#  (91, 2),
#  (92, 2),
#  (94, 2),
#  (104, 1),
#  (107, 3),
#  (109, 2),
#  (113, 6),
#  (118, 17),
#  (120, 4),
#  (126, 1),
#  (133, 2),
#  (136, 1),
#  (138, 3),
#  (142, 1),
#  (143, 3),
#  (147, 5),
#  (157, 4),
#  (162, 1),
#  (171, 7),
#  (173, 7),
#  (174, 2),
#  (175, 8),
#  (178, 18),
#  (181, 5),
#  (185, 1),
#  (188, 1),
#  (189, 1),
#  (190, 1),
#  (195, 1),
#  (197, 2),
#  (200, 1),
#  (202, 2),
#  (204, 4),
#  (205, 17),
#  (206, 1),
#  (210, 1),
#  (212, 1),
#  (213, 1),
#  (214, 1),
#  (222, 6),
#  (231, 5),
#  (234, 1),
#  (246, 2),
#  (250, 3),
#  (252, 14),
#  (255, 1),
#  (256, 1),
#  (267, 1),
#  (268, 4),
#  (269, 2),
#  (274, 4),
#  (281, 2),
#  (283, 2),
#  (285, 7),
#  (286, 4),
#  (290, 3),
#  (293, 10),
#  (294, 2),
#  (295, 1),
#  (301, 2),
#  (313, 1),
#  (318, 1),
#  (322, 1),
#  (323, 118),
#  (326, 9),
#  (332, 1),
#  (333, 3),
#  (341, 5),
#  (345, 1),
#  (346, 1),
#  (347, 1),
#  (349, 13),
#  (354, 9),
#  (355, 1),
#  (361, 3),
#  (363, 1),
#  (364, 7),
#  (365, 2),
#  (367, 1),
#  (368, 19),
#  (369, 50),
#  (373, 2),
#  (374, 6),
#  (375, 1),
#  (377, 5),
#  (378, 4),
#  (380, 1),
#  (381, 2),
#  (382, 31),
#  (383, 1),
#  (384, 1),
#  (385, 1),
#  (387, 2),
#  (390, 2),
#  (394, 1),
#  (399, 3),
#  (400, 8),
#  (401, 1),
#  (403, 25),
#  (411, 1),
#  (415, 5),
#  (419, 8),
#  (421, 3),
#  (424, 2),
#  (426, 5),
#  (427, 1),
#  (428, 1),
#  (430, 1),
#  (433, 2),
#  (437, 12),
#  (440, 24),
#  (442, 1),
#  (443, 2),
#  (453, 1),
#  (454, 1),
#  (455, 2),
#  (461, 93),
#  (463, 1),
#  (464, 6),
#  (466, 2),
#  (471, 3),
#  (474, 3),
#  (492, 2),
#  (493, 312),
#  (495, 1),
#  (499, 1),
#  (502, 17),
#  (504, 1),
#  (507, 1),
#  (510, 6),
#  (511, 1),
#  (512, 2),
#  (517, 3),
#  (518, 2),
#  (522, 1),
#  (523, 17),
#  (524, 2),
#  (528, 5),
#  (531, 2),
#  (534, 15),
#  (535, 1),
#  (538, 1),
#  (540, 1),
#  (543, 1),
#  (550, 2),
#  (552, 1),
#  (553, 23),
#  (556, 5),
#  (558, 1),
#  (559, 42),
#  (561, 4),
#  (565, 1),
#  (566, 2),
#  (571, 5),
#  (573, 4),
#  (574, 7),
#  (579, 3),
#  (581, 1),
#  (585, 1),
#  (593, 4),
#  (596, 3),
#  (600, 12),
#  (601, 89),
#  (602, 2),
#  (603, 1),
#  (606, 2),
#  (607, 2),
#  (610, 6),
#  (615, 6),
#  (618, 1),
#  (627, 18),
#  (632, 1),
#  (635, 3),
#  (640, 3),
#  (641, 8),
#  (643, 1),
#  (645, 4),
#  (648, 1),
#  (650, 5),
#  (651, 2),
#  (652, 179),
#  (656, 2),
#  (657, 1),
#  (662, 2),
#  (665, 1),
#  (668, 1),
#  (673, 2),
#  (674, 1),
#  (676, 3),
#  (677, 5),
#  (682, 5),
#  (684, 8),
#  (686, 3),
#  (692, 1),
#  (693, 4),
#  (694, 5),
#  (696, 2),
#  (697, 14),
#  (708, 21),
#  (709, 3),
#  (710, 4),
#  (715, 3),
#  (716, 1),
#  (717, 3),
#  (721, 1),
#  (724, 4),
#  (726, 19),
#  (727, 7),
#  (728, 4),
#  (730, 1),
#  (731, 1),
#  (732, 1),
#  (735, 11),
):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_11[i][0], 
                                                     dictionary[bow_doc_11[i][0]], 
                                                     bow_doc_11[i][1]))
# Out:
# Word 5 ("abiot") appears 2 time.
# Word 7 ("abras") appears 11 time.
# Word 11 ("acad") appears 1 time.
# Word 21 ("acidif") appears 1 time.
# Word 22 ("acidifi") appears 1 time.
# Word 26 ("acryl") appears 11 time.
# Word 29 ("actinomycet") appears 3 time.
# Word 30 ("activat") appears 3 time.
# Word 32 ("actomyosin") appears 5 time.
# Word 37 ("adaptor") appears 1 time.
# Word 40 ("adductor") appears 1 time.
# Word 41 ("adenin") appears 2 time.
# Word 42 ("adenosin") appears 2 time.
# Word 46 ("adiabat") appears 2 time.
# Word 47 ("adipocyt") appears 3 time.
# Word 49 ("adrenerg") appears 1 time.
# Word 55 ("aerodynam") appears 4 time.
# Word 57 ("aesthet") appears 4 time.
# Word 64 ("agaros") appears 4 time.
# Word 66 ("agglutinin") appears 1 time.
# Word 68 ("agil") appears 6 time.
# Word 71 ("agreeabl") appears 1 time.
# Word 74 ("airborn") appears 8 time.
# Word 75 ("airflow") appears 1 time.
# Word 77 ("akin") appears 2 time.
# Word 82 ("alba") appears 4 time.
# Word 86 ("algin") appears 29 time.
# Word 89 ("alkyl") appears 5 time.
# Word 91 ("allo") appears 2 time.
# Word 92 ("allogen") appears 2 time.
# Word 94 ("alloster") appears 2 time.
# Word 104 ("amalgam") appears 1 time.
# Word 107 ("aminoacyl") appears 3 time.
# Word 109 ("aminoglycosid") appears 2 time.
# Word 113 ("amp") appears 6 time.
# Word 118 ("amphiphil") appears 17 time.
# Word 120 ("ampl") appears 4 time.
# Word 126 ("anabol") appears 1 time.
# Word 133 ("anchorag") appears 2 time.
# Word 136 ("anderson") appears 1 time.
# Word 138 ("android") appears 3 time.
# Word 142 ("angina") appears 1 time.
# Word 143 ("angiogen") appears 3 time.
# Word 147 ("ankl") appears 5 time.
# Word 157 ("anthocyanin") appears 4 time.
# Word 162 ("antiapoptot") appears 1 time.
# Word 171 ("antiparallel") appears 7 time.
# Word 173 ("antisens") appears 7 time.
# Word 174 ("antitoxin") appears 2 time.
# Word 175 ("antitumor") appears 8 time.
# Word 178 ("apatit") appears 18 time.
# Word 181 ("apex") appears 5 time.
# Word 185 ("apo") appears 1 time.
# Word 188 ("apolar") appears 1 time.
# Word 189 ("apolipoprotein") appears 1 time.
# Word 190 ("appendag") appears 1 time.
# Word 195 ("apposit") appears 1 time.
# Word 197 ("aqua") appears 2 time.
# Word 200 ("arab") appears 1 time.
# Word 202 ("arabidopsi") appears 2 time.
# Word 204 ("aragonit") appears 4 time.
# Word 205 ("arbitrarili") appears 17 time.
# Word 206 ("arbor") appears 1 time.
# Word 210 ("archaeal") appears 1 time.
# Word 212 ("archetyp") appears 1 time.
# Word 213 ("arctic") appears 1 time.
# Word 214 ("areal") appears 1 time.
# Word 222 ("arrhenius") appears 6 time.
# Word 231 ("articular") appears 5 time.
# Word 234 ("aryl") appears 1 time.
# Word 246 ("astronom") appears 2 time.
# Word 250 ("atcc") appears 3 time.
# Word 252 ("atomist") appears 14 time.
# Word 255 ("atrial") appears 1 time.
# Word 256 ("attest") appears 1 time.
# Word 267 ("autogen") appears 1 time.
# Word 268 ("autolog") appears 4 time.
# Word 269 ("automata") appears 2 time.
# Word 274 ("autoregul") appears 4 time.
# Word 281 ("avert") appears 2 time.
# Word 283 ("avid") appears 2 time.
# Word 285 ("axillari") appears 7 time.
# Word 286 ("azobenzen") appears 4 time.
# Word 290 ("bacillus") appears 3 time.
# Word 293 ("bactericid") appears 10 time.
# Word 294 ("bacteriophag") appears 2 time.
# Word 295 ("bacteriostat") appears 1 time.
# Word 301 ("bake") appears 2 time.
# Word 313 ("barrel") appears 1 time.
# Word 318 ("battlefield") appears 1 time.
# Word 322 ("beak") appears 1 time.
# Word 323 ("beamform") appears 118 time.
# Word 326 ("beer") appears 9 time.
# Word 332 ("benthic") appears 1 time.
# Word 333 ("benzen") appears 3 time.
# Word 341 ("bifunct") appears 5 time.
# Word 345 ("bill") appears 1 time.
# Word 346 ("bimolecular") appears 1 time.
# Word 347 ("binaur") appears 1 time.
# Word 349 ("biodistribut") appears 13 time.
# Word 354 ("biogen") appears 9 time.
# Word 355 ("biogenesi") appears 1 time.
# Word 361 ("bioluminesc") appears 3 time.
# Word 363 ("biominer") appears 1 time.
# Word 364 ("biopolym") appears 7 time.
# Word 365 ("bioprocess") appears 2 time.
# Word 367 ("bioremedi") appears 1 time.
# Word 368 ("biosens") appears 19 time.
# Word 369 ("biosensor") appears 50 time.
# Word 373 ("biosynthes") appears 2 time.
# Word 374 ("biosynthet") appears 6 time.
# Word 375 ("biosystem") appears 1 time.
# Word 377 ("biotin") appears 5 time.
# Word 378 ("biphas") appears 4 time.
# Word 380 ("bismuth") appears 1 time.
# Word 381 ("bisphenol") appears 2 time.
# Word 382 ("bit") appears 31 time.
# Word 383 ("bival") appears 1 time.
# Word 384 ("bivalv") appears 1 time.
# Word 385 ("blade") appears 1 time.
# Word 387 ("bleach") appears 2 time.
# Word 390 ("blog") appears 2 time.
# Word 394 ("bold") appears 1 time.
# Word 399 ("bonus") appears 3 time.
# Word 400 ("boolean") appears 8 time.
# Word 401 ("bootstrap") appears 1 time.
# Word 403 ("boron") appears 25 time.
# Word 411 ("brace") appears 1 time.
# Word 415 ("braid") appears 5 time.
# Word 419 ("bread") appears 8 time.
# Word 421 ("breakup") appears 3 time.
# Word 424 ("brighter") appears 2 time.
# Word 426 ("brillouin") appears 5 time.
# Word 427 ("brine") appears 1 time.
# Word 428 ("britain") appears 1 time.
# Word 430 ("broker") appears 1 time.
# Word 433 ("bronchoalveolar") appears 2 time.
# Word 437 ("brownian") appears 12 time.
# Word 440 ("bubbl") appears 24 time.
# Word 442 ("buildup") appears 1 time.
# Word 443 ("bulb") appears 2 time.
# Word 453 ("burrow") appears 1 time.
# Word 454 ("bursti") appears 1 time.
# Word 455 ("bus") appears 2 time.
# Word 461 ("cabl") appears 93 time.
# Word 463 ("cadav") appears 1 time.
# Word 464 ("cadmium") appears 6 time.
# Word 466 ("caffeic") appears 2 time.
# Word 471 ("calcit") appears 3 time.
# Word 474 ("calendar") appears 3 time.
# Word 492 ("canopi") appears 2 time.
# Word 493 ("capacitor") appears 312 time.
# Word 495 ("capillar") appears 1 time.
# Word 499 ("capsid") appears 1 time.
# Word 502 ("carbid") appears 17 time.
# Word 504 ("carboxi") appears 1 time.
# Word 507 ("cardin") appears 1 time.
# Word 510 ("cardiomyocyt") appears 6 time.
# Word 511 ("cardiomyopathi") appears 1 time.
# Word 512 ("cardiopulmonari") appears 2 time.
# Word 517 ("cari") appears 3 time.
# Word 518 ("cariogen") appears 2 time.
# Word 522 ("carotenoid") appears 1 time.
# Word 523 ("cartilag") appears 17 time.
# Word 524 ("cartridg") appears 2 time.
# Word 528 ("cassett") appears 5 time.
# Word 531 ("catabol") appears 2 time.
# Word 534 ("catalysi") appears 15 time.
# Word 535 ("cataract") appears 1 time.
# Word 538 ("catecholamin") appears 1 time.
# Word 540 ("caterpillar") appears 1 time.
# Word 543 ("caudal") appears 1 time.
# Word 550 ("cdna") appears 2 time.
# Word 552 ("cdrs") appears 1 time.
# Word 553 ("cdse") appears 23 time.
# Word 556 ("censor") appears 5 time.
# Word 558 ("centromer") appears 1 time.
# Word 559 ("ceram") appears 42 time.
# Word 561 ("cerebellar") appears 4 time.
# Word 565 ("cerium") appears 1 time.
# Word 566 ("certainti") appears 2 time.
# Word 571 ("chalcogenid") appears 5 time.
# Word 573 ("chao") appears 4 time.
# Word 574 ("chaotic") appears 7 time.
# Word 579 ("chase") appears 3 time.
# Word 581 ("checkpoint") appears 1 time.
# Word 585 ("chemoattract") appears 1 time.
# Word 593 ("chiefli") appears 4 time.
# Word 596 ("chill") appears 3 time.
# Word 600 ("chitin") appears 12 time.
# Word 601 ("chitosan") appears 89 time.
# Word 602 ("chloroform") appears 2 time.
# Word 603 ("chlorophyl") appears 1 time.
# Word 606 ("chol") appears 2 time.
# Word 607 ("cholera") appears 2 time.
# Word 610 ("chondrocyt") appears 6 time.
# Word 615 ("chromophor") appears 6 time.
# Word 618 ("cilia") appears 1 time.
# Word 627 ("circuitri") appears 18 time.
# Word 632 ("citizen") appears 1 time.
# Word 635 ("civil") appears 3 time.
# Word 640 ("claw") appears 3 time.
# Word 641 ("clay") appears 8 time.
# Word 643 ("cleavabl") appears 1 time.
# Word 645 ("climb") appears 4 time.
# Word 648 ("clockwis") appears 1 time.
# Word 650 ("clutch") appears 5 time.
# Word 651 ("cmax") appears 2 time.
# Word 652 ("cmos") appears 179 time.
# Word 656 ("coal") appears 2 time.
# Word 657 ("coassembl") appears 1 time.
# Word 662 ("cochlear") appears 2 time.
# Word 665 ("coenzym") appears 1 time.
# Word 668 ("coexpress") appears 1 time.
# Word 673 ("collar") appears 2 time.
# Word 674 ("collater") appears 1 time.
# Word 676 ("collid") appears 3 time.
# Word 677 ("collim") appears 5 time.
# Word 682 ("columnar") appears 5 time.
# Word 684 ("comb") appears 8 time.
# Word 686 ("commensur") appears 3 time.
# Word 692 ("compass") appears 1 time.
# Word 693 ("compel") appears 4 time.
# Word 694 ("competitor") appears 5 time.
# Word 696 ("complementar") appears 2 time.
# Word 697 ("compliant") appears 14 time.
# Word 708 ("conic") appears 21 time.
# Word 709 ("conif") appears 3 time.
# Word 710 ("conjectur") appears 4 time.
# Word 715 ("consequenti") appears 3 time.
# Word 716 ("consortia") appears 1 time.
# Word 717 ("constrict") appears 3 time.
# Word 721 ("contigu") appears 1 time.
# Word 724 ("contractil") appears 4 time.
# Word 726 ("convect") appears 19 time.
# Word 727 ("convolut") appears 7 time.
# Word 728 ("cook") appears 4 time.
# Word 730 ("copious") appears 1 time.
# Word 731 ("copolymer") appears 1 time.
# Word 732 ("coral") appears 1 time.
# Word 735 ("corneal") appears 11 time.
# Word 737 ("cornerston") appears 1 time.
# Word 738 ("corona") appears 35 time.
# Word 739 ("corros") appears 85 time.
# Word 740 ("corrupt") appears 13 time.
# Word 743 ("corticosteroid") appears 1 time.
# Word 749 ("cosmic") appears 1 time.
# Word 750 ("costa") appears 4 time.
# Word 754 ("cough") appears 6 time.
# Word 755 ("coulomb") appears 7 time.
# Word 759 ("countermeasur") appears 5 time.
# Word 764 ("crank") appears 3 time.
# Word 773 ("crest") appears 1 time.
# Word 775 ("crime") appears 1 time.
# Word 776 ("crimin") appears 1 time.
# Word 777 ("crispr") appears 6 time.
# Word 779 ("crosslink") appears 34 time.
# Word 780 ("cruis") appears 3 time.
# Word 783 ("cryogen") appears 14 time.
# Word 785 ("cryostat") appears 4 time.
# Word 788 ("crystallographi") appears 1 time.
# Word 790 ("ctcs") appears 18 time.
# Word 796 ("cumbersom") appears 5 time.
# Word 798 ("curtail") appears 2 time.
# Word 802 ("cxcr") appears 1 time.
# Word 805 ("cyanobacteri") appears 2 time.
# Word 806 ("cyanobacteria") appears 1 time.
# Word 807 ("cyanobacterium") appears 1 time.
# Word 809 ("cyclo") appears 1 time.
# Word 811 ("cyclooxygenas") appears 1 time.
# Word 817 ("cytidin") appears 1 time.
# Word 818 ("cytocompat") appears 6 time.
# Word 823 ("cytoskelet") appears 1 time.
# Word 825 ("dampen") appears 1 time.
# Word 831 ("darwin") appears 1 time.
# Word 834 ("daughter") appears 1 time.
# Word 840 ("deaminas") appears 1 time.
# Word 843 ("decap") appears 2 time.
# Word 847 ("decidu") appears 2 time.
# Word 849 ("decompress") appears 3 time.
# Word 850 ("decorrel") appears 2 time.
# Word 861 ("deloc") appears 5 time.
# Word 865 ("democrat") appears 1 time.
# Word 867 ("dendrim") appears 13 time.
# Word 869 ("deni") appears 4 time.
# Word 871 ("denois") appears 10 time.
# Word 872 ("denomin") appears 2 time.
# Word 873 ("densif") appears 1 time.
# Word 874 ("deoxi") appears 1 time.
# Word 876 ("depolar") appears 7 time.
# Word 877 ("depolaris") appears 2 time.
# Word 880 ("deproton") appears 1 time.
# Word 883 ("derivat") appears 1 time.
# Word 884 ("dermal") appears 6 time.
# Word 885 ("dermi") appears 1 time.
# Word 886 ("desatur") appears 1 time.
# Word 887 ("desensit") appears 1 time.
# Word 896 ("deuterium") appears 5 time.
# Word 900 ("diagon") appears 23 time.
# Word 901 ("dialysi") appears 1 time.
# Word 902 ("diamond") appears 17 time.
# Word 908 ("dicarboxyl") appears 1 time.
# Word 909 ("dice") appears 1 time.
# Word 911 ("dichroism") appears 6 time.
# Word 920 ("dinucleotid") appears 1 time.
# Word 923 ("dip") appears 10 time.
# Word 924 ("diphenyl") appears 1 time.
# Word 925 ("diploid") appears 1 time.
# Word 926 ("dipol") appears 141 time.
# Word 927 ("dipolar") appears 4 time.
# Word 930 ("director") appears 2 time.
# Word 935 ("disassoci") appears 1 time.
# Word 937 ("discord") appears 1 time.
# Word 945 ("dislik") appears 1 time.
# Word 947 ("dispatch") appears 10 time.
# Word 950 ("distract") appears 15 time.
# Word 951 ("distractor") appears 1 time.
# Word 952 ("disulfid") appears 12 time.
# Word 956 ("diversif") appears 1 time.
# Word 963 ("docetaxel") appears 9 time.
# Word 967 ("dopaminerg") appears 3 time.
# Word 968 ("dopant") appears 39 time.
# Word 974 ("doublet") appears 5 time.
# Word 976 ("downscal") appears 10 time.
# Word 977 ("downward") appears 3 time.
# Word 978 ("doxorubicin") appears 15 time.
# Word 980 ("dozen") appears 2 time.
# Word 982 ("drag") appears 7 time.
# Word 987 ("drought") appears 10 time.
# Word 989 ("dsbs") appears 1 time.
# Word 990 ("dsdna") appears 3 time.
# Word 993 ("ductal") appears 2 time.
# Word 996 ("duplex") appears 32 time.
# Word 1014 ("earthquak") appears 1 time.
# Word 1017 ("ebola") appears 1 time.
# Word 1018 ("eccentr") appears 14 time.
# Word 1026 ("eddi") appears 49 time.
# Word 1029 ("edta") appears 5 time.
# Word 1037 ("ehec") appears 1 time.
# Word 1038 ("eigenvalu") appears 21 time.
# Word 1039 ("eighth") appears 2 time.
# Word 1043 ("elastas") appears 1 time.
# Word 1044 ("elastin") appears 3 time.
# Word 1046 ("electropor") appears 4 time.
# Word 1047 ("electrostat") appears 61 time.
# Word 1051 ("elut") appears 22 time.
# Word 1052 ("embol") appears 2 time.
# Word 1057 ("emitt") appears 32 time.
# Word 1066 ("enclos") appears 9 time.
# Word 1067 ("endang") appears 2 time.
# Word 1068 ("endo") appears 2 time.
# Word 1070 ("endocyt") appears 5 time.
# Word 1071 ("endocytosi") appears 10 time.
# Word 1075 ("endonucleas") appears 1 time.
# Word 1077 ("endosom") appears 4 time.
# Word 1081 ("endothelium") appears 1 time.
# Word 1082 ("endotherm") appears 1 time.
# Word 1085 ("energ") appears 4 time.
# Word 1086 ("engulf") appears 7 time.
# Word 1096 ("enthalpi") appears 5 time.
# Word 1100 ("entrain") appears 2 time.
# Word 1101 ("entranc") appears 2 time.
# Word 1102 ("entrap") appears 10 time.
# Word 1103 ("entrop") appears 1 time.
# Word 1109 ("ephemer") appears 1 time.
# Word 1114 ("epilept") appears 3 time.
# Word 1121 ("epitaxi") appears 27 time.
# Word 1122 ("epoch") appears 4 time.
# Word 1123 ("epoxid") appears 2 time.
# Word 1124 ("epstein") appears 2 time.
# Word 1127 ("equilibria") appears 3 time.
# Word 1129 ("eras") appears 7 time.
# Word 1130 ("erbb") appears 6 time.
# Word 1132 ("ergod") appears 16 time.
# Word 1133 ("ergonom") appears 1 time.
# Word 1135 ("errat") appears 2 time.
# Word 1149 ("etanercept") appears 1 time.
# Word 1157 ("euglena") appears 3 time.
# Word 1161 ("evacu") appears 6 time.
# Word 1162 ("evad") appears 8 time.
# Word 1165 ("evolutionarili") appears 1 time.
# Word 1167 ("exciton") appears 60 time.
# Word 1170 ("exfoli") appears 26 time.
# Word 1173 ("exonucleas") appears 2 time.
# Word 1178 ("expon") appears 10 time.
# Word 1180 ("exquisit") appears 2 time.
# Word 1181 ("exterior") appears 4 time.
# Word 1183 ("extran") appears 1 time.
# Word 1184 ("extraordinarili") appears 3 time.
# Word 1186 ("extravas") appears 2 time.
# Word 1189 ("extrud") appears 5 time.
# Word 1190 ("extrus") appears 5 time.
# Word 1191 ("exud") appears 1 time.
# Word 1194 ("fab") appears 3 time.
# Word 1201 ("fare") appears 1 time.
# Word 1202 ("fascin") appears 7 time.
# Word 1203 ("fault") appears 365 time.
# Word 1208 ("feedforward") appears 15 time.
# Word 1209 ("feedstock") appears 1 time.
# Word 1211 ("fellow") appears 1 time.
# Word 1212 ("femtosecond") appears 11 time.
# Word 1215 ("fermi") appears 18 time.
# Word 1217 ("ferric") appears 1 time.
# Word 1218 ("ferromagnet") appears 25 time.
# Word 1220 ("ferrous") appears 1 time.
# Word 1221 ("ferul") appears 3 time.
# Word 1224 ("fibrillar") appears 4 time.
# Word 1225 ("fibrinogen") appears 9 time.
# Word 1226 ("fibrot") appears 2 time.
# Word 1229 ("filler") appears 13 time.
# Word 1230 ("fin") appears 2 time.
# Word 1231 ("financ") appears 1 time.
# Word 1236 ("fitc") appears 5 time.
# Word 1245 ("flame") appears 9 time.
# Word 1246 ("flammabl") appears 2 time.
# Word 1247 ("flank") appears 2 time.
# Word 1248 ("flap") appears 1 time.
# Word 1249 ("flare") appears 4 time.
# Word 1250 ("flatten") appears 3 time.
# Word 1253 ("flavonoid") appears 1 time.
# Word 1255 ("flax") appears 7 time.
# Word 1258 ("flexneri") appears 1 time.
# Word 1259 ("flexur") appears 4 time.
# Word 1260 ("flicker") appears 15 time.
# Word 1261 ("flock") appears 2 time.
# Word 1268 ("fluorin") appears 29 time.
# Word 1269 ("fluoro") appears 1 time.
# Word 1270 ("fluorogen") appears 3 time.
# Word 1272 ("flush") appears 2 time.
# Word 1273 ("fmri") appears 7 time.
# Word 1280 ("follicular") appears 1 time.
# Word 1286 ("fore") appears 1 time.
# Word 1288 ("foreground") appears 7 time.
# Word 1290 ("fork") appears 1 time.
# Word 1293 ("formalin") appears 5 time.
# Word 1296 ("fortifi") appears 1 time.
# Word 1301 ("fractal") appears 30 time.
# Word 1307 ("freestand") appears 6 time.
# Word 1308 ("fret") appears 8 time.
# Word 1311 ("fring") appears 14 time.
# Word 1312 ("frontier") appears 8 time.
# Word 1314 ("fructos") appears 4 time.
# Word 1317 ("fundus") appears 2 time.
# Word 1318 ("fungicid") appears 5 time.
# Word 1319 ("funnel") appears 1 time.
# Word 1320 ("furfur") appears 3 time.
# Word 1321 ("furnish") appears 2 time.
# Word 1322 ("further") appears 2 time.
# Word 1323 ("fusarium") appears 1 time.
# Word 1325 ("förster") appears 2 time.
# Word 1332 ("gadolinium") appears 6 time.
# Word 1337 ("galaxi") appears 1 time.
# Word 1339 ("gallium") appears 28 time.
# Word 1346 ("gapdh") appears 1 time.
# Word 1350 ("gaseous") appears 5 time.
# Word 1352 ("gatekeep") appears 2 time.
# Word 1353 ("gaze") appears 5 time.
# Word 1355 ("gelatin") appears 39 time.
# Word 1368 ("gentamicin") appears 4 time.
# Word 1381 ("gestalt") appears 1 time.
# Word 1382 ("gestur") appears 12 time.
# Word 1383 ("gfap") appears 2 time.
# Word 1396 ("glaucoma") appears 1 time.
# Word 1399 ("glide") appears 1 time.
# Word 1400 ("glioma") appears 9 time.
# Word 1403 ("globular") appears 1 time.
# Word 1410 ("glucosamin") appears 4 time.
# Word 1412 ("glucuron") appears 1 time.
# Word 1414 ("glutamin") appears 1 time.
# Word 1420 ("glyceraldehyd") appears 1 time.
# Word 1432 ("golgi") appears 1 time.
# Word 1438 ("gpcr") appears 3 time.
# Word 1439 ("gpcrs") appears 3 time.
# Word 1440 ("gracili") appears 1 time.
# Word 1444 ("granuloma") appears 1 time.
# Word 1450 ("graphen") appears 514 time.
# Word 1451 ("graphit") appears 39 time.
# Word 1453 ("grate") appears 30 time.
# Word 1454 ("gravit") appears 1 time.
# Word 1455 ("greedi") appears 14 time.
# Word 1460 ("groov") appears 11 time.
# Word 1463 ("groundwork") appears 5 time.
# Word 1469 ("gtpase") appears 1 time.
# Word 1472 ("guanin") appears 1 time.
# Word 1476 ("guest") appears 3 time.
# Word 1478 ("gvhd") appears 7 time.
# Word 1480 ("gyroscop") appears 2 time.
# Word 1482 ("hairpin") appears 2 time.
# Word 1485 ("hamiltonian") appears 7 time.
# Word 1486 ("hamstr") appears 3 time.
# Word 1491 ("haptic") appears 4 time.
# Word 1492 ("harden") appears 17 time.
# Word 1493 ("harder") appears 2 time.
# Word 1494 ("hardwar") appears 123 time.
# Word 1496 ("harmless") appears 1 time.
# Word 1497 ("hatch") appears 4 time.
# Word 1502 ("headgroup") appears 3 time.
# Word 1504 ("heavier") appears 2 time.
# Word 1506 ("helic") appears 19 time.
# Word 1507 ("helicas") appears 1 time.
# Word 1509 ("helmholtz") appears 5 time.
# Word 1511 ("hematolog") appears 3 time.
# Word 1513 ("hematopoiet") appears 4 time.
# Word 1525 ("heparin") appears 1 time.
# Word 1527 ("hepatocellular") appears 2 time.
# Word 1538 ("hesc") appears 4 time.
# Word 1540 ("hetero") appears 7 time.
# Word 1543 ("heterocycl") appears 2 time.
# Word 1544 ("heterodim") appears 3 time.
# Word 1552 ("hexagon") appears 37 time.
# Word 1553 ("hexam") appears 2 time.
# Word 1554 ("hexamer") appears 1 time.
# Word 1556 ("hexaval") appears 1 time.
# Word 1559 ("hexos") appears 1 time.
# Word 1561 ("hibiscus") appears 1 time.
# Word 1563 ("hill") appears 3 time.
# Word 1567 ("hing") appears 3 time.
# Word 1568 ("hint") appears 5 time.
# Word 1575 ("hollow") appears 18 time.
# Word 1577 ("holograph") appears 15 time.
# Word 1582 ("homo") appears 5 time.
# Word 1583 ("homodim") appears 1 time.
# Word 1589 ("hook") appears 2 time.
# Word 1591 ("hotspot") appears 7 time.
# Word 1593 ("housekeep") appears 3 time.
# Word 1594 ("hscs") appears 4 time.
# Word 1596 ("hub") appears 1 time.
# Word 1597 ("hull") appears 1 time.
# Word 1604 ("hurrican") appears 3 time.
# Word 1605 ("hydraul") appears 9 time.
# Word 1606 ("hydro") appears 4 time.
# Word 1612 ("hydrolys") appears 3 time.
# Word 1613 ("hydrolyt") appears 6 time.
# Word 1614 ("hydroxam") appears 1 time.
# Word 1615 ("hydroxyapatit") appears 54 time.
# Word 1616 ("hydroxyl") appears 5 time.
# Word 1621 ("hyperbol") appears 4 time.
# Word 1630 ("hyperspectr") appears 1 time.
# Word 1631 ("hypertroph") appears 1 time.
# Word 1634 ("hypoglycem") appears 1 time.
# Word 1639 ("hypotens") appears 1 time.
# Word 1644 ("hysteresi") appears 47 time.
# Word 1645 ("hysteret") appears 6 time.
# Word 1649 ("icam") appears 3 time.
# Word 1652 ("icosahedr") appears 2 time.
# Word 1654 ("idl") appears 10 time.
# Word 1658 ("ignit") appears 4 time.
# Word 1663 ("illus") appears 1 time.
# Word 1664 ("imagin") appears 2 time.
# Word 1666 ("imbalanc") appears 1 time.
# Word 1668 ("imit") appears 8 time.
# Word 1678 ("immunotherapi") appears 6 time.
# Word 1680 ("impedi") appears 2 time.
# Word 1681 ("impend") appears 1 time.
# Word 1682 ("imperm") appears 2 time.
# Word 1683 ("imping") appears 8 time.
# Word 1684 ("imposit") appears 1 time.
# Word 1685 ("imprint") appears 24 time.
# Word 1686 ("imput") appears 2 time.
# Word 1688 ("inaccess") appears 1 time.
# Word 1693 ("incipi") appears 7 time.
# Word 1695 ("incoher") appears 5 time.
# Word 1696 ("incontin") appears 2 time.
# Word 1699 ("indica") appears 1 time.
# Word 1703 ("indium") appears 34 time.
# Word 1704 ("indocyanin") appears 1 time.
# Word 1707 ("inerti") appears 13 time.
# Word 1708 ("inexact") appears 1 time.
# Word 1712 ("infin") appears 6 time.
# Word 1714 ("inflammasom") appears 3 time.
# Word 1718 ("influx") appears 1 time.
# Word 1722 ("initio") appears 6 time.
# Word 1725 ("innermost") appears 1 time.
# Word 1730 ("insecur") appears 1 time.
# Word 1732 ("insol") appears 6 time.
# Word 1733 ("instanti") appears 3 time.
# Word 1736 ("insular") appears 2 time.
# Word 1743 ("interfaci") appears 51 time.
# Word 1746 ("interim") appears 1 time.
# Word 1748 ("interlay") appears 8 time.
# Word 1753 ("interphas") appears 4 time.
# Word 1754 ("interquartil") appears 1 time.
# Word 1755 ("interspac") appears 1 time.
# Word 1756 ("interspeci") appears 1 time.
# Word 1758 ("interspers") appears 2 time.
# Word 1769 ("intramolecular") appears 3 time.
# Word 1773 ("intraocular") appears 1 time.
# Word 1774 ("intraoss") appears 1 time.
# Word 1775 ("intrapariet") appears 1 time.
# Word 1777 ("intratumor") appears 2 time.
# Word 1781 ("intravit") appears 1 time.
# Word 1784 ("intrud") appears 1 time.
# Word 1788 ("involuntari") appears 1 time.
# Word 1789 ("inward") appears 5 time.
# Word 1790 ("ionophor") appears 2 time.
# Word 1792 ("iphon") appears 2 time.
# Word 1803 ("isoelectr") appears 3 time.
# Word 1806 ("isoleucin") appears 1 time.
# Word 1807 ("isomer") appears 4 time.
# Word 1811 ("isoprenoid") appears 2 time.
# Word 1812 ("isopropanol") appears 2 time.
# Word 1815 ("isotrop") appears 33 time.
# Word 1820 ("jam") appears 15 time.
# Word 1822 ("jeopard") appears 3 time.
# Word 1824 ("jitter") appears 32 time.
# Word 1828 ("juxtapos") appears 1 time.
# Word 1836 ("kelvin") appears 1 time.
# Word 1838 ("ketamin") appears 4 time.
# Word 1841 ("killer") appears 1 time.
# Word 1842 ("kilomet") appears 3 time.
# Word 1843 ("kinesin") appears 1 time.
# Word 1845 ("kink") appears 2 time.
# Word 1848 ("knife") appears 1 time.
# Word 1853 ("kohn") appears 1 time.
# Word 1854 ("kras") appears 1 time.
# Word 1857 ("kurtosi") appears 1 time.
# Word 1860 ("labil") appears 1 time.
# Word 1868 ("lambda") appears 8 time.
# Word 1869 ("lamellipodia") appears 1 time.
# Word 1870 ("lamin") appears 47 time.
# Word 1876 ("lanthanid") appears 3 time.
# Word 1877 ("laparoscop") appears 1 time.
# Word 1879 ("laplacian") appears 5 time.
# Word 1883 ("latitud") appears 1 time.
# Word 1885 ("lattic") appears 63 time.
# Word 1889 ("lavag") appears 2 time.
# Word 1893 ("lcmv") appears 2 time.
# Word 1895 ("leach") appears 5 time.
# Word 1897 ("leaki") appears 26 time.
# Word 1900 ("led") appears 58 time.
# Word 1905 ("lens") appears 18 time.
# Word 1910 ("leucin") appears 3 time.
# Word 1912 ("lever") appears 3 time.
# Word 1916 ("lidar") appears 2 time.
# Word 1920 ("lignocellulos") appears 1 time.
# Word 1922 ("lime") appears 1 time.
# Word 1926 ("ling") appears 1 time.
# Word 1928 ("linker") appears 17 time.
# Word 1933 ("lipophil") appears 2 time.
# Word 1934 ("liposom") appears 18 time.
# Word 1937 ("listeria") appears 1 time.
# Word 1939 ("lithographi") appears 25 time.
# Word 1951 ("lobul") appears 1 time.
# Word 1953 ("localis") appears 23 time.
# Word 1957 ("lognorm") appears 4 time.
# Word 1965 ("lubric") appears 2 time.
# Word 1966 ("luca") appears 1 time.
# Word 1967 ("luciferas") appears 3 time.
# Word 1968 ("luminesc") appears 33 time.
# Word 1970 ("lump") appears 28 time.
# Word 1974 ("lutein") appears 1 time.
# Word 1975 ("lyapunov") appears 31 time.
# Word 1981 ("lyse") appears 1 time.
# Word 1982 ("lysi") appears 4 time.
# Word 1983 ("lysyl") appears 1 time.
# Word 1987 ("macula") appears 1 time.
# Word 1992 ("magnetit") appears 8 time.
# Word 1993 ("magneto") appears 25 time.
# Word 2000 ("maldi") appears 2 time.
# Word 2002 ("maltos") appears 3 time.
# Word 2005 ("mandibular") appears 3 time.
# Word 2006 ("maneuv") appears 15 time.
# Word 2009 ("mann") appears 1 time.
# Word 2010 ("mantl") appears 1 time.
# Word 2013 ("mar") appears 2 time.
# Word 2017 ("maritim") appears 4 time.
# Word 2018 ("markup") appears 1 time.
# Word 2023 ("mart") appears 7 time.
# Word 2025 ("masculin") appears 1 time.
# Word 2026 ("mast") appears 1 time.
# Word 2029 ("mastiti") appears 2 time.
# Word 2034 ("mbcs") appears 1 time.
# Word 2039 ("mechanochem") appears 1 time.
# Word 2056 ("mem") appears 33 time.
# Word 2057 ("memor") appears 1 time.
# Word 2064 ("mercuri") appears 7 time.
# Word 2067 ("mesoderm") appears 1 time.
# Word 2069 ("mesopor") appears 50 time.
# Word 2070 ("mesoscop") appears 5 time.
# Word 2075 ("metallurg") appears 3 time.
# Word 2076 ("metamorph") appears 1 time.
# Word 2079 ("metast") appears 7 time.
# Word 2084 ("methionin") appears 1 time.
# Word 2086 ("methylen") appears 3 time.
# Word 2087 ("metr") appears 1 time.
# Word 2088 ("metropoli") appears 1 time.
# Word 2091 ("mic") appears 4 time.
# Word 2092 ("micell") appears 48 time.
# Word 2094 ("microalga") appears 1 time.
# Word 2098 ("microchannel") appears 8 time.
# Word 2101 ("microdomain") appears 9 time.
# Word 2104 ("microglia") appears 1 time.
# Word 2105 ("micrograph") appears 4 time.
# Word 2108 ("micromechan") appears 6 time.
# Word 2109 ("micromet") appears 26 time.
# Word 2114 ("micropor") appears 6 time.
# Word 2116 ("microscal") appears 10 time.
# Word 2117 ("microsecond") appears 6 time.
# Word 2120 ("microtubul") appears 5 time.
# Word 2121 ("microvesicl") appears 1 time.
# Word 2122 ("microwir") appears 8 time.
# Word 2133 ("millisecond") appears 2 time.
# Word 2134 ("mimet") appears 6 time.
# Word 2137 ("minima") appears 4 time.
# Word 2152 ("modulatori") appears 1 time.
# Word 2153 ("moduli") appears 11 time.
# Word 2154 ("modulus") appears 69 time.
# Word 2156 ("moll") appears 1 time.
# Word 2159 ("molybdenum") appears 5 time.
# Word 2160 ("momentum") appears 26 time.
# Word 2161 ("monetari") appears 1 time.
# Word 2166 ("monochromat") appears 4 time.
# Word 2167 ("monocytogen") appears 1 time.
# Word 2170 ("monophosph") appears 1 time.
# Word 2175 ("monotherapi") appears 2 time.
# Word 2177 ("monoval") appears 1 time.
# Word 2182 ("mori") appears 1 time.
# Word 2186 ("morphogenesi") appears 3 time.
# Word 2188 ("morphotyp") appears 2 time.
# Word 2192 ("moth") appears 1 time.
# Word 2193 ("movi") appears 2 time.
# Word 2194 ("mptp") appears 3 time.
# Word 2195 ("msns") appears 10 time.
# Word 2203 ("muller") appears 3 time.
# Word 2205 ("multicolor") appears 3 time.
# Word 2206 ("multicompon") appears 3 time.
# Word 2208 ("multidomain") appears 2 time.
# Word 2211 ("multiobject") appears 25 time.
# Word 2213 ("multiphoton") appears 4 time.
# Word 2215 ("multipot") appears 1 time.
# Word 2216 ("multiprotein") appears 1 time.
# Word 2217 ("multisensori") appears 2 time.
# Word 2221 ("multistag") appears 1 time.
# Word 2222 ("multistep") appears 5 time.
# Word 2224 ("multitarget") appears 14 time.
# Word 2225 ("multitask") appears 1 time.
# Word 2226 ("multival") appears 6 time.
# Word 2228 ("multiview") appears 4 time.
# Word 2231 ("musculari") appears 2 time.
# Word 2232 ("mushroom") appears 11 time.
# Word 2234 ("mussel") appears 2 time.
# Word 2237 ("mutan") appears 6 time.
# Word 2248 ("myeloma") appears 1 time.
# Word 2251 ("myocyt") appears 1 time.
# Word 2252 ("myofibroblast") appears 3 time.
# Word 2255 ("myosin") appears 7 time.
# Word 2259 ("nadh") appears 1 time.
# Word 2262 ("nadph") appears 4 time.
# Word 2263 ("nail") appears 6 time.
# Word 2264 ("nanocryst") appears 59 time.
# Word 2265 ("nanoelectron") appears 11 time.
# Word 2266 ("nanog") appears 1 time.
# Word 2268 ("nanomechan") appears 4 time.
# Word 2269 ("nanometr") appears 10 time.
# Word 2270 ("nanomolar") appears 1 time.
# Word 2271 ("nanophoton") appears 6 time.
# Word 2272 ("nanosheet") appears 40 time.
# Word 2273 ("nanospher") appears 21 time.
# Word 2274 ("nanotechnolog") appears 14 time.
# Word 2278 ("nasa") appears 2 time.
# Word 2279 ("nascent") appears 6 time.
# Word 2284 ("nausea") appears 1 time.
# Word 2288 ("negoti") appears 2 time.
# Word 2290 ("nemat") appears 3 time.
# Word 2294 ("neoplasia") appears 3 time.
# Word 2296 ("neoplast") appears 2 time.
# Word 2300 ("nephropathi") appears 1 time.
# Word 2303 ("net") appears 8 time.
# Word 2306 ("neurit") appears 13 time.
# Word 2309 ("neurobehavior") appears 2 time.
# Word 2312 ("neurochem") appears 1 time.
# Word 2326 ("neurospher") appears 5 time.
# Word 2333 ("neutron") appears 1 time.
# Word 2335 ("news") appears 1 time.
# Word 2338 ("nhej") appears 1 time.
# Word 2340 ("nicotinamid") appears 1 time.
# Word 2346 ("nigra") appears 3 time.
# Word 2352 ("nitrit") appears 1 time.
# Word 2353 ("nitrocellulos") appears 1 time.
# Word 2357 ("nlrp") appears 2 time.
# Word 2362 ("nodal") appears 5 time.
# Word 2363 ("nodul") appears 2 time.
# Word 2366 ("nonadapt") appears 4 time.
# Word 2369 ("nonclass") appears 1 time.
# Word 2371 ("noncoval") appears 4 time.
# Word 2372 ("noncrystallin") appears 1 time.
# Word 2373 ("nondestruct") appears 8 time.
# Word 2374 ("nonenzymat") appears 2 time.
# Word 2375 ("nonequilibrium") appears 6 time.
# Word 2377 ("nonexist") appears 2 time.
# Word 2384 ("nonhomolog") appears 1 time.
# Word 2385 ("nonion") appears 1 time.
# Word 2388 ("nonpathogen") appears 1 time.
# Word 2389 ("nonplanar") appears 3 time.
# Word 2390 ("nonpolar") appears 8 time.
# Word 2395 ("nonsens") appears 1 time.
# Word 2396 ("nonsmal") appears 1 time.
# Word 2399 ("nontrivi") appears 5 time.
# Word 2400 ("nonuniform") appears 12 time.
# Word 2401 ("nonvir") appears 1 time.
# Word 2406 ("normox") appears 1 time.
# Word 2418 ("nucleas") appears 1 time.
# Word 2421 ("nucleophil") appears 1 time.
# Word 2424 ("nucleosom") appears 7 time.
# Word 2425 ("nude") appears 1 time.
# Word 2426 ("nuisanc") appears 1 time.
# Word 2432 ("obey") appears 5 time.
# Word 2433 ("obliter") appears 1 time.
# Word 2436 ("octahedr") appears 1 time.
# Word 2440 ("oil") appears 4 time.
# Word 2442 ("oligodendrocyt") appears 1 time.
# Word 2443 ("oligom") appears 8 time.
# Word 2446 ("onboard") appears 13 time.
# Word 2456 ("operon") appears 2 time.
# Word 2457 ("ophthalmolog") appears 1 time.
# Word 2462 ("optimist") appears 1 time.
# Word 2463 ("optoelectron") appears 43 time.
# Word 2464 ("optogenet") appears 1 time.
# Word 2467 ("orchestr") appears 2 time.
# Word 2477 ("orthopaed") appears 1 time.
# Word 2479 ("osc") appears 3 time.
# Word 2480 ("osmot") appears 1 time.
# Word 2481 ("osteoclast") appears 21 time.
# Word 2484 ("osterix") appears 3 time.
# Word 2493 ("outflow") appears 1 time.
# Word 2494 ("outgo") appears 3 time.
# Word 2497 ("outward") appears 1 time.
# Word 2498 ("outweigh") appears 1 time.
# Word 2499 ("ovalbumin") appears 7 time.
# Word 2501 ("oven") appears 2 time.
# Word 2504 ("overflow") appears 4 time.
# Word 2506 ("overgrowth") appears 2 time.
# Word 2507 ("overpotenti") appears 8 time.
# Word 2510 ("overrid") appears 3 time.
# Word 2511 ("overs") appears 1 time.
# Word 2518 ("oxidoreductas") appears 1 time.
# Word 2521 ("oxysporum") appears 1 time.
# Word 2527 ("pacif") appears 1 time.
# Word 2528 ("paclitaxel") appears 3 time.
# Word 2534 ("palladium") appears 8 time.
# Word 2541 ("papilla") appears 1 time.
# Word 2542 ("papillari") appears 4 time.
# Word 2544 ("par") appears 1 time.
# Word 2545 ("paracellular") appears 2 time.
# Word 2547 ("paradigmat") appears 1 time.
# Word 2549 ("paralog") appears 1 time.
# Word 2552 ("paramagnet") appears 6 time.
# Word 2553 ("parameter") appears 9 time.
# Word 2558 ("parenchyma") appears 2 time.
# Word 2559 ("parkinsonian") appears 4 time.
# Word 2562 ("pars") appears 1 time.
# Word 2566 ("passeng") appears 21 time.
# Word 2567 ("pasta") appears 1 time.
# Word 2568 ("pasteur") appears 2 time.
# Word 2576 ("payment") appears 1 time.
# Word 2577 ("payoff") appears 5 time.
# Word 2579 ("pcna") appears 1 time.
# Word 2584 ("pdms") appears 20 time.
# Word 2593 ("pelvi") appears 2 time.
# Word 2599 ("pentagon") appears 1 time.
# Word 2600 ("pentam") appears 2 time.
# Word 2602 ("pentapeptid") appears 1 time.
# Word 2603 ("pentos") appears 1 time.
# Word 2609 ("perfor") appears 4 time.
# Word 2614 ("perinuclear") appears 1 time.
# Word 2618 ("peristalt") appears 2 time.
# Word 2624 ("perovskit") appears 48 time.
# Word 2626 ("peroxisom") appears 1 time.
# Word 2635 ("phage") appears 4 time.
# Word 2636 ("phagocyt") appears 2 time.
# Word 2637 ("phagosom") appears 1 time.
# Word 2645 ("phenomenolog") appears 1 time.
# Word 2647 ("phenylalanin") appears 1 time.
# Word 2649 ("phenylketonuria") appears 1 time.
# Word 2650 ("pheromon") appears 4 time.
# Word 2652 ("phonem") appears 6 time.
# Word 2653 ("phonon") appears 49 time.
# Word 2655 ("phospholipas") appears 1 time.
# Word 2656 ("phosphon") appears 4 time.
# Word 2658 ("phosphor") appears 11 time.
# Word 2659 ("photoacoust") appears 20 time.
# Word 2661 ("photobleach") appears 2 time.
# Word 2662 ("photochem") appears 1 time.
# Word 2665 ("photocurr") appears 26 time.
# Word 2666 ("photodamag") appears 2 time.
# Word 2667 ("photoelectrod") appears 7 time.
# Word 2668 ("photoelectron") appears 22 time.
# Word 2669 ("photoexcit") appears 3 time.
# Word 2670 ("photoinduc") appears 2 time.
# Word 2674 ("photoreceptor") appears 3 time.
# Word 2676 ("photorespons") appears 6 time.
# Word 2677 ("photosystem") appears 1 time.
# Word 2678 ("phototherm") appears 26 time.
# Word 2680 ("photovolta") appears 72 time.
# Word 2681 ("phyla") appears 1 time.
# Word 2687 ("physico") appears 5 time.
# Word 2688 ("physiochem") appears 3 time.
# Word 2689 ("phytochem") appears 2 time.
# Word 2699 ("pico") appears 1 time.
# Word 2701 ("picosecond") appears 6 time.
# Word 2706 ("pin") appears 22 time.
# Word 2708 ("pip") appears 2 time.
# Word 2710 ("pit") appears 2 time.
# Word 2715 ("planetari") appears 2 time.
# Word 2716 ("plankton") appears 3 time.
# Word 2717 ("planta") appears 1 time.
# Word 2721 ("plasminogen") appears 1 time.
# Word 2725 ("plateaus") appears 1 time.
# Word 2726 ("playground") appears 1 time.
# Word 2727 ("pleasant") appears 2 time.
# Word 2729 ("pleiotrop") appears 1 time.
# Word 2736 ("pluripot") appears 8 time.
# Word 2737 ("pnas") appears 3 time.
# Word 2740 ("pointer") appears 1 time.
# Word 2741 ("pois") appears 1 time.
# Word 2743 ("polic") appears 1 time.
# Word 2752 ("polycrystallin") appears 12 time.
# Word 2753 ("polycycl") appears 1 time.
# Word 2755 ("polydispers") appears 6 time.
# Word 2759 ("polynomi") appears 41 time.
# Word 2760 ("polyol") appears 5 time.
# Word 2763 ("polyphosph") appears 1 time.
# Word 2772 ("porphyrin") appears 7 time.
# Word 2774 ("port") appears 94 time.
# Word 2775 ("portfolio") appears 1 time.
# Word 2780 ("postinject") appears 1 time.
# Word 2782 ("postmortem") appears 1 time.
# Word 2785 ("potato") appears 2 time.
# Word 2790 ("pparγ") appears 2 time.
# Word 2792 ("preadipocyt") appears 6 time.
# Word 2795 ("precess") appears 3 time.
# Word 2796 ("precious") appears 1 time.
# Word 2797 ("precoci") appears 1 time.
# Word 2805 ("preload") appears 1 time.
# Word 2814 ("prespecifi") appears 2 time.
# Word 2816 ("presuppos") appears 1 time.
# Word 2818 ("pretest") appears 1 time.
# Word 2824 ("proc") appears 1 time.
# Word 2825 ("processor") appears 75 time.
# Word 2828 ("progenitor") appears 9 time.
# Word 2829 ("progesteron") appears 1 time.
# Word 2833 ("prolin") appears 1 time.
# Word 2834 ("prolyl") appears 1 time.
# Word 2836 ("promiscu") appears 1 time.
# Word 2837 ("propanediol") appears 3 time.
# Word 2838 ("propel") appears 15 time.
# Word 2841 ("propuls") appears 23 time.
# Word 2845 ("proteinac") appears 3 time.
# Word 2846 ("proteinas") appears 1 time.
# Word 2849 ("proteolysi") appears 1 time.
# Word 2850 ("proteolyt") appears 1 time.
# Word 2855 ("protrud") appears 5 time.
# Word 2860 ("prune") appears 8 time.
# Word 2861 ("pscs") appears 2 time.
# Word 2863 ("psnr") appears 3 time.
# Word 2868 ("psychophys") appears 2 time.
# Word 2876 ("pulsatil") appears 5 time.
# Word 2879 ("punctur") appears 1 time.
# Word 2880 ("punish") appears 2 time.
# Word 2894 ("pyrolysi") appears 5 time.
# Word 2897 ("pyruv") appears 1 time.
# Word 2900 ("quadrupl") appears 3 time.
# Word 2901 ("quadruplex") appears 1 time.
# Word 2902 ("qualif") appears 1 time.
# Word 2904 ("quantiz") appears 22 time.
# Word 2905 ("quartz") appears 5 time.
# Word 2907 ("quench") appears 36 time.
# Word 2908 ("quencher") appears 6 time.
# Word 2909 ("queue") appears 29 time.
# Word 2911 ("quinon") appears 1 time.
# Word 2912 ("quorum") appears 4 time.
# Word 2917 ("radar") appears 228 time.
# Word 2921 ("radiolabel") appears 1 time.
# Word 2924 ("raft") appears 4 time.
# Word 2929 ("rankl") appears 1 time.
# Word 2932 ("rariti") appears 1 time.
# Word 2933 ("rash") appears 1 time.
# Word 2938 ("reachabl") appears 1 time.
# Word 2939 ("reactant") appears 4 time.
# Word 2941 ("reaffirm") appears 1 time.
# Word 2948 ("rebuild") appears 1 time.
# Word 2950 ("recalcitr") appears 1 time.
# Word 2955 ("reconcil") appears 1 time.
# Word 2959 ("rectangl") appears 1 time.
# Word 2960 ("rectif") appears 14 time.
# Word 2963 ("redefin") appears 1 time.
# Word 2964 ("redesign") appears 3 time.
# Word 2966 ("reevalu") appears 1 time.
# Word 2971 ("refut") appears 1 time.
# Word 2972 ("regia") appears 1 time.
# Word 2973 ("regurgit") appears 1 time.
# Word 2975 ("reintroduct") appears 1 time.
# Word 2977 ("reliant") appears 2 time.
# Word 2986 ("rendezv") appears 13 time.
# Word 2987 ("renorm") appears 3 time.
# Word 2989 ("reorient") appears 3 time.
# Word 2991 ("repercuss") appears 1 time.
# Word 2993 ("replan") appears 2 time.
# Word 2995 ("repress") appears 11 time.
# Word 2997 ("reprogram") appears 7 time.
# Word 2999 ("repuls") appears 4 time.
# Word 3001 ("resampl") appears 3 time.
# Word 3004 ("resorpt") appears 9 time.
# Word 3005 ("restructur") appears 1 time.
# Word 3008 ("resurrect") appears 1 time.
# Word 3015 ("retreat") appears 1 time.
# Word 3021 ("revenu") appears 8 time.
# Word 3022 ("revert") appears 3 time.
# Word 3023 ("reweight") appears 2 time.
# Word 3026 ("rheolog") appears 11 time.
# Word 3031 ("rhodamin") appears 1 time.
# Word 3034 ("rhythmic") appears 1 time.
# Word 3035 ("ribbon") appears 9 time.
# Word 3036 ("ribonucl") appears 1 time.
# Word 3037 ("ribonucleas") appears 1 time.
# Word 3042 ("ribozym") appears 10 time.
# Word 3044 ("richer") appears 1 time.
# Word 3046 ("ride") appears 16 time.
# Word 3054 ("rnai") appears 7 time.
# Word 3055 ("rnas") appears 3 time.
# Word 3056 ("rnase") appears 2 time.
# Word 3060 ("roman") appears 1 time.
# Word 3063 ("rotor") appears 142 time.
# Word 3064 ("router") appears 2 time.
# Word 3067 ("rudimentari") appears 1 time.
# Word 3068 ("rug") appears 1 time.
# Word 3069 ("ruin") appears 1 time.
# Word 3072 ("runt") appears 2 time.
# Word 3073 ("runx") appears 7 time.
# Word 3074 ("rutil") appears 1 time.
# Word 3076 ("saddl") appears 5 time.
# Word 3077 ("safeguard") appears 2 time.
# Word 3078 ("saharan") appears 1 time.
# Word 3084 ("sand") appears 1 time.
# Word 3085 ("sandi") appears 1 time.
# Word 3100 ("scalar") appears 18 time.
# Word 3107 ("scid") appears 1 time.
# Word 3113 ("scrambl") appears 4 time.
# Word 3114 ("screw") appears 11 time.
# Word 3119 ("seam") appears 2 time.
# Word 3120 ("seawat") appears 1 time.
# Word 3121 ("secreci") appears 72 time.
# Word 3126 ("sediment") appears 3 time.
# Word 3129 ("seismic") appears 1 time.
# Word 3131 ("selector") appears 3 time.
# Word 3133 ("selfish") appears 4 time.
# Word 3134 ("sell") appears 1 time.
# Word 3137 ("semiconduct") appears 35 time.
# Word 3142 ("sender") appears 1 time.
# Word 3148 ("sentinel") appears 3 time.
# Word 3151 ("sequel") appears 1 time.
# Word 3155 ("sequestr") appears 2 time.
# Word 3157 ("serin") appears 1 time.
# Word 3165 ("server") appears 21 time.
# Word 3166 ("sessil") appears 5 time.
# Word 3171 ("shaker") appears 1 time.
# Word 3173 ("sharper") appears 3 time.
# Word 3174 ("sharpli") appears 4 time.
# Word 3175 ("sheath") appears 14 time.
# Word 3180 ("shigella") appears 1 time.
# Word 3184 ("showcas") appears 3 time.
# Word 3185 ("shrna") appears 4 time.
# Word 3186 ("shrnas") appears 1 time.
# Word 3188 ("shuffl") appears 4 time.
# Word 3189 ("shut") appears 3 time.
# Word 3190 ("shutdown") appears 1 time.
# Word 3191 ("sialic") appears 6 time.
# Word 3196 ("sift") appears 4 time.
# Word 3197 ("sigmoid") appears 3 time.
# Word 3200 ("silic") appears 4 time.
# Word 3201 ("sim") appears 1 time.
# Word 3203 ("simplest") appears 6 time.
# Word 3204 ("simplif") appears 4 time.
# Word 3205 ("simplist") appears 1 time.
# Word 3207 ("singlet") appears 3 time.
# Word 3214 ("sizabl") appears 1 time.
# Word 3215 ("slab") appears 24 time.
# Word 3217 ("slippag") appears 1 time.
# Word 3218 ("slit") appears 20 time.
# Word 3219 ("slowest") appears 1 time.
# Word 3221 ("smac") appears 4 time.
# Word 3222 ("smad") appears 4 time.
# Word 3223 ("smartphon") appears 11 time.
# Word 3224 ("smcs") appears 3 time.
# Word 3225 ("smear") appears 5 time.
# Word 3227 ("smoothen") appears 1 time.
# Word 3229 ("snake") appears 3 time.
# Word 3231 ("snapshot") appears 2 time.
# Word 3234 ("snow") appears 13 time.
# Word 3236 ("snrs") appears 7 time.
# Word 3237 ("sociolog") appears 1 time.
# Word 3238 ("softer") appears 3 time.
# Word 3242 ("solenoid") appears 12 time.
# Word 3243 ("solicit") appears 1 time.
# Word 3245 ("solvat") appears 1 time.
# Word 3249 ("sonar") appears 7 time.
# Word 3250 ("sonic") appears 2 time.
# Word 3254 ("southwest") appears 2 time.
# Word 3257 ("spacecraft") appears 11 time.
# Word 3258 ("spare") appears 4 time.
# Word 3260 ("spawn") appears 2 time.
# Word 3262 ("speckl") appears 17 time.
# Word 3270 ("spermatozoa") appears 2 time.
# Word 3275 ("spice") appears 14 time.
# Word 3278 ("spillov") appears 2 time.
# Word 3279 ("spindl") appears 9 time.
# Word 3283 ("spong") appears 6 time.
# Word 3285 ("spotlight") appears 1 time.
# Word 3286 ("sprout") appears 1 time.
# Word 3288 ("spur") appears 3 time.
# Word 3289 ("sputter") appears 22 time.
# Word 3292 ("ssdna") appears 1 time.
# Word 3296 ("stall") appears 1 time.
# Word 3297 ("staphylococc") appears 1 time.
# Word 3299 ("stark") appears 2 time.
# Word 3301 ("starv") appears 2 time.
# Word 3306 ("stator") appears 90 time.
# Word 3310 ("stereochemistri") appears 1 time.
# Word 3315 ("steric") appears 2 time.
# Word 3318 ("sticki") appears 4 time.
# Word 3325 ("stitch") appears 2 time.
# Word 3326 ("stoichiometr") appears 3 time.
# Word 3327 ("stoichiometri") appears 5 time.
# Word 3328 ("stoke") appears 9 time.
# Word 3330 ("storm") appears 2 time.
# Word 3334 ("strap") appears 1 time.
# Word 3338 ("streptococci") appears 1 time.
# Word 3339 ("streptomyc") appears 3 time.
# Word 3341 ("striatum") appears 4 time.
# Word 3342 ("stride") appears 11 time.
# Word 3344 ("stripe") appears 3 time.
# Word 3345 ("stroma") appears 4 time.
# Word 3346 ("strontium") appears 13 time.
# Word 3347 ("struggl") appears 2 time.
# Word 3348 ("stud") appears 2 time.
# Word 3350 ("styliz") appears 2 time.
# Word 3353 ("subclass") appears 1 time.
# Word 3357 ("subdomain") appears 7 time.
# Word 3360 ("subleth") appears 1 time.
# Word 3361 ("submarin") appears 3 time.
# Word 3362 ("submicromet") appears 7 time.
# Word 3364 ("submicron") appears 5 time.
# Word 3366 ("subregion") appears 1 time.
# Word 3374 ("substant") appears 1 time.
# Word 3375 ("substantia") appears 3 time.
# Word 3376 ("substitu") appears 1 time.
# Word 3377 ("substratum") appears 1 time.
# Word 3378 ("subsystem") appears 19 time.
# Word 3382 ("subthreshold") appears 29 time.
# Word 3383 ("subtili") appears 4 time.
# Word 3386 ("subvert") appears 1 time.
# Word 3387 ("subway") appears 2 time.
# Word 3390 ("suffic") appears 3 time.
# Word 3392 ("sulcus") appears 1 time.
# Word 3393 ("sum") appears 5 time.
# Word 3396 ("sunset") appears 2 time.
# Word 3398 ("supercapacitor") appears 38 time.
# Word 3399 ("superconduct") appears 41 time.
# Word 3401 ("superfamili") appears 2 time.
# Word 3402 ("superresolut") appears 1 time.
# Word 3406 ("swarm") appears 12 time.
# Word 3407 ("sweat") appears 2 time.
# Word 3411 ("swimmer") appears 1 time.
# Word 3421 ("synaps") appears 13 time.
# Word 3422 ("synapt") appears 13 time.
# Word 3429 ("synerg") appears 5 time.
# Word 3430 ("syngen") appears 1 time.
# Word 3431 ("synonym") appears 1 time.
# Word 3433 ("synthetas") appears 2 time.
# Word 3435 ("synuclein") appears 2 time.
# Word 3445 ("taiwan") appears 4 time.
# Word 3448 ("tall") appears 3 time.
# Word 3452 ("taper") appears 31 time.
# Word 3456 ("taxan") appears 1 time.
# Word 3457 ("taxi") appears 11 time.
# Word 3460 ("tdcs") appears 2 time.
# Word 3462 ("tear") appears 7 time.
# Word 3466 ("televis") appears 1 time.
# Word 3468 ("teller") appears 4 time.
# Word 3469 ("tellurid") appears 3 time.
# Word 3471 ("telomeras") appears 1 time.
# Word 3479 ("tensil") appears 40 time.
# Word 3481 ("tensor") appears 22 time.
# Word 3485 ("terrac") appears 2 time.
# Word 3486 ("terrain") appears 22 time.
# Word 3490 ("testi") appears 1 time.
# Word 3494 ("tetra") appears 2 time.
# Word 3496 ("tetracyclin") appears 7 time.
# Word 3508 ("therapist") appears 1 time.
# Word 3509 ("thermochem") appears 1 time.
# Word 3510 ("thermoelectr") appears 13 time.
# Word 3512 ("thermostat") appears 1 time.
# Word 3515 ("theta") appears 3 time.
# Word 3516 ("thicken") appears 1 time.
# Word 3518 ("thoma") appears 1 time.
# Word 3521 ("threonin") appears 2 time.
# Word 3524 ("thrombosi") appears 2 time.
# Word 3528 ("thrombus") appears 1 time.
# Word 3529 ("thrust") appears 14 time.
# Word 3535 ("thymus") appears 3 time.
# Word 3540 ("tighten") appears 1 time.
# Word 3541 ("tile") appears 20 time.
# Word 3542 ("till") appears 1 time.
# Word 3544 ("timescal") appears 7 time.
# Word 3545 ("tini") appears 7 time.
# Word 3548 ("tmds") appears 22 time.
# Word 3550 ("tnbc") appears 3 time.
# Word 3553 ("tnfα") appears 1 time.
# Word 3554 ("toggl") appears 1 time.
# Word 3555 ("tolerogen") appears 1 time.
# Word 3556 ("toluen") appears 7 time.
# Word 3557 ("tomato") appears 1 time.
# Word 3561 ("toolkit") appears 5 time.
# Word 3562 ("top") appears 2 time.
# Word 3565 ("torqu") appears 247 time.
# Word 3566 ("torsion") appears 3 time.
# Word 3567 ("tortuous") appears 1 time.
# Word 3569 ("tower") appears 18 time.
# Word 3573 ("trabecular") appears 1 time.
# Word 3578 ("transderm") appears 8 time.
# Word 3579 ("transepitheli") appears 1 time.
# Word 3580 ("transistor") appears 286 time.
# Word 3587 ("transpos") appears 4 time.
# Word 3589 ("transposit") appears 6 time.
# Word 3591 ("travers") appears 6 time.
# Word 3593 ("treg") appears 1 time.
# Word 3595 ("trench") appears 15 time.
# Word 3596 ("triad") appears 2 time.
# Word 3601 ("trimer") appears 4 time.
# Word 3602 ("trimethyl") appears 1 time.
# Word 3607 ("triphosph") appears 2 time.
# Word 3608 ("triplet") appears 5 time.
# Word 3612 ("trna") appears 4 time.
# Word 3618 ("tropism") appears 1 time.
# Word 3621 ("troubl") appears 1 time.
# Word 3630 ("tuber") appears 1 time.
# Word 3634 ("tumorigen") appears 1 time.
# Word 3638 ("ture") appears 2 time.
# Word 3639 ("turf") appears 2 time.
# Word 3641 ("tween") appears 1 time.
# Word 3643 ("tweezer") appears 8 time.
# Word 3648 ("typolog") appears 1 time.
# Word 3649 ("tyramin") appears 1 time.
# Word 3650 ("tyrosinas") appears 6 time.
# Word 3653 ("ultrafast") appears 19 time.
# Word 3654 ("ultrahigh") appears 20 time.
# Word 3655 ("ultralong") appears 1 time.
# Word 3657 ("ultrastructur") appears 1 time.
# Word 3658 ("ultrathin") appears 25 time.
# Word 3659 ("umbil") appears 2 time.
# Word 3664 ("unbind") appears 2 time.
# Word 3673 ("underground") appears 12 time.
# Word 3674 ("underneath") appears 7 time.
# Word 3676 ("underus") appears 1 time.
# Word 3680 ("undirect") appears 2 time.
# Word 3683 ("unexplain") appears 1 time.
# Word 3685 ("unfriend") appears 1 time.
# Word 3686 ("uniaxi") appears 29 time.
# ...
# Word 9694 ("laminin") appears 2 time.
# Word 9697 ("lcst") appears 1 time.
# Word 9698 ("leap") appears 11 time.
# Word 9702 ("levit") appears 2 time.
# Word 9712 ("lossi") appears 36 time.
# Word 9717 ("mac") appears 1 time.
# Word 9718 ("mach") appears 4 time.
# Word 9719 ("mage") appears 4 time.
# Word 9722 ("manchest") appears 1 time.
# Word 9724 ("mascot") appears 1 time.
# Word 9727 ("mdcs") appears 2 time.
# Word 9738 ("metrolog") appears 5 time.
# Word 9744 ("microdevic") appears 11 time.
# Word 9745 ("microdroplet") appears 1 time.
# Word 9746 ("micropattern") appears 4 time.
# Word 9750 ("microtissu") appears 3 time.
# Word 9752 ("microtub") appears 7 time.
# Word 9753 ("microwel") appears 2 time.
# Word 9757 ("minipig") appears 2 time.
# Word 9763 ("mise") appears 2 time.
# Word 9764 ("misinterpret") appears 1 time.
# Word 9765 ("miso") appears 15 time.
# Word 9769 ("mof") appears 9 time.
# Word 9771 ("monocrystallin") appears 2 time.
# Word 9772 ("monolith") appears 25 time.
# Word 9774 ("mpeg") appears 8 time.
# Word 9776 ("multiag") appears 4 time.
# Word 9777 ("multichannel") appears 14 time.
# Word 9778 ("multicor") appears 9 time.
# Word 9780 ("mump") appears 1 time.
# Word 9782 ("mwnt") appears 8 time.
# Word 9788 ("nanobead") appears 1 time.
# Word 9789 ("nanoconjug") appears 5 time.
# Word 9790 ("nanodiamond") appears 2 time.
# Word 9791 ("nanoformul") appears 1 time.
# Word 9792 ("nanohybrid") appears 5 time.
# Word 9793 ("nanoindent") appears 4 time.
# Word 9794 ("nanoprob") appears 7 time.
# Word 9795 ("nanoscop") appears 5 time.
# Word 9796 ("nanosecond") appears 8 time.
# Word 9797 ("nanowir") appears 233 time.
# Word 9802 ("neomycin") appears 1 time.
# Word 9809 ("nitroaromat") appears 1 time.
# Word 9810 ("nitrophenol") appears 2 time.
# Word 9811 ("nitrophenyl") appears 1 time.
# Word 9815 ("nonclin") appears 1 time.
# Word 9816 ("nonconvent") appears 1 time.
# Word 9817 ("nonloc") appears 5 time.
# Word 9819 ("nonoptim") appears 3 time.
# Word 9820 ("nonoverlap") appears 1 time.
# Word 9827 ("nozzl") appears 4 time.
# Word 9828 ("occult") appears 1 time.
# Word 9831 ("opc") appears 2 time.
# Word 9834 ("opson") appears 1 time.
# Word 9835 ("organometal") appears 1 time.
# Word 9839 ("osteochondr") appears 6 time.
# Word 9840 ("osteoinduct") appears 5 time.
# Word 9841 ("osteonectin") appears 1 time.
# Word 9844 ("overhang") appears 12 time.
# Word 9845 ("overshoot") appears 6 time.
# Word 9850 ("paracetamol") appears 3 time.
# Word 9854 ("pascal") appears 1 time.
# Word 9855 ("passband") appears 42 time.
# Word 9856 ("pathfind") appears 2 time.
# Word 9859 ("pedomet") appears 2 time.
# Word 9860 ("peg") appears 3 time.
# Word 9861 ("pem") appears 1 time.
# Word 9866 ("periosteum") appears 1 time.
# Word 9867 ("permitt") appears 69 time.
# Word 9877 ("photoact") appears 2 time.
# Word 9878 ("photophys") appears 8 time.
# Word 9879 ("photoreact") appears 1 time.
# Word 9880 ("photost") appears 3 time.
# Word 9881 ("photoswitch") appears 2 time.
# Word 9882 ("phthalocyanin") appears 4 time.
# Word 9883 ("piezo") appears 1 time.
# Word 9884 ("piezoelectr") appears 40 time.
# Word 9886 ("ping") appears 2 time.
# Word 9887 ("pinhol") appears 1 time.
# Word 9888 ("piperazin") appears 2 time.
# Word 9891 ("pmma") appears 14 time.
# Word 9894 ("pnipam") appears 5 time.
# Word 9895 ("polyelectrolyt") appears 1 time.
# Word 9896 ("polyurethan") appears 11 time.
# Word 9897 ("pom") appears 6 time.
# Word 9898 ("portrait") appears 1 time.
# Word 9899 ("poss") appears 11 time.
# Word 9902 ("postinjuri") appears 4 time.
# Word 9904 ("posturographi") appears 1 time.
# Word 9906 ("preambl") appears 4 time.
# Word 9908 ("preemptiv") appears 2 time.
# Word 9909 ("prefix") appears 3 time.
# Word 9915 ("prodigiosin") appears 1 time.
# Word 9921 ("prussian") appears 2 time.
# Word 9925 ("ptcl") appears 3 time.
# Word 9926 ("punch") appears 1 time.
# Word 9928 ("pvdf") appears 3 time.
# Word 9936 ("radiomet") appears 2 time.
# Word 9937 ("raster") appears 2 time.
# Word 9939 ("recalcul") appears 1 time.
# Word 9942 ("reconnect") appears 2 time.
# Word 9944 ("reengin") appears 2 time.
# Word 9945 ("referenti") appears 2 time.
# Word 9946 ("reflector") appears 65 time.
# Word 9948 ("regret") appears 3 time.
# Word 9953 ("reopen") appears 1 time.
# Word 9954 ("repar") appears 1 time.
# Word 9955 ("replay") appears 1 time.
# Word 9958 ("resorb") appears 2 time.
# Word 9959 ("resp") appears 2 time.
# Word 9961 ("restless") appears 1 time.
# Word 9962 ("retrain") appears 1 time.
# Word 9967 ("rim") appears 1 time.
# Word 9968 ("risperidon") appears 6 time.
# Word 9969 ("roadmap") appears 3 time.
# Word 9970 ("roger") appears 7 time.
# Word 9972 ("rotterdam") appears 1 time.
# Word 9973 ("roughen") appears 1 time.
# Word 9975 ("ruler") appears 1 time.
# Word 9976 ("runtim") appears 8 time.
# Word 9977 ("sacrifici") appears 10 time.
# Word 9980 ("saha") appears 6 time.
# Word 9981 ("sake") appears 7 time.
# Word 9984 ("sandblast") appears 5 time.
# Word 9985 ("sao") appears 1 time.
# Word 9987 ("sccs") appears 3 time.
# Word 9993 ("septum") appears 1 time.
# Word 9994 ("ser") appears 45 time.
# Word 9997 ("shin") appears 1 time.
# Word 9999 ("sige") appears 23 time.
# Word 10000 ("silsesquioxan") appears 4 time.
# Word 10003 ("sinter") appears 30 time.
# Word 10004 ("slant") appears 8 time.
# Word 10005 ("sleev") appears 17 time.
# Word 10006 ("solvabl") appears 3 time.
# Word 10008 ("sparc") appears 2 time.
# Word 10010 ("specular") appears 7 time.
# Word 10011 ("speedup") appears 2 time.
# Word 10012 ("spheroid") appears 17 time.
# Word 10013 ("spion") appears 11 time.
# Word 10014 ("spiro") appears 1 time.
# Word 10016 ("spline") appears 4 time.
# Word 10025 ("stretchabl") appears 19 time.
# Word 10027 ("stumbl") appears 1 time.
# Word 10029 ("suberoylanilid") appears 1 time.
# Word 10031 ("subgraph") appears 8 time.
# Word 10034 ("submodul") appears 26 time.
# Word 10035 ("subpixel") appears 7 time.
# Word 10036 ("subspac") appears 23 time.
# Word 10037 ("succinct") appears 1 time.
# Word 10041 ("suzuki") appears 1 time.
# Word 10044 ("switchabl") appears 18 time.
# Word 10047 ("synchronis") appears 21 time.
# Word 10049 ("tautomer") appears 3 time.
# Word 10054 ("temporospati") appears 1 time.
# Word 10057 ("tent") appears 1 time.
# Word 10059 ("tetragon") appears 4 time.
# Word 10060 ("tetraki") appears 2 time.
# Word 10061 ("textual") appears 1 time.
# Word 10063 ("theranost") appears 19 time.
# Word 10064 ("thermoplast") appears 5 time.
# Word 10065 ("thermosensit") appears 7 time.
# Word 10069 ("thwart") appears 2 time.
# Word 10070 ("thymin") appears 1 time.
# Word 10073 ("titan") appears 8 time.
# Word 10075 ("torso") appears 3 time.
# Word 10076 ("tosyl") appears 1 time.
# Word 10078 ("trailer") appears 1 time.
# Word 10079 ("transceiv") appears 33 time.
# Word 10083 ("tricalcium") appears 7 time.
# Word 10090 ("unaddress") appears 1 time.
# Word 10091 ("unattract") appears 1 time.
# Word 10092 ("uncoordin") appears 1 time.
# Word 10093 ("undercook") appears 1 time.
# Word 10098 ("unforeseen") appears 1 time.
# Word 10099 ("unilamellar") appears 2 time.
# Word 10100 ("unoccupi") appears 3 time.
# Word 10101 ("unord") appears 1 time.
# Word 10107 ("unwrap") appears 1 time.
# Word 10108 ("upconvers") appears 16 time.
# Word 10110 ("uptaken") appears 2 time.
# Word 10111 ("urethan") appears 1 time.
# Word 10119 ("vibrant") appears 1 time.
# Word 10121 ("viewer") appears 5 time.
# Word 10126 ("xilinx") appears 2 time.
# Word 10128 ("zeolit") appears 6 time.
# Word 10137 ("aviat") appears 2 time.
# Word 10138 ("bandgap") appears 59 time.
# Word 10139 ("butadien") appears 2 time.
# Word 10142 ("cyanoacryl") appears 2 time.
# Word 10143 ("cyber") appears 6 time.
# Word 10146 ("diblock") appears 6 time.
# Word 10147 ("dihydrogen") appears 1 time.
# Word 10148 ("dsscs") appears 6 time.
# Word 10149 ("electroact") appears 6 time.
# Word 10151 ("faraday") appears 2 time.
# Word 10152 ("glycerin") appears 2 time.
# Word 10153 ("gnrs") appears 5 time.
# Word 10154 ("heterojunct") appears 43 time.
# Word 10158 ("keratocyt") appears 5 time.
# Word 10159 ("lumo") appears 1 time.
# Word 10161 ("miscibl") appears 1 time.
# Word 10162 ("monometal") appears 1 time.
# Word 10163 ("multiphys") appears 7 time.
# Word 10164 ("nanoribbon") appears 14 time.
# Word 10165 ("nanorod") appears 78 time.
# Word 10166 ("obsolet") appears 1 time.
# Word 10167 ("operando") appears 2 time.
# Word 10168 ("opv") appears 3 time.
# Word 10169 ("pedot") appears 12 time.
# Word 10170 ("perylen") appears 2 time.
# Word 10172 ("photoemiss") appears 8 time.
# Word 10173 ("photogener") appears 6 time.
# Word 10174 ("pipet") appears 1 time.
# Word 10176 ("potentiometr") appears 7 time.
# Word 10177 ("rhodium") appears 2 time.
# Word 10180 ("srms") appears 8 time.
# Word 10183 ("vinylen") appears 1 time.
# Word 10184 ("weld") appears 19 time.
# Word 10185 ("zirconium") appears 5 time.
# Word 10187 ("auger") appears 5 time.
# Word 10189 ("biocomposit") appears 11 time.
# Word 10191 ("carbonac") appears 10 time.
# Word 10192 ("cdte") appears 10 time.
# Word 10194 ("corrug") appears 11 time.
# Word 10195 ("countless") appears 1 time.
# Word 10196 ("degeneraci") appears 5 time.
# Word 10200 ("entrepreneur") appears 1 time.
# Word 10201 ("fasten") appears 2 time.
# Word 10202 ("ferroelectr") appears 22 time.
# Word 10203 ("fet") appears 36 time.
# Word 10206 ("galleri") appears 10 time.
# Word 10207 ("haze") appears 4 time.
# Word 10208 ("heterostructur") appears 13 time.
# Word 10211 ("laplac") appears 5 time.
# Word 10214 ("multipol") appears 10 time.
# Word 10215 ("multisourc") appears 2 time.
# Word 10216 ("nanochannel") appears 12 time.
# Word 10217 ("nanoplatform") appears 3 time.
# Word 10218 ("nanosc") appears 3 time.
# Word 10219 ("nanosystem") appears 5 time.
# Word 10220 ("nanotextur") appears 2 time.
# Word 10221 ("niobat") appears 5 time.
# Word 10222 ("nitrobenzen") appears 1 time.
# Word 10224 ("nonpor") appears 1 time.
# Word 10225 ("nonradi") appears 11 time.
# Word 10226 ("nonstationari") appears 1 time.
# Word 10228 ("ole") appears 4 time.
# Word 10231 ("pamam") appears 3 time.
# Word 10232 ("papr") appears 13 time.
# Word 10233 ("pces") appears 1 time.
# Word 10235 ("pervious") appears 1 time.
# Word 10236 ("petrochem") appears 1 time.
# Word 10237 ("phosphid") appears 2 time.
# Word 10238 ("photodetector") appears 33 time.
# Word 10239 ("photoelectr") appears 3 time.
# Word 10241 ("polaron") appears 2 time.
# Word 10242 ("poloxam") appears 8 time.
# Word 10243 ("polyanilin") appears 5 time.
# Word 10244 ("portland") appears 3 time.
# Word 10245 ("printabl") appears 1 time.
# Word 10248 ("reman") appears 4 time.
# Word 10249 ("resistor") appears 45 time.
# Word 10250 ("rip") appears 1 time.
# Word 10251 ("sag") appears 10 time.
# Word 10252 ("scandium") appears 1 time.
# Word 10253 ("solvotherm") appears 4 time.
# Word 10254 ("soot") appears 5 time.
# Word 10255 ("substat") appears 15 time.
# Word 10256 ("swnts") appears 1 time.
# Word 10257 ("tantalum") appears 10 time.
# Word 10259 ("ultralow") appears 12 time.
# Word 10260 ("ultrashort") appears 6 time.
# Word 10261 ("uncag") appears 1 time.
# Word 10264 ("yttrium") appears 2 time.
# Word 10265 ("acquaint") appears 1 time.
# Word 10267 ("bernoulli") appears 6 time.
# Word 10268 ("cach") appears 5 time.
# Word 10269 ("centralis") appears 2 time.
# Word 10270 ("charger") appears 31 time.
# Word 10271 ("codebook") appears 11 time.
# Word 10272 ("coder") appears 7 time.
# Word 10273 ("codeword") appears 13 time.
# Word 10274 ("compressor") appears 7 time.
# Word 10275 ("cpss") appears 6 time.
# Word 10276 ("deadlin") appears 4 time.
# Word 10277 ("debug") appears 1 time.
# Word 10278 ("decentralis") appears 1 time.
# Word 10279 ("downlink") appears 34 time.
# Word 10280 ("downsid") appears 1 time.
# Word 10281 ("downtim") appears 1 time.
# Word 10282 ("droop") appears 28 time.
# Word 10283 ("dualiti") appears 4 time.
# Word 10285 ("erbium") appears 5 time.
# Word 10286 ("extractor") appears 2 time.
# Word 10289 ("fpgas") appears 10 time.
# Word 10290 ("gpus") appears 1 time.
# Word 10291 ("grayscal") appears 6 time.
# Word 10292 ("handoff") appears 4 time.
# Word 10293 ("handset") appears 7 time.
# Word 10295 ("hilbert") appears 6 time.
# Word 10297 ("ieee") appears 46 time.
# Word 10298 ("inlin") appears 2 time.
# Word 10299 ("interferomet") appears 8 time.
# Word 10300 ("intracardiac") appears 1 time.
# Word 10301 ("kalman") appears 46 time.
# Word 10302 ("kinect") appears 1 time.
# Word 10303 ("kuhn") appears 3 time.
# Word 10304 ("lookup") appears 6 time.
# Word 10305 ("lossless") appears 11 time.
# Word 10307 ("metro") appears 1 time.
# Word 10308 ("microprocessor") appears 2 time.
# Word 10309 ("mimo") appears 187 time.
# Word 10310 ("missil") appears 1 time.
# Word 10311 ("monochrom") appears 2 time.
# Word 10312 ("mover") appears 4 time.
# Word 10313 ("multiband") appears 26 time.
# Word 10314 ("multicarri") appears 4 time.
# Word 10315 ("multimedia") appears 15 time.
# Word 10316 ("nonconvex") appears 10 time.
# Word 10317 ("nonsmooth") appears 4 time.
# Word 10318 ("offload") appears 3 time.
# Word 10319 ("onus") appears 1 time.
# Word 10320 ("opto") appears 3 time.
# Word 10322 ("outag") appears 78 time.
# Word 10323 ("outsourc") appears 7 time.
# Word 10325 ("oximet") appears 1 time.
# Word 10326 ("password") appears 3 time.
# Word 10328 ("phasor") appears 17 time.
# Word 10329 ("pipe") appears 2 time.
# Word 10332 ("quad") appears 14 time.
# Word 10333 ("quantize") appears 49 time.
# Word 10334 ("reckon") appears 2 time.
# Word 10335 ("recover") appears 3 time.
# Word 10336 ("rerout") appears 1 time.
# Word 10337 ("resiz") appears 2 time.
# Word 10338 ("rfid") appears 46 time.
# Word 10339 ("roadsid") appears 5 time.
# Word 10340 ("rotate") appears 2 time.
# Word 10341 ("rssi") appears 2 time.
# Word 10343 ("slack") appears 1 time.
# Word 10344 ("ssds") appears 4 time.
# Word 10345 ("ssim") appears 1 time.
# Word 10347 ("superpixel") appears 4 time.
# Word 10351 ("testb") appears 10 time.
# Word 10352 ("tikhonov") appears 4 time.
# Word 10353 ("tucker") appears 3 time.
# Word 10354 ("underdetermin") appears 2 time.
# Word 10355 ("undistort") appears 3 time.
# Word 10356 ("unipolar") appears 10 time.
# Word 10357 ("unlicens") appears 4 time.
# Word 10358 ("unscent") appears 5 time.
# Word 10360 ("uplink") appears 26 time.
# Word 10361 ("upset") appears 3 time.
# Word 10362 ("virtex") appears 2 time.
# Word 10363 ("wifi") appears 3 time.
# Word 10364 ("workspac") appears 13 time.
# Word 10365 ("deck") appears 1 time.
# Word 10367 ("interclass") appears 1 time.
# Word 10368 ("monopolar") appears 2 time.
# Word 10369 ("multipass") appears 1 time.
# Word 10370 ("multiregion") appears 1 time.
# Word 10371 ("narrowband") appears 20 time.
# Word 10373 ("pretrain") appears 1 time.
# Word 10374 ("squint") appears 8 time.
# Word 10375 ("uncalibr") appears 2 time.
# Word 10378 ("chassi") appears 4 time.
# Word 10380 ("fixtur") appears 6 time.
# Word 10381 ("governor") appears 2 time.
# Word 10383 ("mosfet") appears 80 time.
# Word 10384 ("movabl") appears 1 time.
# Word 10385 ("noncontact") appears 5 time.
# Word 10386 ("reactanc") appears 5 time.
# Word 10387 ("reschedul") appears 2 time.
# Word 10388 ("solder") appears 19 time.
# Word 10389 ("startup") appears 9 time.
# Word 10391 ("vernier") appears 2 time.
# Word 10392 ("ada") appears 6 time.
# Word 10393 ("apt") appears 2 time.
# Word 10394 ("automobil") appears 4 time.
# Word 10395 ("cabinet") appears 8 time.
# Word 10396 ("cantilev") appears 15 time.
# Word 10397 ("choke") appears 6 time.
# Word 10398 ("conferenc") appears 2 time.
# Word 10399 ("dass") appears 2 time.
# Word 10400 ("embarrass") appears 1 time.
# Word 10401 ("esthet") appears 1 time.
# Word 10402 ("freiburg") appears 1 time.
# Word 10403 ("hank") appears 3 time.
# Word 10404 ("hypopnea") appears 1 time.
# Word 10405 ("inch") appears 3 time.
# Word 10406 ("jacket") appears 2 time.
# Word 10407 ("magazin") appears 1 time.
# Word 10408 ("midsiz") appears 1 time.
# Word 10409 ("nanogel") appears 9 time.
# Word 10410 ("noncytotox") appears 1 time.
# Word 10411 ("pcsa") appears 1 time.
# Word 10412 ("penn") appears 2 time.
# Word 10413 ("polymethyl") appears 1 time.
# Word 10414 ("shutter") appears 3 time.
# Word 10415 ("supervisor") appears 4 time.
# Word 10416 ("tenni") appears 3 time.
# Word 10417 ("thinnest") appears 3 time.
# Word 10418 ("unsatisfi") appears 1 time.
# Word 10419 ("useabl") appears 1 time.
# Word 10420 ("wavefront") appears 6 time.
# Word 10421 ("wilkinson") appears 8 time.
# Word 10422 ("zigzag") appears 3 time.

# %% [markdown]
# TF-IDF method

# %%
from gensim import corpora, models

tfidf = models.TfidfModel(bow_corpus)

# %%
corpus_tfidf = tfidf[bow_corpus]

# %%
from pprint import pprint

for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0
# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=100, id2word=dictionary, passes=2, workers=2)

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.002*"caregiv" + 0.002*"thyroid" + 0.002*"atrial" + 0.002*"transfus" + 0.002*"aneurysm" + 0.002*"youth" + 0.001*"pylori" + 0.001*"allergen" + 0.001*"oocyt" + 0.001*"remiss"
# Topic: 1
# Words: 0.010*"therapist" + 0.007*"concuss" + 0.006*"ptsd" + 0.005*"youth" + 0.005*"caregiv" + 0.005*"snack" + 0.005*"psychosi" + 0.005*"music" + 0.005*"amygdala" + 0.005*"esteem"
# Topic: 2
# Words: 0.004*"periodont" + 0.002*"caregiv" + 0.002*"youth" + 0.002*"cow" + 0.001*"violenc" + 0.001*"radiograph" + 0.001*"atrial" + 0.001*"aneurysm" + 0.001*"synapt" + 0.001*"thyroid"
# Topic: 3
# Words: 0.004*"tick" + 0.002*"thyroid" + 0.002*"larva" + 0.002*"autophagi" + 0.002*"cow" + 0.002*"atrial" + 0.002*"caregiv" + 0.002*"malaria" + 0.002*"synapt" + 0.001*"youth"
# Topic: 4
# Words: 0.013*"fault" + 0.006*"turbin" + 0.005*"lignocellulos" + 0.004*"ieee" + 0.004*"rotor" + 0.003*"torqu" + 0.003*"capacitor" + 0.003*"xylos" + 0.003*"microalga" + 0.003*"substat"
# Topic: 5
# Words: 0.003*"periodont" + 0.003*"caregiv" + 0.003*"cow" + 0.002*"synapt" + 0.001*"thyroid" + 0.001*"arabidopsi" + 0.001*"autophagi" + 0.001*"aneurysm" + 0.001*"stat" + 0.001*"malaria"
# Topic: 6
# Words: 0.002*"caregiv" + 0.002*"aneurysm" + 0.002*"youth" + 0.002*"thyroid" + 0.002*"periodont" + 0.002*"atrial" + 0.002*"stent" + 0.002*"pylori" + 0.001*"remiss" + 0.001*"nsclc"
# Topic: 7
# Words: 0.002*"wireless" + 0.002*"autophagi" + 0.002*"graphen" + 0.001*"cow" + 0.001*"youth" + 0.001*"caregiv" + 0.001*"aneurysm" + 0.001*"thyroid" + 0.001*"sepsi" + 0.001*"stent"
# Topic: 8
# Words: 0.002*"cow" + 0.002*"caregiv" + 0.002*"thyroid" + 0.002*"atrial" + 0.001*"remiss" + 0.001*"stent" + 0.001*"progenitor" + 0.001*"synapt" + 0.001*"graphen" + 0.001*"periodont"
# Topic: 9
# Words: 0.010*"mimo" + 0.009*"asymptot" + 0.009*"wireless" + 0.006*"outag" + 0.006*"censor" + 0.006*"beamform" + 0.005*"secreci" + 0.005*"packet" + 0.004*"ofdm" + 0.004*"wiley"
# Topic: 10
# Words: 0.006*"readmiss" + 0.003*"unplan" + 0.002*"wireless" + 0.002*"graphen" + 0.002*"caregiv" + 0.002*"payoff" + 0.002*"cow" + 0.002*"atrial" + 0.001*"periodont" + 0.001*"aneurysm"
# Topic: 11
# Words: 0.002*"cow" + 0.002*"caregiv" + 0.002*"youth" + 0.002*"thyroid" + 0.002*"violenc" + 0.002*"radiograph" + 0.001*"atrial" + 0.001*"synapt" + 0.001*"transfus" + 0.001*"autophagi"
# Topic: 12
# Words: 0.002*"caregiv" + 0.002*"thyroid" + 0.002*
# Topic: 37
# Words: 0.003*"autophagi" + 0.002*"synapt" + 0.002*"oocyt" + 0.002*"progenitor" + 0.002*"caregiv" + 0.002*"thyroid" + 0.001*"aneurysm" + 0.001*"stat" + 0.001*"pten" + 0.001*"corneal"
# Topic: 38
# Words: 0.007*"tick" + 0.003*"autophagi" + 0.002*"larva" + 0.002*"oocyt" + 0.002*"clade" + 0.002*"thyroid" + 0.002*"rnas" + 0.002*"cyst" + 0.001*"nsclc" + 0.001*"gondii"
# Topic: 39
# Words: 0.002*"stent" + 0.002*"thyroid" + 0.002*"atrial" + 0.002*"sepsi" + 0.002*"radiograph" + 0.002*"aneurysm" + 0.001*"youth" + 0.001*"caregiv" + 0.001*"oocyt" + 0.001*"autophagi"
# Topic: 40
# Words: 0.004*"caregiv" + 0.003*"aneurysm" + 0.003*"youth" + 0.003*"transfus" + 0.003*"remiss" + 0.003*"stent" + 0.003*"atrial" + 0.003*"ptsd" + 0.002*"laparoscop" + 0.002*"sepsi"
# Topic: 41
# Words: 0.002*"periodont" + 0.002*"youth" + 0.002*"caregiv" + 0.002*"wireless" + 0.002*"graphen" + 0.002*"autophagi" + 0.001*"thyroid" + 0.001*"fault" + 0.001*"dielectr" + 0.001*"waveguid"
# Topic: 42
# Words: 0.005*"aryl" + 0.004*"graphen" + 0.004*"alkyl" + 0.004*"intramolecular" + 0.004*"porphyrin" + 0.004*"cyclize" + 0.004*"heterocycl" + 0.004*"substitu" + 0.003*"fluorin" + 0.003*"catalysi"
# Topic: 43
# Words: 0.002*"autophagi" + 0.002*"atrial" + 0.002*"youth" + 0.002*"caregiv" + 0.002*"synapt" + 0.002*"aneurysm" + 0.002*"stent" + 0.001*"thyroid" + 0.001*"progenitor" + 0.001*"transfus"
# Topic: 44
# Words: 0.002*"synapt" + 0.002*"graphen" + 0.002*"autophagi" + 0.002*"liposom" + 0.002*"wireless" + 0.002*"fault" + 0.002*"flavonoid" + 0.002*"curcumin" + 0.002*"chitosan" + 0.001*"hydroxyl"
# Topic: 45
# Words: 0.003*"thyroid" + 0.003*"aneurysm" + 0.002*"youth" + 0.002*"atrial" + 0.002*"transfus" + 0.002*"autophagi" + 0.002*"caregiv" + 0.002*"malaria" + 0.002*"laparoscop" + 0.002*"progenitor"
# Topic: 46
# Words: 0.002*"radiograph" + 0.002*"thyroid" + 0.001*"caregiv" + 0.001*"stent" + 0.001*"autophagi" + 0.001*"cow" + 0.001*"periodont" + 0.001*"atrial" + 0.001*"youth" + 0.001*"oocyt"
# Topic: 47
# Words: 0.002*"graphen" + 0.002*"dielectr" + 0.002*"wireless" + 0.002*"cow" + 0.002*"waveguid" + 0.002*"fault" + 0.002*"radar" + 0.002*"caregiv" + 0.002*"stent" + 0.002*"atrial"
# Topic: 48
# Words: 0.002*"atrial" + 0.002*"caregiv" + 0.002*"youth" + 0.002*"stent" + 0.001*"aneurysm" + 0.001*"thyroid" + 0.001*"graphen" + 0.001*"synapt" + 0.001*"transfus" + 0.001*"malaria"
# Topic: 49
# Words: 0.002*"caregiv" + 0.002*"thyroid" + 0.002*"youth" + 0.001*"synapt" + 0.001*"autophagi" + 0.001*"cow" + 0.001*"larva" + 0.001*"oocyt" + 0.001*"atrial" + 0.001*"malaria"
# Topic: 63
# Words: 0.002*"oocyt" + 0.002*"autophagi" + 0.002*"thyroid" + 0.002*"progenitor" + 0.002*"mapk" + 0.002*"stat" + 0.002*"malaria" + 0.002*"clade" + 0.001*"caregiv" + 0.001*"nsclc"
# Topic: 64
# Words: 0.002*"caregiv" + 0.002*"radiograph" + 0.002*"thyroid" + 0.002*"periodont" + 0.002*"atrial" + 0.002*"stent" + 0.002*"transfus" + 0.002*"graphen" + 0.001*"wireless" + 0.001*"dielectr"
# Topic: 65
# Words: 0.002*"periodont" + 0.002*"caregiv" + 0.002*"thyroid" + 0.002*"cow" + 0.001*"ankl" + 0.001*"atrial" + 0.001*"youth" + 0.001*"stent" + 0.001*"sepsi" + 0.001*"aneurysm"
# Topic: 66
# Words: 0.002*"periodont" + 0.002*"cow" + 0.002*"synapt" + 0.002*"atrial" + 0.002*"graphen" + 0.002*"autophagi" + 0.002*"thyroid" + 0.001*"radiograph" + 0.001*"senesc" + 0.001*"oocyt"
# Topic: 67
# Words: 0.002*"caregiv" + 0.002*"aneurysm" + 0.002*"synapt" + 0.002*"atrial" + 0.002*"youth" + 0.001*"stent" + 0.001*"cow" + 0.001*"reperfus" + 0.001*"laparoscop" + 0.001*"autophagi"
# Topic: 68
# Words: 0.002*"cow" + 0.002*"youth" + 0.002*"synapt" + 0.002*"caregiv" + 0.002*"atrial" + 0.001*"violenc" + 0.001*"stent" + 0.001*"malaria" + 0.001*"aneurysm" + 0.001*"arabidopsi"
# Topic: 69
# Words: 0.003*"graphen" + 0.002*"fault" + 0.002*"atrial" + 0.002*"cow" + 0.002*"oocyt" + 0.002*"stent" + 0.002*"malaria" + 0.001*"synapt" + 0.001*"dielectr" + 0.001*"wireless"
# Topic: 70
# Words: 0.002*"caregiv" + 0.002*"autophagi" + 0.002*"stent" + 0.002*"radiograph" + 0.002*"thyroid" + 0.002*"malaria" + 0.001*"youth" + 0.001*"aneurysm" + 0.001*"cow" + 0.001*"transfus"
# Topic: 71
# Words: 0.002*"periodont" + 0.002*"synapt" + 0.002*"youth" + 0.002*"caregiv" + 0.001*"cow" + 0.001*"autophagi" + 0.001*"arabidopsi" + 0.001*"oocyt" + 0.001*"larva" + 0.001*"repress"
# Topic: 72
# Words: 0.002*"atrial" + 0.002*"synapt" + 0.002*"stent" + 0.002*"oocyt" + 0.002*"thyroid" + 0.001*"transfus" + 0.001*"sepsi" + 0.001*"malaria" + 0.001*"periodont" + 0.001*"youth"
# Topic: 73
# Words: 0.002*"periodont" + 0.002*"youth" + 0.002*"thyroid" + 0.002*"cow" + 0.002*"caregiv" + 0.001*"stent" + 0.001*"sepsi" + 0.001*"synapt" + 0.001*"aneurysm" + 0.001*"malaria"
# Topic: 74
# Words: 0.003*"graphen" + 0.002*"caregiv" + 0.002*"thyroid" + 0.001*"autophagi" + 0.001*"cow" + 0.001*"malaria" + 0.001*"atrial" + 0.001*"periodont" + 0.001*"wireless" + 0.001*"aneurysm"
# Topic: 75
# Words: 0.002*"periodont" + 0.002*"cow" + 0.002*"radar" + 0.002*"hyperspectr" + 0.001*"caregiv" + 0.001*"autophagi" + 0.001*"stent" + 0.001*"youth" + 0.001*"larva" + 0.001*"oocyt"
# Topic: 76
# Words: 0.002*"caregiv" + 0.002*"periodont" + 0.002*"autophagi" + 0.002*"cow" + 0.002*"synapt" + 0.002*"radiograph" + 0.002*"thyroid" + 0.001*"stent" + 0.001*"atrial" + 0.001*"youth"
# Topic: 77
# Words: 0.002*"caregiv" + 0.002*"cow" + 0.002*"thyroid" + 0.002*"atrial" + 0.002*"remiss" + 0.001*"youth" + 0.001*"synapt" + 0.001*"wireless" + 0.001*"aneurysm" + 0.001*"fault"
# Topic: 78
# Words: 0.004*"fantasi" + 0.004*"writer" + 0.003*"amateur" + 0.002*"caregiv" + 0.002*"autophagi" + 0.002*"appoint" + 0.002*"discours" + 0.001*"oocyt" + 0.001*"thyroid" + 0.001*"cow"
# Topic: 79
# Words: 0.002*"stent" + 0.002*"periodont" + 0.002*"laparoscop" + 0.002*"thyroid" + 0.002*"aneurysm" + 0.002*"caregiv" + 0.002*"atrial" + 0.002*"malaria" + 0.002*"cow" + 0.002*"transfus"
# Topic: 80
# Words: 0.002*"graphen" + 0.002*"atrial" + 0.002*"cat" + 0.002*"corneal" + 0.002*"cow" + 0.002*"herd" + 0.002*"radiograph" + 0.002*"caregiv" + 0.002*"cattl" + 0.001*"malaria"
# Topic: 81
# Words: 0.003*"caregiv" + 0.002*"graphen" + 0.002*"thyroid" + 0.002*"youth" + 0.002*"aneurysm" + 0.002*"dielectr" + 0.002*"transfus" + 0.001*"radiograph" + 0.001*"waveguid" + 0.001*"stent"
# Topic: 82
# Words: 0.004*"stent" + 0.003*"aneurysm" + 0.003*"radiograph" + 0.003*"caregiv" + 0.002*"transfus" + 0.002*"allergen" + 0.002*"atrial" + 0.002*"laparoscop" + 0.002*"malaria" + 0.002*"thyroid"
# Topic: 83
# Words: 0.017*"graphen" + 0.011*"wireless" + 0.010*"dielectr" + 0.010*"fault" + 0.008*"waveguid" + 0.007*"capacitor" + 0.007*"transistor" + 0.006*"slot" + 0.006*"nanowir" + 0.006*"torqu"
# Topic: 84
# Words: 0.008*"ankl" + 0.008*"sprint" + 0.008*"flexion" + 0.008*"therapist" + 0.007*"elit" + 0.007*"soccer" + 0.006*"seat" + 0.006*"kick" + 0.006*"squat" + 0.005*"prison"
# Topic: 85
# Words: 0.016*"wireless" + 0.008*"packet" + 0.007*"fault" + 0.005*"waveguid" + 0.005*"grate" + 0.004*"ofdm" + 0.004*"server" + 0.003*"overhead" + 0.003*"testb" + 0.003*"cach"
# Topic: 86
# Words: 0.004*"liposom" + 0.003*"genotox" + 0.003*"curcumin" + 0.002*"autophagi" + 0.002*"hepg" + 0.002*"mapk" + 0.002*"atpas" + 0.002*"chitosan" + 0.002*"pharmacist" + 0.002*"hydroxyl"
# Topic: 11 Word: 0.001*"offend" + 0.001*"moral" + 0.001*"listen" + 0.001*"audiolog" + 0.001*"rememb" + 0.000*"handed" + 0.000*"recollect" + 0.000*"tinnitus" + 0.000*"bilingu" + 0.000*"vowel"
# Topic: 12 Word: 0.002*"readmiss" + 0.001*"unplan" + 0.001*"wireless" + 0.001*"fault" + 0.001*"packet" + 0.000*"payoff" + 0.000*"breakfast" + 0.000*"cach" + 0.000*"subspac" + 0.000*"wage"
# Topic: 13 Word: 0.000*"laparoscop" + 0.000*"endometri" + 0.000*"transfus" + 0.000*"aneurysm" + 0.000*"stenosi" + 0.000*"embol" + 0.000*"caregiv" + 0.000*"atrial" + 0.000*"periop" + 0.000*"hsct"
# Topic: 14 Word: 0.001*"fantasi" + 0.001*"amateur" + 0.001*"writer" + 0.000*"ptsd" + 0.000*"therapist" + 0.000*"genr" + 0.000*"snack" + 0.000*"allianc" + 0.000*"concuss" + 0.000*"psychotherapi"
# Topic: 15 Word: 0.000*"wastewat" + 0.000*"sludg" + 0.000*"sediment" + 0.000*"pah" + 0.000*"arsenic" + 0.000*"lake" + 0.000*"wetland" + 0.000*"effluent" + 0.000*"cadmium" + 0.000*"biodivers"
# Topic: 16 Word: 0.001*"waveguid" + 0.001*"grate" + 0.000*"interferomet" + 0.000*"coupler" + 0.000*"ofdm" + 0.000*"terahertz" + 0.000*"mem" + 0.000*"wireless" + 0.000*"cmos" + 0.000*"dielectr"
# Topic: 17 Word: 0.001*"mimo" + 0.001*"asymptot" + 0.001*"outag" + 0.001*"beamform" + 0.001*"synapt" + 0.001*"ofdm" + 0.001*"wireless" + 0.001*"secreci" + 0.001*"uplink" + 0.000*"downlink"
# Topic: 18 Word: 0.001*"tick" + 0.001*"fault" + 0.001*"turbin" + 0.001*"ieee" + 0.001*"lignocellulos" + 0.000*"rotor" + 0.000*"xylos" + 0.000*"phasor" + 0.000*"substat" + 0.000*"bioga"
# Topic: 19 Word: 0.001*"caregiv" + 0.001*"palliat" + 0.001*"delirium" + 0.001*"leadership" + 0.000*"spiritu" + 0.000*"moral" + 0.000*"triag" + 0.000*"violenc" + 0.000*"carer" + 0.000*"autophagi"

# %% [markdown]
# Classify sample document using LDA Bag of Words model

# %%
processed_docs[11]
# Out:
# ['consid',
#  'problem',
#  'estim',
#  'local',
#  'sensor',
#  'paramet',
#  'local',
#  'paramet',
#  'sensor',
#  'observ',
#  'relat',
#  'linear',
#  'stochast',
#  'model',
#  'studi',
#  'gaussian',
#  'product',
#  'algorithm',
#  'wireless',
#  'network',
#  'gspawn',
#  'procedur',
#  'compar',
#  'popular',
#  'diffus',
#  'strategi',
#  'perform',
#  'network',
#  'paramet',
#  'estim',
#  'communic',
#  'cost',
#  'sensor',
#  'increas',
#  'increas',
#  'network',
#  'densiti',
#  'gspawn',
#  'allow',
#  'sensor',
#  'broadcast',
#  'messag',
#  'size',
#  'depend',
#  'network',
#  'size',
#  'densiti',
#  'make',
#  'suitabl',
#  'applic',
#  'wireless',
#  'sensor',
#  'network',
#  'gspawn',
#  'converg',
#  'mean',
#  'mean',
#  'squar',
#  'stabil',
#  'technic',
#  'suffici',
#  'condit',
#  'applic',
#  'gspawn',
#  'network',
#  'local',
#  'problem',
#  'line',
#  'sight',
#  'environ',
#  'numer',
#  'result',
#  'suggest',
#  'gspawn',
#  'converg',
#  'faster',
#  'general',
#  'diffus',
#  'method',
#  'lower',
#  'communic',
#  'cost',
#  'sensor',
#  'compar',
#  'root',
#  'mean',
#  'squar',
#  'error',
#  'express',
#  'clone',
#  'play',
#  'import',
#  'role',
#  'facial',
#  'express',
#  'synthesi',
#  'paper',
#  'novel',
#  'algorithm',
#  'propos',
#  'facial',
#  'express',
#  'clone',
#  'propos',
#  'algorithm',
#  'introduc',
#  'elast',
#  'model',
#  'balanc',
#  'global',
#  'local',
#  'warp',
#  'effect',
#  'impact',
#  'facial',
#  'featur',
#  'divers',
#  'peopl',
#  'minim',
#  'effect',
#  'geometr',
#  'warp',
#  'result',
#  'achiev',
#  'furthermor',
#  'muscl',
#  'distribut',
#  'base',
#  'model',
#  'propos',
#  'util',
#  'muscl',
#  'distribut',
#  'human',
#  'face',
#  'result',
#  'accur',
#  'facial',
#  'illumin',
#  'detail',
#  'addit',
#  'propos',
#  'distanc',
#  'base',
#  'metric',
#  'automat',
#  'select',
#  'optim',
#  'paramet',
#  'global',
#  'local',
#  'warp',
#  'effect',
#  'elast',
#  'model',
#  'suitabl',
#  'balanc',
#  'experiment',
#  'result',
#  'propos',
#  'algorithm',
#  'outperform',
#  'exist',
#  'method',
#  'elsevi',
#  'right',
#  'reserv',
#  'paper',
#  'consid',
#  'wireless',
#  'power',
#  'cooper',
#  'communic',
#  'network',
#  'consist',
#  'hybrid',
#  'access',
#  'point',
#  'sourc',
#  'relay',
#  'contrast',
#  'convent',
#  'cooper',
#  'network',
#  'sourc',
#  'relay',
#  'consid',
#  'network',
#  'emb',
#  'energi',
#  'suppli',
#  'need',
#  'reli',
#  'energi',
#  'harvest',
#  'signal',
#  'broadcast',
#  'cooper',
#  'inform',
#  'transmiss',
#  'base',
#  'node',
#  'refer',
#  'model',
#  'propos',
#  'harvest',
#  'cooper',
#  'protocol',
#  'sourc',
#  'relay',
#  'harvest',
#  'energi',
#  'downlink',
#  'work',
#  'cooper',
#  'uplink',
#  'sourc',
#  'inform',
#  'transmiss',
#  'consid',
#  'delay',
#  'limit',
#  'transmiss',
#  'mode',
#  'approxim',
#  'close',
#  'form',
#  'express',
#  'averag',
#  'throughput',
#  'propos',
#  'protocol',
#  'deriv',
#  'rayleigh',
#  'fade',
#  'channel',
#  'subsequ',
#  'analysi',
#  'extend',
#  'multi',
#  'relay',
#  'scenario',
#  'approxim',
#  'throughput',
#  'protocol',
#  'popular',
#  'relay',
#  'select',
#  'scheme',
#  'deriv',
#  'asymptot',
#  'analys',
#  'throughput',
#  'perform',
#  'consid',
#  'scheme',
#  'high',
#  'signal',
#  'nois',
#  'radio',
#  'provid',
#  'theoret',
#  'result',
#  'valid',
#  'numer',
#  'simul',
#  'impact',
#  'paramet',
#  'time',
#  'alloc',
#  'relay',
#  'number',
#  'relay',
#  'posit',
#  'throughput',
#  'perform',
#  'extens',
#  'investig',
#  'paper',
#  'propos',
#  'crowdsourc',
#  'base',
#  'framework',
#  'myopic',
#  'target',
#  'track',
#  'design',
#  'optim',
#  'incent',
#  'compat',
#  'mechan',
#  'wireless',
#  'sensor',
#  'network',
#  'contain',
#  'sensor',
#  'selfish',
#  'profit',
#  'motiv',
#  'typic',
#  'wsns',
#  'limit',
#  'bandwidth',
#  'fusion',
#  'center',
#  'distribut',
#  'total',
#  'number',
#  'bit',
#  'transmit',
#  'sensor',
#  'sensor',
#  'formul',
#  'consid',
#  'conduct',
#  'auction',
#  'solicit',
#  'bid',
#  'selfish',
#  'sensor',
#  'reflect',
#  'valu',
#  'energi',
#  'cost',
#  'furthermor',
#  'ration',
#  'truth',
#  'sensor',
#  'guarante',
#  'model',
#  'final',
#  'problem',
#  'formul',
#  'multipl',
#  'choic',
#  'knapsack',
#  'problem',
#  'mckp',
#  'solv',
#  'dynam',
#  'program',
#  'method',
#  'pseudo',
#  'polynomi',
#  'time',
#  'simul',
#  'result',
#  'effect',
#  'propos',
#  'approach',
#  'term',
#  'track',
#  'perform',
#  'lifetim',
#  'sensor',
#  'network',
#  'present',
#  'joint',
#  'channel',
#  'power',
#  'alloc',
#  'framework',
#  'downlink',
#  'transmiss',
#  'orthogon',
#  'frequenc',
#  'divis',
#  'multipl',
#  'access',
#  'ofdma',
#  'base',
#  'cellular',
#  'network',
#  'compos',
#  'macrocel',
#  'overlay',
#  'small',
#  'cell',
#  'framework',
#  'resourc',
#  'alloc',
#  'problem',
#  'macrocel',
#  'small',
#  'cell',
#  'formul',
#  'optim',
#  'problem',
#  'macrocel',
#  'formul',
#  'problem',
#  'awar',
#  'exist',
#  'small',
#  'cell',
#  'tier',
#  'problem',
#  'macrocel',
#  'perform',
#  'satisfi',
#  'data',
#  'rate',
#  'requir',
#  'macro',
#  'user',
#  'equip',
#  'mue',
#  'maxim',
#  'toler',
#  'interfer',
#  'small',
#  'cell',
#  'tier',
#  'alloc',
#  'channel',
#  'problem',
#  'macrocel',
#  'show',
#  'mix',
#  'integ',
#  'nonlinear',
#  'problem',
#  'minlp',
#  'prove',
#  'macrocel',
#  'solv',
#  'altern',
#  'optim',
#  'problem',
#  'yield',
#  'optim',
#  'solut',
#  'reduc',
#  'complex',
#  'small',
#  'cell',
#  'follow',
#  'idea',
#  'tier',
#  'awar',
#  'formul',
#  'optim',
#  'problem',
#  'account',
#  'admiss',
#  'control',
#  'aim',
#  'maxim',
#  'number',
#  'admit',
#  'user',
#  'simultan',
#  'minim',
#  'consum',
#  'bandwidth',
#  'similar',
#  'macrocel',
#  'optim',
#  'problem',
#  'small',
#  'cell',
#  'problem',
#  'show',
#  'minlp',
#  'obtain',
#  'optim',
#  'solut',
#  'minlp',
#  'problem',
#  'reli',
#  'convex',
#  'relax',
#  'addit',
#  'employ',
#  'dual',
#  'decomposit',
#  'techniqu',
#  'distribut',
#  'solut',
#  'small',
#  'cell',
#  'tier',
#  'numer',
#  'result',
#  'confirm',
#  'perform',
#  'gain',
#  'propos',
#  'formul',
#  'macrocel',
#  'tradit',
#  'resourc',
#  'alloc',
#  'base',
#  'minim',
#  'transmiss',
#  'power',
#  'show',
#  'formul',
#  'base',
#  'convex',
#  'relax',
#  'yield',
#  'similar',
#  'behavior',
#  'minlp',
#  'formul',
#  'distribut',
#  'solut',
#  'converg',
#  'solut',
#  'obtain',
#  'solv',
#  'correspond',
#  'convex',
#  'optim',
#  'problem',
#  'central',
#  'fashion',
#  'cellular',
#  'network',
#  'model',
#  'base',
#  'station',
#  'usual',
#  'assum',
#  'form',
#  'lattic',
#  'poisson',
#  'point',
#  'process',
#  'realiti',
#  'deploy',
#  'fulli',
#  'regular',
#  'complet',
#  'random',
#  'accord',
#  'paper',
#  'consid',
#  'general',
#  'class',
#  'motion',
#  'invari',
#  'model',
#  'analyz',
#  'behavior',
#  'outag',
#  'probabl',
#  'probabl',
#  'signal',
#  'interfer',
#  'plus',
#  'nois',
#  'ratio',
#  'sinr',
#  'smaller',
#  'threshold',
#  'threshold',
#  'go',
#  'zero',
#  'remark',
#  'slope',
#  'outag',
#  'probabl',
#  'function',
#  'threshold',
#  'essenti',
#  'motion',
#  'invari',
#  'point',
#  'process',
#  'slope',
#  'mere',
#  'depend',
#  'fade',
#  'statist',
#  'result',
#  'introduc',
#  'notion',
#  'asymptot',
#  'deploy',
#  'gain',
#  'character',
#  'horizont',
#  'success',
#  'probabl',
#  'point',
#  'process',
#  'high',
#  'reliabl',
#  'regim',
#  'success',
#  'probabl',
#  'near',
#  'demonstr',
#  'use',
#  'sinr',
#  'distribut',
#  'investig',
#  'outag',
#  'probabl',
#  'adg',
#  'differ',
#  'point',
#  'process',
#  'fade',
#  'statist',
#  'simul',
#  'molecular',
#  'communic',
#  'network',
#  'realis',
#  'communic',
#  'nanoscal',
#  'devic',
#  'molecular',
#  'communic',
#  'network',
#  'transmitt',
#  'receiv',
#  'communic',
#  'signal',
#  'molecul',
#  'receiv',
#  'signal',
#  'molecul',
#  'react',
#  'chain',
#  'chemic',
#  'reaction',
#  'produc',
#  'output',
#  'molecul',
#  'count',
#  'output',
#  'molecul',
#  'time',
#  'output',
#  'signal',
#  'receiv',
#  'output',
#  'signal',
#  'noisi',
#  'stochast',
#  'natur',
#  'diffus',
#  'chemic',
#  'reaction',
#  'paper',
#  'aim',
#  'characteris',
#  'properti',
#  'output',
#  'signal',
#  'model',
#  'transmiss',
#  'medium',
#  'transmitt',
#  'receiv',
#  'order',
#  'simplifi',
#  'analysi',
#  'model',
#  'transmitt',
#  'sequenc',
#  'specifi',
#  'number',
#  'molecul',
#  'emit',
#  'transmitt',
#  'time',
#  'paper',
#  'consid',
#  'receiv',
#  'reaction',
#  'mechan',
#  'revers',
#  'convers',
#  'linear',
#  'catalyt',
#  'approxim',
#  'respect',
#  'ligand',
#  'receptor',
#  'bind',
#  'enzymat',
#  'reaction',
#  'mechan',
#  'choos',
#  'consid',
#  'transmitt',
#  'diffus',
#  'ordinari',
#  'differenti',
#  'equat',
#  'describ',
#  'mean',
#  'behaviour',
#  'reaction',
#  'mechan',
#  'form',
#  'consid',
#  'behaviour',
#  'transmitt',
#  'signal',
#  'mean',
#  'varianc',
#  'number',
#  'output',
#  'molecul',
#  'receiv',
#  'reaction',
#  'mechan',
#  'differ',
#  'behaviour',
#  'deriv',
#  'analyt',
#  'express',
#  'mean',
#  'varianc',
#  'frequenc',
#  'properti',
#  'number',
#  'output',
#  'molecul',
#  'receiv',
#  'reaction',
#  'mechan',
#  'addit',
#  'revers',
#  'convers',
#  'abl',
#  'deriv',
#  'exact',
#  'probabl',
#  'distribut',
#  'number',
#  'output',
#  'molecul',
#  'model',
#  'allow',
#  'studi',
#  'impact',
#  'design',
#  'paramet',
#  'communic',
#  'perform',
#  'exampl',
#  'assum',
#  'receiv',
#  'enclos',
#  'membran',
#  'studi',
#  'impact',
#  'diffus',
#  'molecul',
#  'membran',
#  'communic',
#  'rformanc',
#  'paper',
#  'present',
#  'statist',
#  'chatter',
#  'detect',
#  'method',
#  'methodolog',
#  'base',
#  'studi',
#  'discret',
#  'wavelet',
#  'transform',
#  'scheme',
#  'statist',
#  'analysi',
#  'wavelet',
#  'transform',
#  'modulus',
#  'maxima',
#  'wtmm',
#  'wavelet',
#  'transform',
#  'modulus',
#  'maxima',
#  'point',
#  'wavelet',
#  'transform',
#  'signal',
#  'local',
#  'maxim',
#  'correspond',
#  'time',
#  'locat',
#  'noisi',
#  'machin',
#  'environ',
#  'wavelet',
#  'base',
#  'nois',
#  'method',
#  'includ',
#  'hybrid',
#  'threshold',
#  'function',
#  'level',
#  'depend',
#  'univers',
#  'threshold',
#  'rule',
#  'propos',
#  'dimension',
#  'chatter',
#  'index',
#  'vari',
#  'design',
#  'base',
#  'statist',
#  'analysi',
#  'wtmm',
#  'main',
#  'advantag',
#  'propos',
#  'chatter',
#  'index',
#  'includ',
#  'variat',
#  'rang',
#  'independ',
#  'process',
#  'paramet',
#  'machin',
#  'system',
#  'threshold',
#  'valu',
#  'suscept',
#  'cut',
#  'condit',
#  'chang',
#  'valu',
#  'relat',
#  'term',
#  'result',
#  'chatter',
#  'index',
#  'differ',
#  'machin',
#  'process',
#  'time',
#  'consum',
#  'recalibr',
#  'process',
#  'present',
#  'multipl',
#  'person',
#  'track',
#  'algorithm',
#  'base',
#  'combin',
#  'particl',
#  'filter',
#  'reciproc',
#  'veloc',
#  'obstacl',
#  'agent',
#  'base',
#  'crowd',
#  'model',
#  'infer',
#  'collis',
#  'free',
#  'veloc',
#  'predict',
#  'pedestrian',
#  'motion',
#  'addit',
#  'posit',
#  'veloc',
#  'track',
#  'algorithm',
#  'estim',
#  'intern',
#  'goal',
#  'desir',
#  'destin',
#  'desir',
#  'veloc',
#  'track',
#  'pedestrian',
#  'onlin',
#  'manner',
#  'remov',
#  'need',
#  'specifi',
#  'inform',
#  'furthermor',
#  'leverag',
#  'longer',
#  'term',
#  'predict',
#  'deriv',
#  'higher',
#  'order',
#  'aggreg',
#  'multipl',
#  'predict',
#  'differ',
#  'prior',
#  'time',
#  'step',
#  'yield',
#  'tracker',
#  'recov',
#  'short',
#  'term',
#  'occlus',
#  'spurious',
#  'nois',
#  'appear',
#  'model',
#  'experiment',
#  'result',
#  'track',
#  'algorithm',
#  'suitabl',
#  'predict',
#  'pedestrian',
#  'behavior',
#  'onlin',
#  'need',
#  'scene',
#  'prior',
#  'hand',
#  'annot',
#  'goal',
#  'inform',
#  'improv',
#  'track',
#  'real',
#  'world',
#  'crowd',
#  'scene',
#  'frame',
#  'rat',
#  'extract',
#  'latent',
#  'dimension',
#  'structur',
#  'high',
#  'dimension',
#  'data',
#  'paramount',
#  'import',
#  'time',
#  'infer',
#  'task',
#  'encount',
#  'data',
#  'analyt',
#  'increas',
#  'noisi',
#  'heterogen',
#  'incomplet',
#  'dataset',
#  'need',
#  'real',
#  'time',
#  'process',
#  'stream',
#  'data',
#  'pose',
#  'major',
#  'challeng',
#  'context',
#  'present',
#  'paper',
#  'permeat',
#  'benefit',
#  'rank',
#  'minim',
#  'scalabl',
#  'imput',
#  'miss',
#  'data',
#  'track',
#  'dimension',
#  'subspac',
#  'unravel',
#  'latent',
#  'possibl',
#  'multi',
#  'structur',
#  'incomplet',
#  'stream',
#  'data',
#  'rank',
#  'matrix',
#  'data',
#  'subspac',
#  'estim',
#  'propos',
#  ...]

# %%
for index, score in sorted(lda_model[bow_corpus[11]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.9993623495101929
# Topic: 0.017*"graphen" + 0.011*"wireless" + 0.010*"dielectr" + 0.010*"fault" + 0.008*"waveguid" + 0.007*"capacitor" + 0.007*"transistor" + 0.006*"slot" + 0.006*"nanowir" + 0.006*"torqu"

# %%
for index, score in sorted(lda_model_tfidf[bow_corpus[11]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.508795440196991
# Topic: 0.001*"nanowir" + 0.001*"graphen" + 0.001*"dielectr" + 0.001*"fault" + 0.001*"slot" + 0.001*"wireless" + 0.001*"inductor" + 0.000*"mimo" + 0.000*"capacitor" + 0.000*"cmos"
#
# Score: 0.24771787226200104
# Topic: 0.001*"graphen" + 0.001*"nanocomposit" + 0.001*"copolym" + 0.001*"lignin" + 0.001*"nanosheet" + 0.001*"synapt" + 0.001*"cnts" + 0.001*"nanorod" + 0.001*"zeolit" + 0.001*"nanowir"
#
# Score: 0.11542007327079773
# Topic: 0.001*"mimo" + 0.001*"asymptot" + 0.001*"outag" + 0.001*"beamform" + 0.001*"synapt" + 0.001*"ofdm" + 0.001*"wireless" + 0.001*"secreci" + 0.001*"uplink" + 0.000*"downlink"
#
# Score: 0.054043304175138474
# Topic: 0.001*"tick" + 0.001*"fault" + 0.001*"turbin" + 0.001*"ieee" + 0.001*"lignocellulos" + 0.000*"rotor" + 0.000*"xylos" + 0.000*"phasor" + 0.000*"substat" + 0.000*"bioga"
#
# Score: 0.03317471593618393
# Topic: 0.001*"waveguid" + 0.001*"grate" + 0.000*"interferomet" + 0.000*"coupler" + 0.000*"ofdm" + 0.000*"terahertz" + 0.000*"mem" + 0.000*"wireless" + 0.000*"cmos" + 0.000*"dielectr"
#
# Score: 0.03042285516858101
# Topic: 0.002*"readmiss" + 0.001*"unplan" + 0.001*"wireless" + 0.001*"fault" + 0.001*"packet" + 0.000*"payoff" + 0.000*"breakfast" + 0.000*"cach" + 0.000*"subspac" + 0.000*"wage"
#
# Score: 0.010340625420212746
# Topic: 0.001*"hyperspectr" + 0.001*"radar" + 0.001*"modi" + 0.000*"backscatt" + 0.000*"multispectr" + 0.000*"lidar" + 0.000*"unmix" + 0.000*"albedo" + 0.000*"interferometr" + 0.000*"radiomet"
