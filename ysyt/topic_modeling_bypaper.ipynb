# %%
import re
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os
import math

# %% [markdown]
# **Create dataframe that matches paper abstract with subjects **

# %%
paper_id = []
abstract = []

f = open('aminer_2015.txt','r',encoding = 'utf8')
f.readline()
for i, line in enumerate(f):
        if (i+2) % 250000 == 0:
            print('file '+file+': ',round((i+2)/1000000*100,1),"%")
        json_line = json.loads(line)
        if 'year' in json_line and 'keywords' in json_line and \
        'abstract' in json_line and 'lang' in json_line and \
        'references' in json_line and 'issn' in json_line:
            
            if json_line['lang'] == 'en' :
                
                ## store paper info, later use to get the subject of the paper
                paper_id.append(json_line['id'])
                abstract.append(json_line['abstract'])

                
f.close()

# %%
df= pd.DataFrame()
df['id'] = paper_id
df['abstract'] = abstract
#df.set_index('id')
df.describe()
# Out:
#                               id  \
# count                      95421
# unique                     95421
# top     55323e1245cec66b6f9e1750
# freq                           1
#
#                                                  abstract
# count                                               95421
# unique                                              95413
# top     The 2015 Tandem American Society for Blood and...
# freq                                                    2

# %%
df.head()
# Out:
#                          id                                           abstract
# 0  53e99796b7602d9701f5d979  The pHealth 2015 Conference is the 12th in a s...
# 1  53e99796b7602d9701f613ec  A graphical model is a probability distributio...
# 2  53e9979bb7602d9701f668c8  An inter-governmental body is encouraging the ...
# 3  53e997a2b7602d9701f74d6a  The most important results from the EU-sponsor...
# 4  53e997a2b7602d9701f75614  The Nursing and Midwifery Council is seeking t...

# %%
df.iloc[1,1]
# Out:
# 'A graphical model is a probability distribution associated with a graph with the following properties: (1) the nodes in the graph represent the variables in the model, (2) separation in the graph implies conditional independence of the variables given the separating set, and (3) the probability distribution can be factored according to the graph. Graphical models are useful for researchers because they support efficient computation in models with many variables and provide a visualization of a complex model.'

# %%
subject = pd.read_csv('paper_subject_match.csv',index_col = 'id')

# %%
subject.head()
# Out:
#                           paper_subject
# id
# 53e99784b7602d9701f3e13e           13.0
# 53e99784b7602d9701f3e4f2           13.0
# 53e9978db7602d9701f4f415           13.0
# 53e99792b7602d9701f56a86           27.0
# 53e99792b7602d9701f5b087            NaN

# %%
tm = pd.merge(df, subject, on = ['id'])

# %%
tm.head()
# Out:
#                          id  \
# 0  53e99796b7602d9701f5d979
# 1  53e99796b7602d9701f613ec
# 2  53e9979bb7602d9701f668c8
# 3  53e997a2b7602d9701f74d6a
# 4  53e997a2b7602d9701f75614
#
#                                             abstract  paper_subject
# 0  The pHealth 2015 Conference is the 12th in a s...            NaN
# 1  A graphical model is a probability distributio...            NaN
# 2  An inter-governmental body is encouraging the ...           10.0
# 3  The most important results from the EU-sponsor...            NaN
# 4  The Nursing and Midwifery Council is seeking t...           29.0

# %%
tm.isnull().sum()
# Out:
# id                  0
# abstract            0
# paper_subject    6180
# dtype: int64

# %%
len(tm)
# Out:
# 95421

# %%
tm = tm.dropna()

# %%
tm = tm.drop(columns = ['id'])

# %%
tm['paper_subject'] = tm['paper_subject'].apply(np.int64)

# %% [markdown]
# **Concatenate all abstracts having the same subject(group by subject)**

# %%
tm_all = tm.groupby('paper_subject').agg({'abstract':'-'.join})

# %%
tm_all.reset_index(level=0, inplace=True)

# %%
tm_all.head()
# Out:
#    paper_subject                                           abstract
# 0             10  An inter-governmental body is encouraging the ...
# 1             11  The total variation (TV) regularization method...
# 2             12  Technologies for automated detection of neonat...
# 3             13  Skeletal stem cells (SSCs) reside in the postn...
# 4             14  Despite the extensive application of Monte Car...

# %% [markdown]
# **Processing the abstract:**
# - Tokenization: Split the text into sentences and the sentences into words. Lowercase the words and remove punctuation
# - Words that have fewer than 3 characters are removed
# - All stopwords are removed
# - lemmatized — words in third person to first person, verbs in past and future tenses to present
# - Stemmed — words are reduced to their root form

# %%
#import sys
#!{sys.executable} -m pip install gensim
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2015)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/yihuan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v')) #lemmatize as verb, default is noun

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %% [markdown]
# An example of processing the words in the abstract:

# %%
stemmer = SnowballStemmer('english') #Create a new instance of a language specific subclass
doc_sample = df.iloc[1,1]
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words[:100])
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample[:1000]))
# Out:
# ['A', 'graphical', 'model', 'is', 'a', 'probability', 'distribution', 'associated', 'with', 'a', 'graph', 'with', 'the', 'following', 'properties:', '(1)', 'the', 'nodes', 'in', 'the', 'graph', 'represent', 'the', 'variables', 'in', 'the', 'model,', '(2)', 'separation', 'in', 'the', 'graph', 'implies', 'conditional', 'independence', 'of', 'the', 'variables', 'given', 'the', 'separating', 'set,', 'and', '(3)', 'the', 'probability', 'distribution', 'can', 'be', 'factored', 'according', 'to', 'the', 'graph.', 'Graphical', 'models', 'are', 'useful', 'for', 'researchers', 'because', 'they', 'support', 'efficient', 'computation', 'in', 'models', 'with', 'many', 'variables', 'and', 'provide', 'a', 'visualization', 'of', 'a', 'complex', 'model.']
#
#
#  tokenized and lemmatized document:
# ['graphic', 'model', 'probabl', 'distribut', 'associ', 'graph', 'follow', 'properti', 'nod', 'graph', 'repres', 'variabl', 'model', 'separ', 'graph', 'impli', 'condit', 'independ', 'variabl', 'give', 'separ', 'probabl', 'distribut', 'factor', 'accord', 'graph', 'graphic', 'model', 'use', 'research', 'support', 'effici', 'comput', 'model', 'variabl', 'provid', 'visual', 'complex', 'model']

# %% [markdown]
# The real processing of all the abstract, **takes time!**

# %%
processed_docs = df['abstract'].map(preprocess)

# %%
processed_docs[1] #words processed in Economics, Econometrics and Finance
# Out:
# ['graphic',
#  'model',
#  'probabl',
#  'distribut',
#  'associ',
#  'graph',
#  'follow',
#  'properti',
#  'nod',
#  'graph',
#  'repres',
#  'variabl',
#  'model',
#  'separ',
#  'graph',
#  'impli',
#  'condit',
#  'independ',
#  'variabl',
#  'give',
#  'separ',
#  'probabl',
#  'distribut',
#  'factor',
#  'accord',
#  'graph',
#  'graphic',
#  'model',
#  'use',
#  'research',
#  'support',
#  'effici',
#  'comput',
#  'model',
#  'variabl',
#  'provid',
#  'visual',
#  'complex',
#  'model']

# %%
dictionary = gensim.corpora.Dictionary(processed_docs) 
#Dictionary encapsulates the mapping between normalized words and their integer ids.

# %%
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 30:
        break
# Out:
# 0 academ
# 1 accept
# 2 acknowledg
# 3 activ
# 4 actuat
# 5 adapt
# 6 add
# 7 addit
# 8 address
# 9 administr
# 10 affair
# 11 ahm
# 12 aim
# 13 allow
# 14 analyt
# 15 anim
# 16 app
# 17 applic
# 18 approach
# 19 area
# 20 artifact
# 21 aspect
# 22 assist
# 23 attende
# 24 attract
# 25 author
# 26 autonom
# 27 autonomi
# 28 base
# 29 basic
# 30 benefit

# %%
# dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)
# How should we limit?

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
# for each subject, create a dictionary reporting words and how many times those words appear

# %%
bow_corpus[1] #（id in dict, how many times of appearance
# Out:
# [(8, 4),
#  (10, 6),
#  (11, 184),
#  (13, 2),
#  (14, 172),
#  (15, 12),
#  (17, 20),
#  (21, 11),
#  (23, 10),
#  (25, 42),
#  (26, 6),
#  (28, 35),
#  (29, 105),
#  (30, 154),
#  (32, 9),
#  (34, 17),
#  (35, 1),
#  (38, 1),
#  (39, 7),
#  (41, 86),
#  (42, 52),
#  (43, 13),
#  (44, 214),
#  (45, 4),
#  (47, 20),
#  (48, 16),
#  (49, 36),
#  (50, 200),
#  (51, 154),
#  (56, 86),
#  (57, 338),
#  (58, 330),
#  (62, 14),
#  (67, 17),
#  (68, 1),
#  (71, 1144),
#  (73, 203),
#  (74, 1),
#  (76, 1),
#  (81, 68),
#  (83, 48),
#  (84, 32),
#  (86, 11),
#  (87, 50),
#  (90, 8),
#  (93, 3),
#  (94, 49),
#  (95, 758),
#  (96, 3),
#  (99, 5),
#  (100, 1),
#  (102, 63),
#  (103, 130),
#  (104, 7),
#  (110, 349),
#  (111, 1),
#  (113, 111),
#  (114, 12),
#  (117, 711),
#  (118, 216),
#  (119, 1),
#  (120, 2),
#  (121, 3),
#  (122, 2),
#  (126, 25),
#  (128, 119),
#  (130, 2),
#  (131, 3),
#  (132, 10),
#  (133, 45),
#  (134, 150),
#  (135, 5),
#  (137, 12),
#  (138, 25),
#  (140, 9),
#  (141, 8),
#  (144, 172),
#  (147, 1),
#  (149, 22),
#  (150, 70),
#  (151, 2),
#  (153, 171),
#  (154, 293),
#  (155, 6),
#  (156, 31),
#  (158, 1),
#  (163, 7),
#  (164, 2),
#  (166, 4),
#  (168, 1),
#  (169, 4),
#  (170, 4),
#  (172, 195),
#  (175, 41),
#  (178, 15),
#  (190, 12),
#  (192, 2),
#  (194, 4),
#  (195, 4),
#  (198, 108),
#  (199, 11),
#  (202, 125),
#  (203, 1),
#  (204, 2),
#  (205, 91),
#  (207, 4),
#  (208, 6),
#  (213, 42),
#  (214, 1),
#  (215, 173),
#  (216, 4),
#  (221, 6),
#  (224, 47),
#  (226, 115),
#  (228, 8),
#  (229, 1),
#  (231, 3),
#  (232, 2),
#  (234, 1),
#  (236, 40),
#  (239, 4),
#  (241, 24),
#  (246, 7),
#  (249, 1),
#  (251, 29),
#  (252, 1116),
#  (253, 98),
#  (255, 4),
#  (256, 1),
#  (257, 3),
#  (260, 30),
#  (264, 5),
#  (271, 32),
#  (275, 2),
#  (277, 153),
#  (279, 2),
#  (283, 2),
#  (284, 4),
#  (285, 462),
#  (288, 1),
#  (292, 1),
#  (293, 3),
#  (299, 52),
#  (300, 199),
#  (303, 7),
#  (304, 1),
#  (308, 36),
#  (310, 2),
#  (311, 1),
#  (313, 1),
#  (315, 40),
#  (316, 32),
#  (320, 1),
#  (321, 6),
#  (322, 3),
#  (324, 2),
#  (325, 9),
#  (326, 15),
#  (327, 32),
#  (328, 3),
#  (330, 2),
#  (333, 1),
#  (335, 7),
#  (340, 57),
#  (341, 26),
#  (342, 6),
#  (350, 17),
#  (354, 4),
#  (356, 25),
#  (357, 197),
#  (358, 146),
#  (364, 7),
#  (368, 1),
#  (370, 1),
#  (372, 105),
#  (373, 28),
#  (374, 208),
#  (375, 976),
#  (376, 354),
#  (377, 453),
#  (381, 14),
#  (382, 1),
#  (387, 32),
#  (388, 2),
#  (390, 1),
#  (394, 1),
#  (396, 3),
#  (397, 2),
#  (402, 1),
#  (404, 3),
#  (405, 3),
#  (406, 2),
#  (410, 260),
#  (412, 59),
#  (416, 22),
#  (417, 14),
#  (421, 46),
#  (422, 45),
#  (423, 5),
#  (424, 42),
#  (426, 6),
#  (428, 3),
#  (430, 94),
#  (433, 19),
#  (434, 8),
#  (438, 1),
#  (440, 6),
#  (442, 2),
#  (443, 1),
#  (447, 1783),
#  (448, 2),
#  (450, 4),
#  (454, 1),
#  (455, 58),
#  (459, 1),
#  (460, 53),
#  (461, 18),
#  (462, 42),
#  (463, 16),
#  (465, 13),
#  (474, 2),
#  (475, 23),
#  (477, 32),
#  (480, 14),
#  (481, 7),
#  (483, 5),
#  (487, 7),
#  (490, 2),
#  (491, 8),
#  (493, 1),
#  (495, 3),
#  (498, 1),
#  (499, 16),
#  (500, 18),
#  (504, 135),
#  (506, 5),
#  (510, 3),
#  (514, 1),
#  (520, 1),
#  (521, 1),
#  (527, 16),
#  (528, 6),
#  (529, 29),
#  (530, 7),
#  (531, 14),
#  (532, 76),
#  (533, 1),
#  (536, 628),
#  (537, 1393),
#  (541, 1),
#  (542, 2),
#  (543, 6),
#  (544, 1066),
#  (545, 128),
#  (546, 11),
#  (547, 283),
#  (549, 4),
#  (550, 2),
#  (552, 4),
#  (553, 39),
#  (555, 1),
#  (557, 2),
#  (559, 4),
#  (560, 84),
#  (561, 17),
#  (562, 1),
#  (566, 2),
#  (568, 1),
#  (571, 1),
#  (572, 242),
#  (575, 1),
#  (577, 454),
#  (578, 1),
#  (579, 1),
#  (581, 3),
#  (582, 3),
#  (583, 8),
#  (585, 54),
#  (588, 25),
#  (592, 10),
#  (594, 2),
#  (595, 87),
#  (596, 815),
#  (597, 10),
#  (599, 6),
#  (601, 1),
#  (603, 52),
#  (606, 3),
#  (609, 23),
#  (617, 57),
#  (618, 7),
#  (619, 5),
#  (621, 20),
#  (622, 91),
#  (628, 1),
#  (632, 1),
#  (633, 5),
#  (636, 7),
#  (637, 7),
#  (639, 1),
#  (642, 3),
#  (643, 4),
#  (647, 2),
#  (648, 102),
#  (652, 2),
#  (654, 83),
#  (655, 275),
#  (657, 2),
#  (658, 185),
#  (659, 47),
#  (661, 112),
#  (662, 208),
#  (664, 106),
#  (665, 81),
#  (667, 1),
#  (669, 2),
#  (670, 2),
#  (674, 95),
#  (675, 12),
#  (677, 35),
#  (680, 3),
#  (682, 6),
#  (683, 3),
#  (687, 3),
#  (689, 31),
#  (691, 179),
#  (692, 14),
#  (699, 1),
#  (700, 84),
#  (701, 100),
#  (702, 46),
#  (703, 24),
#  (705, 86),
#  (706, 69),
#  (707, 1),
#  (708, 25),
#  (709, 118),
#  (711, 98),
#  (715, 12),
#  (716, 5),
#  (717, 30),
#  (720, 22),
#  (725, 1),
#  (726, 3),
#  (728, 41),
#  (730, 111),
#  (734, 12),
#  (738, 1),
#  (741, 4),
#  (742, 50),
#  (743, 86),
#  (744, 2),
#  (745, 40),
#  (751, 4),
#  (755, 44),
#  (757, 200),
#  (759, 7),
#  (760, 346),
#  (762, 2),
#  (764, 2),
#  (765, 149),
#  (767, 34),
#  (768, 11),
#  (769, 16),
#  (770, 85),
#  (771, 106),
#  (773, 7),
#  (775, 7),
#  (779, 4),
#  (785, 3),
#  (786, 5),
#  (788, 83),
#  (789, 22),
#  (791, 59),
#  (792, 49),
#  (793, 10),
#  (794, 2),
#  (795, 1),
#  (796, 5),
#  (806, 2),
#  (809, 171),
#  (810, 1),
#  (817, 824),
#  (818, 569),
#  (820, 7),
#  (824, 28),
#  (825, 29),
#  (833, 1),
#  (834, 103),
#  (835, 7),
#  (837, 2695),
#  (838, 10),
#  (840, 169),
#  (841, 78),
#  (842, 1),
#  (847, 18),
#  (849, 1),
#  (851, 235),
#  (852, 1),
#  (853, 5),
#  (854, 28),
#  (862, 1),
#  (863, 281),
#  (864, 118),
#  (865, 58),
#  (866, 10),
#  (873, 9),
#  (875, 22),
#  (876, 13),
#  (877, 381),
#  (878, 62),
#  (880, 1),
#  (882, 11),
#  (883, 24),
#  (884, 11),
#  (887, 46),
#  (888, 79),
#  (889, 2),
#  (890, 40),
#  (892, 136),
#  (894, 8),
#  (898, 1),
#  (900, 3),
#  (904, 112),
#  (906, 7),
#  (908, 276),
#  (915, 205),
#  (918, 61),
#  (921, 5),
#  (922, 2),
#  (926, 16),
#  (928, 48),
#  (931, 1),
#  (932, 3),
#  (933, 7),
#  (934, 1),
#  (936, 82),
#  (937, 1),
#  (938, 213),
#  (940, 69),
#  (941, 3),
#  (942, 2),
#  (943, 5),
#  (945, 14),
#  (946, 4),
#  (947, 44),
#  (950, 41),
#  (951, 13),
#  (957, 28),
#  (958, 3),
#  (960, 9),
#  (961, 1),
#  (971, 197),
#  (973, 3),
#  (975, 14),
#  (976, 6),
#  (977, 46),
#  (978, 11),
#  (979, 95),
#  (981, 25),
#  (982, 1),
#  (983, 23),
#  (984, 6),
#  (985, 7),
#  (986, 2),
#  (988, 6),
#  (989, 5),
#  (990, 1),
#  (991, 19),
#  (992, 50),
#  (999, 2),
#  (1000, 12),
#  (1001, 6),
#  (1002, 1),
#  (1003, 7),
#  (1005, 5),
#  (1007, 4),
#  (1009, 47),
#  (1937, 56),
#  (1938, 3),
#  (1940, 1),
#  (1941, 1),
#  (1943, 3),
#  (1944, 212),
#  (1945, 11),
#  (1946, 35),
#  (1948, 21),
#  (1949, 4),
#  (1950, 7),
#  (1953, 18),
#  (1954, 153),
#  (1955, 172),
#  (1956, 2),
#  (1957, 2347),
#  (1958, 5),
#  (1961, 19),
#  (1962, 38),
#  (1963, 561),
#  (1964, 144),
#  (1965, 210),
#  (1966, 1011),
#  (1967, 76),
#  (1968, 3),
#  (1969, 3),
#  (1970, 3),
#  (1971, 7),
#  (1973, 4),
#  (1974, 61),
#  (1975, 144),
#  (1976, 99),
#  (1979, 14),
#  (1982, 11),
#  (1983, 1),
#  (1984, 1),
#  (1985, 95),
#  (1987, 1),
#  (1988, 1),
#  (1989, 9),
#  (1990, 339),
#  (1999, 11),
#  (2001, 1),
#  (2002, 35),
#  (2003, 7),
#  (2005, 1),
#  (2006, 2),
#  (2007, 191),
#  (2008, 222),
#  (2009, 213),
#  (2010, 15),
#  (2011, 85),
#  (2012, 13),
#  (2015, 6),
#  (2016, 13),
#  (2019, 1),
#  (2026, 1),
#  (2027, 1),
#  (2029, 483),
#  (2030, 4),
#  (2036, 4),
#  (2038, 6),
#  (2039, 7),
#  (2042, 33),
#  (2043, 19),
#  (2044, 3),
#  (2047, 5),
#  (2048, 56),
#  ...]

# %%
# bag of words example in Economics, Econometrics and Finance
bow_doc_1 = bow_corpus[1]

for i in range(len(bow_doc_1)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_1[i][0], 
                                                     dictionary[bow_doc_1[i][0]], 
                                                     bow_doc_1[i][1]))
# Out:
# Word 110 ("follow") appears 1 time.
# Word 117 ("give") appears 1 time.
# Word 144 ("independ") appears 1 time.
# Word 186 ("model") appears 5 time.
# Word 246 ("provid") appears 1 time.
# Word 258 ("repres") appears 1 time.
# Word 260 ("research") appears 1 time.
# Word 294 ("support") appears 1 time.
# Word 328 ("accord") appears 1 time.
# Word 329 ("associ") appears 1 time.
# Word 330 ("complex") appears 1 time.
# Word 331 ("comput") appears 1 time.
# Word 332 ("condit") appears 1 time.
# Word 333 ("distribut") appears 2 time.
# Word 334 ("effici") appears 1 time.
# Word 335 ("factor") appears 1 time.
# Word 336 ("graph") appears 4 time.
# Word 337 ("graphic") appears 2 time.
# Word 338 ("impli") appears 1 time.
# Word 339 ("nod") appears 1 time.
# Word 340 ("probabl") appears 2 time.
# Word 341 ("properti") appears 1 time.
# Word 342 ("separ") appears 2 time.
# Word 343 ("use") appears 1 time.
# Word 344 ("variabl") appears 3 time.
# Word 345 ("visual") appears 1 time.

# %% [markdown]
# TF-IDF method

# %%
from gensim import corpora, models

tfidf = models.TfidfModel(bow_corpus)

# %%
corpus_tfidf = tfidf[bow_corpus]

# %%
from pprint import pprint

for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.01942468004371076),
#  (1, 0.030999255857770868),
#  (2, 0.023715142168980616),
#  (3, 0.018587680457326106),
#  (4, 0.024656993243389585),
#  (5, 0.013213920397690388),
#  (6, 0.01607170054937349),
#  (7, 0.007648930221198545),
#  (8, 0.03877588177016929),
#  (9, 0.027893912046377388),
#  (10, 0.02780741317110187),
#  (11, 0.03764608407701659),
#  (12, 0.010942724786037675),
#  (297, 0.047943818330988285),
#  (298, 0.08085206045105867),
#  (299, 0.01923205024064881),
#  (300, 0.01073276264136123),
#  (301, 0.12259481182212066),
#  (302, 0.03172679195496683),
#  (303, 0.009604402265756633),
#  (304, 0.029565084761606766),
#  (305, 0.05126271343097087),
#  (306, 0.006329095503989056),
#  (307, 0.03638860385706327),
#  (308, 0.014513139073797577),
#  (309, 0.014777101185595113),
#  (310, 0.016326996801618407),
#  (311, 0.027516360096518016),
#  (312, 0.0218476651720919),
#  (313, 0.04320597637404208),
#  (314, 0.009407451008415314),
#  (315, 0.014953326289783913),
#  (316, 0.009708519286549235),
#  (317, 0.030630717736742606),
#  (318, 0.07024995411726452),
#  (319, 0.019593515631901058),
#  (320, 0.014196823161693607),
#  (321, 0.045985922522554824),
#  (322, 0.02826365620876506),
#  (323, 0.026312756259798443),
#  (324, 0.011154780310498318),
#  (325, 0.01049163264267364),
#  (326, 0.025944030405892375),
#  (327, 0.03084442406074235)]

# %% [markdown]
# Running LDA using Bag of Words

# %%
lda_model = gensim.models.LdaMulticore(bow_corpus, num_topics=10, id2word=dictionary, passes=2, workers=2)

# %%
for idx, topic in lda_model.print_topics(-1):
    print('Topic: {} \nWords: {}'.format(idx, topic))
# Out:
# Topic: 0
# Words: 0.052*"patient" + 0.010*"studi" + 0.010*"group" + 0.009*"year" + 0.009*"signific" + 0.008*"case" + 0.008*"treatment" + 0.008*"clinic" + 0.007*"associ" + 0.007*"follow"
# Topic: 1
# Words: 0.015*"method" + 0.015*"imag" + 0.011*"measur" + 0.010*"model" + 0.010*"time" + 0.008*"result" + 0.007*"base" + 0.007*"data" + 0.007*"perform" + 0.007*"propos"
# Topic: 2
# Words: 0.014*"studi" + 0.014*"health" + 0.010*"risk" + 0.009*"care" + 0.008*"associ" + 0.008*"patient" + 0.006*"data" + 0.006*"year" + 0.006*"women" + 0.006*"report"
# Topic: 3
# Words: 0.017*"speci" + 0.009*"differ" + 0.008*"sampl" + 0.008*"studi" + 0.008*"model" + 0.008*"popul" + 0.008*"data" + 0.006*"plant" + 0.006*"method" + 0.006*"genet"
# Topic: 4
# Words: 0.015*"activ" + 0.014*"level" + 0.013*"increas" + 0.012*"induc" + 0.011*"effect" + 0.009*"express" + 0.008*"signific" + 0.008*"studi" + 0.008*"mice" + 0.006*"associ"
# Topic: 5
# Words: 0.038*"cell" + 0.017*"gene" + 0.016*"express" + 0.010*"protein" + 0.009*"cancer" + 0.007*"studi" + 0.007*"regul" + 0.006*"tumor" + 0.006*"human" + 0.006*"activ"
# Topic: 6
# Words: 0.014*"acid" + 0.013*"activ" + 0.010*"protein" + 0.009*"product" + 0.009*"compound" + 0.009*"concentr" + 0.009*"studi" + 0.007*"show" + 0.006*"effect" + 0.006*"high"
# Topic: 7
# Words: 0.021*"group" + 0.013*"studi" + 0.011*"treatment" + 0.011*"signific" + 0.010*"effect" + 0.010*"dose" + 0.009*"infect" + 0.009*"control" + 0.009*"week" + 0.009*"test"
# Topic: 8
# Words: 0.010*"children" + 0.010*"studi" + 0.009*"food" + 0.008*"differ" + 0.006*"relat" + 0.006*"obes" + 0.006*"behavior" + 0.006*"effect" + 0.006*"task" + 0.006*"particip"
# Topic: 9
# Words: 0.008*"structur" + 0.007*"high" + 0.007*"surfac" + 0.006*"base" + 0.006*"result" + 0.005*"method" + 0.005*"applic" + 0.005*"optic" + 0.005*"properti" + 0.004*"materi"

# %% [markdown]
# Running LDA using TF-IDF

# %%
lda_model_tfidf = gensim.models.LdaMulticore(corpus_tfidf, num_topics=10, id2word=dictionary, passes=2, workers=4)

# %%
for idx, topic in lda_model_tfidf.print_topics(-1):
    print('Topic: {} Word: {}'.format(idx, topic))
# Out:
# Topic: 0 Word: 0.003*"compound" + 0.003*"acid" + 0.003*"protein" + 0.003*"cell" + 0.003*"activ" + 0.003*"structur" + 0.003*"surfac" + 0.002*"temperatur" + 0.002*"plant" + 0.002*"product"
# Topic: 1 Word: 0.005*"patient" + 0.004*"cell" + 0.003*"group" + 0.003*"associ" + 0.003*"cancer" + 0.003*"express" + 0.002*"diseas" + 0.002*"risk" + 0.002*"treatment" + 0.002*"gene"
# Topic: 2 Word: 0.003*"dialysi" + 0.003*"hydrogel" + 0.003*"rcts" + 0.003*"hypox" + 0.003*"sirt" + 0.002*"phage" + 0.002*"claudin" + 0.002*"pufa" + 0.002*"periton" + 0.002*"gondii"
# Topic: 3 Word: 0.005*"pylori" + 0.004*"leptin" + 0.003*"endometri" + 0.003*"screw" + 0.003*"toxin" + 0.002*"tdcs" + 0.002*"aborigin" + 0.002*"beverag" + 0.002*"literaci" + 0.002*"glioblastoma"
# Topic: 4 Word: 0.006*"resect" + 0.006*"tumour" + 0.005*"colon" + 0.005*"pancreat" + 0.005*"surgic" + 0.004*"nerv" + 0.004*"epilepsi" + 0.004*"spinal" + 0.004*"cord" + 0.004*"obes"
# Topic: 5 Word: 0.006*"obes" + 0.006*"nurs" + 0.005*"intak" + 0.004*"dietari" + 0.003*"eat" + 0.003*"propos" + 0.002*"tobacco" + 0.002*"staff" + 0.002*"algorithm" + 0.002*"energi"
# Topic: 6 Word: 0.008*"gastric" + 0.005*"laparoscop" + 0.004*"senesc" + 0.004*"allergen" + 0.003*"immunotherapi" + 0.003*"nasal" + 0.003*"lumbar" + 0.003*"nicotin" + 0.003*"olfactori" + 0.003*"biofilm"
# Topic: 7 Word: 0.006*"milk" + 0.004*"injuri" + 0.003*"copd" + 0.003*"pig" + 0.003*"ptsd" + 0.003*"athlet" + 0.003*"ischemia" + 0.002*"ankl" + 0.002*"reperfus" + 0.002*"power"
# Topic: 8 Word: 0.013*"pain" + 0.006*"postop" + 0.006*"caregiv" + 0.005*"preoper" + 0.005*"injuri" + 0.005*"trauma" + 0.005*"aortic" + 0.005*"drink" + 0.004*"surgic" + 0.003*"autophagi"
# Topic: 9 Word: 0.007*"sexual" + 0.005*"stent" + 0.004*"schizophrenia" + 0.004*"violenc" + 0.003*"psychiatr" + 0.003*"cathet" + 0.003*"stenosi" + 0.003*"depress" + 0.003*"youth" + 0.003*"palliat"

# %% [markdown]
# Classify sample document using LDA Bag of Words model

# %%
processed_docs[1]
# Out:
# ['graphic',
#  'model',
#  'probabl',
#  'distribut',
#  'associ',
#  'graph',
#  'follow',
#  'properti',
#  'nod',
#  'graph',
#  'repres',
#  'variabl',
#  'model',
#  'separ',
#  'graph',
#  'impli',
#  'condit',
#  'independ',
#  'variabl',
#  'give',
#  'separ',
#  'probabl',
#  'distribut',
#  'factor',
#  'accord',
#  'graph',
#  'graphic',
#  'model',
#  'use',
#  'research',
#  'support',
#  'effici',
#  'comput',
#  'model',
#  'variabl',
#  'provid',
#  'visual',
#  'complex',
#  'model']

# %%
for index, score in sorted(lda_model[bow_corpus[1]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.6990560293197632
# Topic: 0.015*"method" + 0.015*"imag" + 0.011*"measur" + 0.010*"model" + 0.010*"time" + 0.008*"result" + 0.007*"base" + 0.007*"data" + 0.007*"perform" + 0.007*"propos"
#
# Score: 0.28093457221984863
# Topic: 0.017*"speci" + 0.009*"differ" + 0.008*"sampl" + 0.008*"studi" + 0.008*"model" + 0.008*"popul" + 0.008*"data" + 0.006*"plant" + 0.006*"method" + 0.006*"genet"

# %%
for index, score in sorted(lda_model_tfidf[bow_corpus[1]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.9774827361106873
# Topic: 0.005*"patient" + 0.004*"cell" + 0.003*"group" + 0.003*"associ" + 0.003*"cancer" + 0.003*"express" + 0.002*"diseas" + 0.002*"risk" + 0.002*"treatment" + 0.002*"gene"

# %% [markdown]
# Try to estimate for subjects

# %%
processed_subject = tm_all['abstract'].map(preprocess)

# %%
processed_subject[11] #words processed in Economics, Econometrics and Finance
# Out:
# ['consid',
#  'problem',
#  'estim',
#  'local',
#  'sensor',
#  'paramet',
#  'local',
#  'paramet',
#  'sensor',
#  'observ',
#  'relat',
#  'linear',
#  'stochast',
#  'model',
#  'studi',
#  'gaussian',
#  'product',
#  'algorithm',
#  'wireless',
#  'network',
#  'gspawn',
#  'procedur',
#  'compar',
#  'popular',
#  'diffus',
#  'strategi',
#  'perform',
#  'network',
#  'paramet',
#  'estim',
#  'communic',
#  'cost',
#  'sensor',
#  'increas',
#  'increas',
#  'network',
#  'densiti',
#  'gspawn',
#  'allow',
#  'sensor',
#  'broadcast',
#  'messag',
#  'size',
#  'depend',
#  'network',
#  'size',
#  'densiti',
#  'make',
#  'suitabl',
#  'applic',
#  'wireless',
#  'sensor',
#  'network',
#  'gspawn',
#  'converg',
#  'mean',
#  'mean',
#  'squar',
#  'stabil',
#  'technic',
#  'suffici',
#  'condit',
#  'applic',
#  'gspawn',
#  'network',
#  'local',
#  'problem',
#  'line',
#  'sight',
#  'environ',
#  'numer',
#  'result',
#  'suggest',
#  'gspawn',
#  'converg',
#  'faster',
#  'general',
#  'diffus',
#  'method',
#  'lower',
#  'communic',
#  'cost',
#  'sensor',
#  'compar',
#  'root',
#  'mean',
#  'squar',
#  'error',
#  'express',
#  'clone',
#  'play',
#  'import',
#  'role',
#  'facial',
#  'express',
#  'synthesi',
#  'paper',
#  'novel',
#  'algorithm',
#  'propos',
#  'facial',
#  'express',
#  'clone',
#  'propos',
#  'algorithm',
#  'introduc',
#  'elast',
#  'model',
#  'balanc',
#  'global',
#  'local',
#  'warp',
#  'effect',
#  'impact',
#  'facial',
#  'featur',
#  'divers',
#  'peopl',
#  'minim',
#  'effect',
#  'geometr',
#  'warp',
#  'result',
#  'achiev',
#  'furthermor',
#  'muscl',
#  'distribut',
#  'base',
#  'model',
#  'propos',
#  'util',
#  'muscl',
#  'distribut',
#  'human',
#  'face',
#  'result',
#  'accur',
#  'facial',
#  'illumin',
#  'detail',
#  'addit',
#  'propos',
#  'distanc',
#  'base',
#  'metric',
#  'automat',
#  'select',
#  'optim',
#  'paramet',
#  'global',
#  'local',
#  'warp',
#  'effect',
#  'elast',
#  'model',
#  'suitabl',
#  'balanc',
#  'experiment',
#  'result',
#  'propos',
#  'algorithm',
#  'outperform',
#  'exist',
#  'method',
#  'elsevi',
#  'right',
#  'reserv',
#  'paper',
#  'consid',
#  'wireless',
#  'power',
#  'cooper',
#  'communic',
#  'network',
#  'consist',
#  'hybrid',
#  'access',
#  'point',
#  'sourc',
#  'relay',
#  'contrast',
#  'convent',
#  'cooper',
#  'network',
#  'sourc',
#  'relay',
#  'consid',
#  'network',
#  'emb',
#  'energi',
#  'suppli',
#  'need',
#  'reli',
#  'energi',
#  'harvest',
#  'signal',
#  'broadcast',
#  'cooper',
#  'inform',
#  'transmiss',
#  'base',
#  'node',
#  'refer',
#  'model',
#  'propos',
#  'harvest',
#  'cooper',
#  'protocol',
#  'sourc',
#  'relay',
#  'harvest',
#  'energi',
#  'downlink',
#  'work',
#  'cooper',
#  'uplink',
#  'sourc',
#  'inform',
#  'transmiss',
#  'consid',
#  'delay',
#  'limit',
#  'transmiss',
#  'mode',
#  'approxim',
#  'close',
#  'form',
#  'express',
#  'averag',
#  'throughput',
#  'propos',
#  'protocol',
#  'deriv',
#  'rayleigh',
#  'fade',
#  'channel',
#  'subsequ',
#  'analysi',
#  'extend',
#  'multi',
#  'relay',
#  'scenario',
#  'approxim',
#  'throughput',
#  'protocol',
#  'popular',
#  'relay',
#  'select',
#  'scheme',
#  'deriv',
#  'asymptot',
#  'analys',
#  'throughput',
#  'perform',
#  'consid',
#  'scheme',
#  'high',
#  'signal',
#  'nois',
#  'radio',
#  'provid',
#  'theoret',
#  'result',
#  'valid',
#  'numer',
#  'simul',
#  'impact',
#  'paramet',
#  'time',
#  'alloc',
#  'relay',
#  'number',
#  'relay',
#  'posit',
#  'throughput',
#  'perform',
#  'extens',
#  'investig',
#  'paper',
#  'propos',
#  'crowdsourc',
#  'base',
#  'framework',
#  'myopic',
#  'target',
#  'track',
#  'design',
#  'optim',
#  'incent',
#  'compat',
#  'mechan',
#  'wireless',
#  'sensor',
#  'network',
#  'contain',
#  'sensor',
#  'selfish',
#  'profit',
#  'motiv',
#  'typic',
#  'wsns',
#  'limit',
#  'bandwidth',
#  'fusion',
#  'center',
#  'distribut',
#  'total',
#  'number',
#  'bit',
#  'transmit',
#  'sensor',
#  'sensor',
#  'formul',
#  'consid',
#  'conduct',
#  'auction',
#  'solicit',
#  'bid',
#  'selfish',
#  'sensor',
#  'reflect',
#  'valu',
#  'energi',
#  'cost',
#  'furthermor',
#  'ration',
#  'truth',
#  'sensor',
#  'guarante',
#  'model',
#  'final',
#  'problem',
#  'formul',
#  'multipl',
#  'choic',
#  'knapsack',
#  'problem',
#  'mckp',
#  'solv',
#  'dynam',
#  'program',
#  'method',
#  'pseudo',
#  'polynomi',
#  'time',
#  'simul',
#  'result',
#  'effect',
#  'propos',
#  'approach',
#  'term',
#  'track',
#  'perform',
#  'lifetim',
#  'sensor',
#  'network',
#  'present',
#  'joint',
#  'channel',
#  'power',
#  'alloc',
#  'framework',
#  'downlink',
#  'transmiss',
#  'orthogon',
#  'frequenc',
#  'divis',
#  'multipl',
#  'access',
#  'ofdma',
#  'base',
#  'cellular',
#  'network',
#  'compos',
#  'macrocel',
#  'overlay',
#  'small',
#  'cell',
#  'framework',
#  'resourc',
#  'alloc',
#  'problem',
#  'macrocel',
#  'small',
#  'cell',
#  'formul',
#  'optim',
#  'problem',
#  'macrocel',
#  'formul',
#  'problem',
#  'awar',
#  'exist',
#  'small',
#  'cell',
#  'tier',
#  'problem',
#  'macrocel',
#  'perform',
#  'satisfi',
#  'data',
#  'rate',
#  'requir',
#  'macro',
#  'user',
#  'equip',
#  'mue',
#  'maxim',
#  'toler',
#  'interfer',
#  'small',
#  'cell',
#  'tier',
#  'alloc',
#  'channel',
#  'problem',
#  'macrocel',
#  'show',
#  'mix',
#  'integ',
#  'nonlinear',
#  'problem',
#  'minlp',
#  'prove',
#  'macrocel',
#  'solv',
#  'altern',
#  'optim',
#  'problem',
#  'yield',
#  'optim',
#  'solut',
#  'reduc',
#  'complex',
#  'small',
#  'cell',
#  'follow',
#  'idea',
#  'tier',
#  'awar',
#  'formul',
#  'optim',
#  'problem',
#  'account',
#  'admiss',
#  'control',
#  'aim',
#  'maxim',
#  'number',
#  'admit',
#  'user',
#  'simultan',
#  'minim',
#  'consum',
#  'bandwidth',
#  'similar',
#  'macrocel',
#  'optim',
#  'problem',
#  'small',
#  'cell',
#  'problem',
#  'show',
#  'minlp',
#  'obtain',
#  'optim',
#  'solut',
#  'minlp',
#  'problem',
#  'reli',
#  'convex',
#  'relax',
#  'addit',
#  'employ',
#  'dual',
#  'decomposit',
#  'techniqu',
#  'distribut',
#  'solut',
#  'small',
#  'cell',
#  'tier',
#  'numer',
#  'result',
#  'confirm',
#  'perform',
#  'gain',
#  'propos',
#  'formul',
#  'macrocel',
#  'tradit',
#  'resourc',
#  'alloc',
#  'base',
#  'minim',
#  'transmiss',
#  'power',
#  'show',
#  'formul',
#  'base',
#  'convex',
#  'relax',
#  'yield',
#  'similar',
#  'behavior',
#  'minlp',
#  'formul',
#  'distribut',
#  'solut',
#  'converg',
#  'solut',
#  'obtain',
#  'solv',
#  'correspond',
#  'convex',
#  'optim',
#  'problem',
#  'central',
#  'fashion',
#  'cellular',
#  'network',
#  'model',
#  'base',
#  'station',
#  'usual',
#  'assum',
#  'form',
#  'lattic',
#  'poisson',
#  'point',
#  'process',
#  'realiti',
#  'deploy',
#  'fulli',
#  'regular',
#  'complet',
#  'random',
#  'accord',
#  'paper',
#  'consid',
#  'general',
#  'class',
#  'motion',
#  'invari',
#  'model',
#  'analyz',
#  'behavior',
#  'outag',
#  'probabl',
#  'probabl',
#  'signal',
#  'interfer',
#  'plus',
#  'nois',
#  'ratio',
#  'sinr',
#  'smaller',
#  'threshold',
#  'threshold',
#  'go',
#  'zero',
#  'remark',
#  'slope',
#  'outag',
#  'probabl',
#  'function',
#  'threshold',
#  'essenti',
#  'motion',
#  'invari',
#  'point',
#  'process',
#  'slope',
#  'mere',
#  'depend',
#  'fade',
#  'statist',
#  'result',
#  'introduc',
#  'notion',
#  'asymptot',
#  'deploy',
#  'gain',
#  'character',
#  'horizont',
#  'success',
#  'probabl',
#  'point',
#  'process',
#  'high',
#  'reliabl',
#  'regim',
#  'success',
#  'probabl',
#  'near',
#  'demonstr',
#  'use',
#  'sinr',
#  'distribut',
#  'investig',
#  'outag',
#  'probabl',
#  'adg',
#  'differ',
#  'point',
#  'process',
#  'fade',
#  'statist',
#  'simul',
#  'molecular',
#  'communic',
#  'network',
#  'realis',
#  'communic',
#  'nanoscal',
#  'devic',
#  'molecular',
#  'communic',
#  'network',
#  'transmitt',
#  'receiv',
#  'communic',
#  'signal',
#  'molecul',
#  'receiv',
#  'signal',
#  'molecul',
#  'react',
#  'chain',
#  'chemic',
#  'reaction',
#  'produc',
#  'output',
#  'molecul',
#  'count',
#  'output',
#  'molecul',
#  'time',
#  'output',
#  'signal',
#  'receiv',
#  'output',
#  'signal',
#  'noisi',
#  'stochast',
#  'natur',
#  'diffus',
#  'chemic',
#  'reaction',
#  'paper',
#  'aim',
#  'characteris',
#  'properti',
#  'output',
#  'signal',
#  'model',
#  'transmiss',
#  'medium',
#  'transmitt',
#  'receiv',
#  'order',
#  'simplifi',
#  'analysi',
#  'model',
#  'transmitt',
#  'sequenc',
#  'specifi',
#  'number',
#  'molecul',
#  'emit',
#  'transmitt',
#  'time',
#  'paper',
#  'consid',
#  'receiv',
#  'reaction',
#  'mechan',
#  'revers',
#  'convers',
#  'linear',
#  'catalyt',
#  'approxim',
#  'respect',
#  'ligand',
#  'receptor',
#  'bind',
#  'enzymat',
#  'reaction',
#  'mechan',
#  'choos',
#  'consid',
#  'transmitt',
#  'diffus',
#  'ordinari',
#  'differenti',
#  'equat',
#  'describ',
#  'mean',
#  'behaviour',
#  'reaction',
#  'mechan',
#  'form',
#  'consid',
#  'behaviour',
#  'transmitt',
#  'signal',
#  'mean',
#  'varianc',
#  'number',
#  'output',
#  'molecul',
#  'receiv',
#  'reaction',
#  'mechan',
#  'differ',
#  'behaviour',
#  'deriv',
#  'analyt',
#  'express',
#  'mean',
#  'varianc',
#  'frequenc',
#  'properti',
#  'number',
#  'output',
#  'molecul',
#  'receiv',
#  'reaction',
#  'mechan',
#  'addit',
#  'revers',
#  'convers',
#  'abl',
#  'deriv',
#  'exact',
#  'probabl',
#  'distribut',
#  'number',
#  'output',
#  'molecul',
#  'model',
#  'allow',
#  'studi',
#  'impact',
#  'design',
#  'paramet',
#  'communic',
#  'perform',
#  'exampl',
#  'assum',
#  'receiv',
#  'enclos',
#  'membran',
#  'studi',
#  'impact',
#  'diffus',
#  'molecul',
#  'membran',
#  'communic',
#  'rformanc',
#  'paper',
#  'present',
#  'statist',
#  'chatter',
#  'detect',
#  'method',
#  'methodolog',
#  'base',
#  'studi',
#  'discret',
#  'wavelet',
#  'transform',
#  'scheme',
#  'statist',
#  'analysi',
#  'wavelet',
#  'transform',
#  'modulus',
#  'maxima',
#  'wtmm',
#  'wavelet',
#  'transform',
#  'modulus',
#  'maxima',
#  'point',
#  'wavelet',
#  'transform',
#  'signal',
#  'local',
#  'maxim',
#  'correspond',
#  'time',
#  'locat',
#  'noisi',
#  'machin',
#  'environ',
#  'wavelet',
#  'base',
#  'nois',
#  'method',
#  'includ',
#  'hybrid',
#  'threshold',
#  'function',
#  'level',
#  'depend',
#  'univers',
#  'threshold',
#  'rule',
#  'propos',
#  'dimension',
#  'chatter',
#  'index',
#  'vari',
#  'design',
#  'base',
#  'statist',
#  'analysi',
#  'wtmm',
#  'main',
#  'advantag',
#  'propos',
#  'chatter',
#  'index',
#  'includ',
#  'variat',
#  'rang',
#  'independ',
#  'process',
#  'paramet',
#  'machin',
#  'system',
#  'threshold',
#  'valu',
#  'suscept',
#  'cut',
#  'condit',
#  'chang',
#  'valu',
#  'relat',
#  'term',
#  'result',
#  'chatter',
#  'index',
#  'differ',
#  'machin',
#  'process',
#  'time',
#  'consum',
#  'recalibr',
#  'process',
#  'present',
#  'multipl',
#  'person',
#  'track',
#  'algorithm',
#  'base',
#  'combin',
#  'particl',
#  'filter',
#  'reciproc',
#  'veloc',
#  'obstacl',
#  'agent',
#  'base',
#  'crowd',
#  'model',
#  'infer',
#  'collis',
#  'free',
#  'veloc',
#  'predict',
#  'pedestrian',
#  'motion',
#  'addit',
#  'posit',
#  'veloc',
#  'track',
#  'algorithm',
#  'estim',
#  'intern',
#  'goal',
#  'desir',
#  'destin',
#  'desir',
#  'veloc',
#  'track',
#  'pedestrian',
#  'onlin',
#  'manner',
#  'remov',
#  'need',
#  'specifi',
#  'inform',
#  'furthermor',
#  'leverag',
#  'longer',
#  'term',
#  'predict',
#  'deriv',
#  'higher',
#  'order',
#  'aggreg',
#  'multipl',
#  'predict',
#  'differ',
#  'prior',
#  'time',
#  'step',
#  'yield',
#  'tracker',
#  'recov',
#  'short',
#  'term',
#  'occlus',
#  'spurious',
#  'nois',
#  'appear',
#  'model',
#  'experiment',
#  'result',
#  'track',
#  'algorithm',
#  'suitabl',
#  'predict',
#  'pedestrian',
#  'behavior',
#  'onlin',
#  'need',
#  'scene',
#  'prior',
#  'hand',
#  'annot',
#  'goal',
#  'inform',
#  'improv',
#  'track',
#  'real',
#  'world',
#  'crowd',
#  'scene',
#  'frame',
#  'rat',
#  'extract',
#  'latent',
#  'dimension',
#  'structur',
#  'high',
#  'dimension',
#  'data',
#  'paramount',
#  'import',
#  'time',
#  'infer',
#  'task',
#  'encount',
#  'data',
#  'analyt',
#  'increas',
#  'noisi',
#  'heterogen',
#  'incomplet',
#  'dataset',
#  'need',
#  'real',
#  'time',
#  'process',
#  'stream',
#  'data',
#  'pose',
#  'major',
#  'challeng',
#  'context',
#  'present',
#  'paper',
#  'permeat',
#  'benefit',
#  'rank',
#  'minim',
#  'scalabl',
#  'imput',
#  'miss',
#  'data',
#  'track',
#  'dimension',
#  'subspac',
#  'unravel',
#  'latent',
#  'possibl',
#  'multi',
#  'structur',
#  'incomplet',
#  'stream',
#  'data',
#  'rank',
#  'matrix',
#  'data',
#  'subspac',
#  'estim',
#  'propos',
#  ...]

# %%
dictionary_sub = gensim.corpora.Dictionary(processed_subject) 
bow_corpus_sub = [dictionary_sub.doc2bow(doc) for doc in processed_subject]

# %%
for index, score in sorted(lda_model[bow_corpus_sub[11]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.34674182534217834
# Topic: 0.008*"structur" + 0.007*"high" + 0.007*"surfac" + 0.006*"base" + 0.006*"result" + 0.005*"method" + 0.005*"applic" + 0.005*"optic" + 0.005*"properti" + 0.004*"materi"
#
# Score: 0.13652276992797852
# Topic: 0.015*"method" + 0.015*"imag" + 0.011*"measur" + 0.010*"model" + 0.010*"time" + 0.008*"result" + 0.007*"base" + 0.007*"data" + 0.007*"perform" + 0.007*"propos"
#
# Score: 0.10468249022960663
# Topic: 0.010*"children" + 0.010*"studi" + 0.009*"food" + 0.008*"differ" + 0.006*"relat" + 0.006*"obes" + 0.006*"behavior" + 0.006*"effect" + 0.006*"task" + 0.006*"particip"
#
# Score: 0.09535442292690277
# Topic: 0.017*"speci" + 0.009*"differ" + 0.008*"sampl" + 0.008*"studi" + 0.008*"model" + 0.008*"popul" + 0.008*"data" + 0.006*"plant" + 0.006*"method" + 0.006*"genet"
#
# Score: 0.09149647504091263
# Topic: 0.014*"studi" + 0.014*"health" + 0.010*"risk" + 0.009*"care" + 0.008*"associ" + 0.008*"patient" + 0.006*"data" + 0.006*"year" + 0.006*"women" + 0.006*"report"
#
# Score: 0.06016428396105766
# Topic: 0.052*"patient" + 0.010*"studi" + 0.010*"group" + 0.009*"year" + 0.009*"signific" + 0.008*"case" + 0.008*"treatment" + 0.008*"clinic" + 0.007*"associ" + 0.007*"follow"
#
# Score: 0.05271724611520767
# Topic: 0.021*"group" + 0.013*"studi" + 0.011*"treatment" + 0.011*"signific" + 0.010*"effect" + 0.010*"dose" + 0.009*"infect" + 0.009*"control" + 0.009*"week" + 0.009*"test"
#
# Score: 0.04231870174407959
# Topic: 0.014*"acid" + 0.013*"activ" + 0.010*"protein" + 0.009*"product" + 0.009*"compound" + 0.009*"concentr" + 0.009*"studi" + 0.007*"show" + 0.006*"effect" + 0.006*"high"
#
# Score: 0.03709159418940544
# Topic: 0.015*"activ" + 0.014*"level" + 0.013*"increas" + 0.012*"induc" + 0.011*"effect" + 0.009*"express" + 0.008*"signific" + 0.008*"studi" + 0.008*"mice" + 0.006*"associ"
#
# Score: 0.03291021287441254
# Topic: 0.038*"cell" + 0.017*"gene" + 0.016*"express" + 0.010*"protein" + 0.009*"cancer" + 0.007*"studi" + 0.007*"regul" + 0.006*"tumor" + 0.006*"human" + 0.006*"activ"

# %%
for index, score in sorted(lda_model_tfidf[bow_corpus[11]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.5669774413108826
# Topic: 0.003*"compound" + 0.003*"acid" + 0.003*"protein" + 0.003*"cell" + 0.003*"activ" + 0.003*"structur" + 0.003*"surfac" + 0.002*"temperatur" + 0.002*"plant" + 0.002*"product"
#
# Score: 0.4101311266422272
# Topic: 0.005*"patient" + 0.004*"cell" + 0.003*"group" + 0.003*"associ" + 0.003*"cancer" + 0.003*"express" + 0.002*"diseas" + 0.002*"risk" + 0.002*"treatment" + 0.002*"gene"
