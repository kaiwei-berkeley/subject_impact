# %%
import re
import numpy as np
import pandas as pd
from collections import Counter
import matplotlib.pyplot as plt
import seaborn as sns
import json
import os
import math

# %% [markdown]
# **Create dataframe that matches paper abstract with subjects **

# %%
paper_id = []
abstract = []

f = open('aminer_2015.txt','r',encoding = 'utf8')
f.readline()
for i, line in enumerate(f):
        if (i+2) % 250000 == 0:
            print('file '+file+': ',round((i+2)/1000000*100,1),"%")
        json_line = json.loads(line)
        if 'year' in json_line and 'keywords' in json_line and \
        'abstract' in json_line and 'lang' in json_line and \
        'references' in json_line and 'issn' in json_line:
            
            if json_line['lang'] == 'en' :
                
                ## store paper info, later use to get the subject of the paper
                paper_id.append(json_line['id'])
                abstract.append(json_line['abstract'])

                
f.close()

# %%
df= pd.DataFrame()
df['id'] = paper_id
df['abstract'] = abstract
df.set_index('id')
# Out:
#                                                                    abstract
# id
# 53e99796b7602d9701f5d979  The pHealth 2015 Conference is the 12th in a s...
# 53e99796b7602d9701f613ec  A graphical model is a probability distributio...
# 53e9979bb7602d9701f668c8  An inter-governmental body is encouraging the ...
# 53e997a2b7602d9701f74d6a  The most important results from the EU-sponsor...
# 53e997a2b7602d9701f75614  The Nursing and Midwifery Council is seeking t...
# 53e997a2b7602d9701f75a62                                          Contents.
# 53e997a2b7602d9701f75a78                                              cover
# 53e997a6b7602d9701f7c67e  The above comments on our previous paper are t...
# 53e997b2b7602d9701f91202  Machine learning's focus on ill-defined proble...
# 53e997b5b7602d9701f969d2  \n Die numerische Mathematik (kurz: Numerik) i...
# 53e997b9b7602d9701f9eead  Gold Standard allergen-specific immunotherapy ...
# 53e997c2b7602d9701fb3181  \n When working with chemicals which may be ha...
# 53e997c6b7602d9701fb50da  Metabolomic studies generate large quantities ...
# 53e997f1b7602d9701ff1755  Retinal images in the human eye are normally d...
# 53e997f1b7602d9701ff3a2d  Computer transposition of matrices larger than...
# 53e997f1b7602d9701ff3a2e                          First Page of the Article
# 53e997f1b7602d9701ff3a40  Thacker and Shendumikar 1 write that there is ...
# 53e997f5b7602d9701ffb1ce  From the Publisher:The design of knowledge sys...
# 53e997f8b7602d9701ffcd85  Human–computer interaction (HCI) is the study ...
# 53e997f9b7602d9702002dfd                          First Page of the Article
# 53e99822b7602d9702042c14  Skeletal stem cells (SSCs) reside in the postn...
# 53e99822b7602d970204416d  In this article we attempt a closer examinatio...
# 53e99827b7602d9702046f1d                                   Without Abstract
# 53e99827b7602d9702047011  We read with interest the report ‘Milky ascite...
# 53e99842b7602d970206b530  At a time when dealing with climate change iss...
# 53e99842b7602d970206e55d  Summary  The MEN syndromes continue to be the ...
# 53e99853b7602d970208892b  Injection of local anesthetic intraneurally oc...
# 53e998aab7602d97020e6892  Background Electroacupuncture (EA) at acupoint...
# 53e9a0d8b7602d97029be954  In Cyber-Physical Networked Systems (CPNS), th...
# 53e9a0d8b7602d97029c0a03  We consider the problem of estimating local se...
# ...                                                                     ...
# 55a6d1dd65ce054aad772e9a  Attempting to achieve long-lasting and stable ...
# 55a6d1dd65ce054aad772e9d  Rising atmospheric CO2 concentration (C a) is ...
# 55a6d1dd65ce054aad772ea4  The present study evaluated the differences in...
# 55aa3f0d65ce2a9b9e15fc13  Infrared spectroscopy is the technique of choi...
# 55aa484865ce2a9b9e15fc55  Mutant mitochondrial DNA (mtDNA) gives rise to...
# 55aa495765ce2a9b9e15fc5b  On 6 March 2015, the United States Food and Dr...
# 55aa4f3f65ce2a9b9e15fc80  Mammalian mitochondrial ribosomes (mitoribosom...
# 55aa553665ce2a9b9e15fcab  Methane is a key component in the global carbo...
# 55aa613965ce2a9b9e15fcfb  Measles is a highly contagious human disease. ...
# 55aa670465ce2a9b9e15fd1a  The Protoaurignacian culture is pivotal to the...
# 55aa6cb265ce2a9b9e15fd3d  Growing evidence has demonstrated the importan...
# 55aa76d865ce2a9b9e15fd95  Werner syndrome (WS) is a premature aging diso...
# 55aa9d6365ce2a9b9e15fe2e  Tobacco smoking is a risk factor for numerous ...
# 55aaa23d65ce2a9b9e15fe40  China is the world's largest producer, consume...
# 55aaa5f665ce2a9b9e15fe52  XRCC4 and XLF are two structurally related pro...
# 55aab5b865ce2a9b9e15fe96  The 26S proteasome is a key player in eukaryot...
# 55aaccef65ce2a9b9e15feb3  Incoming and outgoing solar radiation couple w...
# 55aacdf765ce2a9b9e15feb7  The 18-kilodalton translocator protein (TSPO),...
# 55aada4e65ce2a9b9e15fef7  Electric double layers (EDLs) of ionic liquids...
# 55aadb6765ce2a9b9e15feff  The C-terminal region of Clostridium perfringe...
# 55aae0b665ce2a9b9e15ff1d  The evolution of galaxies is connected to the ...
# 55aae12e65ce2a9b9e15ff1f  Cope’s rule proposes that animal lineages evol...
# 55aae51e65ce2a9b9e15ff70  Superhydrophobic self-cleaning surfaces are ba...
# 55aae52965ce2a9b9e15ff72  The mammalian cerebral cortex supports cogniti...
# 55aae5da65ce2a9b9e15ff89  Payments for Ecosystem Services (PES) mechanis...
# 53e99df0b7602d97026b112d  In this work, we formulate the problem of keyw...
# 53e99e13b7602d97026d39ec  In this paper, we address the problems of mode...
# 53e99e6ab7602d9702731d2f  This paper studies the simultaneous wireless i...
# 53e99faeb7602d9702883abc  It is of great interest to develop efficient w...
# 53e9a026b7602d97029074fa  In this paper, we deal with resource allocatio...
#
# [95421 rows x 1 columns]

# %%
df.head()
# Out:
#                          id                                           abstract
# 0  53e99796b7602d9701f5d979  The pHealth 2015 Conference is the 12th in a s...
# 1  53e99796b7602d9701f613ec  A graphical model is a probability distributio...
# 2  53e9979bb7602d9701f668c8  An inter-governmental body is encouraging the ...
# 3  53e997a2b7602d9701f74d6a  The most important results from the EU-sponsor...
# 4  53e997a2b7602d9701f75614  The Nursing and Midwifery Council is seeking t...

# %%
subject = pd.read_csv('paper_subject_match.csv',index_col = 'id')

# %%
subject.head()
# Out:
#                           paper_subject
# id
# 53e99784b7602d9701f3e13e           13.0
# 53e99784b7602d9701f3e4f2           13.0
# 53e9978db7602d9701f4f415           13.0
# 53e99792b7602d9701f56a86           27.0
# 53e99792b7602d9701f5b087            NaN

# %%
tm = pd.merge(df, subject, on = ['id'])

# %%
tm.head()
# Out:
#                          id  \
# 0  53e99796b7602d9701f5d979
# 1  53e99796b7602d9701f613ec
# 2  53e9979bb7602d9701f668c8
# 3  53e997a2b7602d9701f74d6a
# 4  53e997a2b7602d9701f75614
#
#                                             abstract  paper_subject
# 0  The pHealth 2015 Conference is the 12th in a s...            NaN
# 1  A graphical model is a probability distributio...            NaN
# 2  An inter-governmental body is encouraging the ...           10.0
# 3  The most important results from the EU-sponsor...            NaN
# 4  The Nursing and Midwifery Council is seeking t...           29.0

# %%
tm.isnull().sum()
# Out:
# id                  0
# abstract            0
# paper_subject    6180
# dtype: int64

# %%
len(tm)
# Out:
# 95421

# %%
tm = tm.dropna()

# %%
tm = tm.drop(columns = ['id'])

# %%
tm['paper_subject'] = tm['paper_subject'].apply(np.int64)

# %% [markdown]
# **Concatenate all abstracts having the same subject(group by subject)**

# %%
tm_all = tm.groupby('paper_subject').agg({'abstract':'-'.join})

# %%
tm_all.reset_index(level=0, inplace=True)

# %%
tm_all.head()
# Out:
#    paper_subject                                           abstract
# 0             10  An inter-governmental body is encouraging the ...
# 1             11  The total variation (TV) regularization method...
# 2             12  Technologies for automated detection of neonat...
# 3             13  Skeletal stem cells (SSCs) reside in the postn...
# 4             14  Despite the extensive application of Monte Car...

# %% [markdown]
# **Processing the abstract:**
# - Tokenization: Split the text into sentences and the sentences into words. Lowercase the words and remove punctuation
# - Words that have fewer than 3 characters are removed
# - All stopwords are removed
# - lemmatized — words in third person to first person, verbs in past and future tenses to present
# - Stemmed — words are reduced to their root form

# %%
#import sys
#!{sys.executable} -m pip install gensim
import gensim
from gensim.utils import simple_preprocess
from gensim.parsing.preprocessing import STOPWORDS
from nltk.stem import WordNetLemmatizer, SnowballStemmer
from nltk.stem.porter import *
import numpy as np
np.random.seed(2015)

# %%
import nltk
nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package wordnet to /Users/yihuan/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# True

# %%
def lemmatize_stemming(text):
    return stemmer.stem(WordNetLemmatizer().lemmatize(text, pos='v')) #lemmatize as verb, default is noun

def preprocess(text):
    result = []
    for token in gensim.utils.simple_preprocess(text):
        if token not in gensim.parsing.preprocessing.STOPWORDS and len(token) > 3:
            result.append(lemmatize_stemming(token))
    return result

# %% [markdown]
# An example of processing the words in the abstract:

# %%
stemmer = SnowballStemmer('english') #Create a new instance of a language specific subclass
doc_sample = tm_all[tm_all['paper_subject'] == 10].values[0][1]
words = []
for word in doc_sample.split(' '):
    words.append(word)
print(words[:10])
print('\n\n tokenized and lemmatized document: ')
print(preprocess(doc_sample[:100]))
# Out:
# ['An', 'inter-governmental', 'body', 'is', 'encouraging', 'the', 'replacement', 'of', 'currency', 'with']
#
#
#  tokenized and lemmatized document:
# ['inter', 'government', 'bodi', 'encourag', 'replac', 'currenc', 'object', 'discoura']

# %% [markdown]
# The real processing of all the abstract, **takes time!**

# %%
processed_docs = tm_all['abstract'].map(preprocess)

# %%
processed_docs[11] #words processed in Economics, Econometrics and Finance
# Out:
# ['consid',
#  'problem',
#  'estim',
#  'local',
#  'sensor',
#  'paramet',
#  'local',
#  'paramet',
#  'sensor',
#  'observ',
#  'relat',
#  'linear',
#  'stochast',
#  'model',
#  'studi',
#  'gaussian',
#  'product',
#  'algorithm',
#  'wireless',
#  'network',
#  'gspawn',
#  'procedur',
#  'compar',
#  'popular',
#  'diffus',
#  'strategi',
#  'perform',
#  'network',
#  'paramet',
#  'estim',
#  'communic',
#  'cost',
#  'sensor',
#  'increas',
#  'increas',
#  'network',
#  'densiti',
#  'gspawn',
#  'allow',
#  'sensor',
#  'broadcast',
#  'messag',
#  'size',
#  'depend',
#  'network',
#  'size',
#  'densiti',
#  'make',
#  'suitabl',
#  'applic',
#  'wireless',
#  'sensor',
#  'network',
#  'gspawn',
#  'converg',
#  'mean',
#  'mean',
#  'squar',
#  'stabil',
#  'technic',
#  'suffici',
#  'condit',
#  'applic',
#  'gspawn',
#  'network',
#  'local',
#  'problem',
#  'line',
#  'sight',
#  'environ',
#  'numer',
#  'result',
#  'suggest',
#  'gspawn',
#  'converg',
#  'faster',
#  'general',
#  'diffus',
#  'method',
#  'lower',
#  'communic',
#  'cost',
#  'sensor',
#  'compar',
#  'root',
#  'mean',
#  'squar',
#  'error',
#  'express',
#  'clone',
#  'play',
#  'import',
#  'role',
#  'facial',
#  'express',
#  'synthesi',
#  'paper',
#  'novel',
#  'algorithm',
#  'propos',
#  'facial',
#  'express',
#  'clone',
#  'propos',
#  'algorithm',
#  'introduc',
#  'elast',
#  'model',
#  'balanc',
#  'global',
#  'local',
#  'warp',
#  'effect',
#  'impact',
#  'facial',
#  'featur',
#  'divers',
#  'peopl',
#  'minim',
#  'effect',
#  'geometr',
#  'warp',
#  'result',
#  'achiev',
#  'furthermor',
#  'muscl',
#  'distribut',
#  'base',
#  'model',
#  'propos',
#  'util',
#  'muscl',
#  'distribut',
#  'human',
#  'face',
#  'result',
#  'accur',
#  'facial',
#  'illumin',
#  'detail',
#  'addit',
#  'propos',
#  'distanc',
#  'base',
#  'metric',
#  'automat',
#  'select',
#  'optim',
#  'paramet',
#  'global',
#  'local',
#  'warp',
#  'effect',
#  'elast',
#  'model',
#  'suitabl',
#  'balanc',
#  'experiment',
#  'result',
#  'propos',
#  'algorithm',
#  'outperform',
#  'exist',
#  'method',
#  'elsevi',
#  'right',
#  'reserv',
#  'paper',
#  'consid',
#  'wireless',
#  'power',
#  'cooper',
#  'communic',
#  'network',
#  'consist',
#  'hybrid',
#  'access',
#  'point',
#  'sourc',
#  'relay',
#  'contrast',
#  'convent',
#  'cooper',
#  'network',
#  'sourc',
#  'relay',
#  'consid',
#  'network',
#  'emb',
#  'energi',
#  'suppli',
#  'need',
#  'reli',
#  'energi',
#  'harvest',
#  'signal',
#  'broadcast',
#  'cooper',
#  'inform',
#  'transmiss',
#  'base',
#  'node',
#  'refer',
#  'model',
#  'propos',
#  'harvest',
#  'cooper',
#  'protocol',
#  'sourc',
#  'relay',
#  'harvest',
#  'energi',
#  'downlink',
#  'work',
#  'cooper',
#  'uplink',
#  'sourc',
#  'inform',
#  'transmiss',
#  'consid',
#  'delay',
#  'limit',
#  'transmiss',
#  'mode',
#  'approxim',
#  'close',
#  'form',
#  'express',
#  'averag',
#  'throughput',
#  'propos',
#  'protocol',
#  'deriv',
#  'rayleigh',
#  'fade',
#  'channel',
#  'subsequ',
#  'analysi',
#  'extend',
#  'multi',
#  'relay',
#  'scenario',
#  'approxim',
#  'throughput',
#  'protocol',
#  'popular',
#  'relay',
#  'select',
#  'scheme',
#  'deriv',
#  'asymptot',
#  'analys',
#  'throughput',
#  'perform',
#  'consid',
#  'scheme',
#  'high',
#  'signal',
#  'nois',
#  'radio',
#  'provid',
#  'theoret',
#  'result',
#  'valid',
#  'numer',
#  'simul',
#  'impact',
#  'paramet',
#  'time',
#  'alloc',
#  'relay',
#  'number',
#  'relay',
#  'posit',
#  'throughput',
#  'perform',
#  'extens',
#  'investig',
#  'paper',
#  'propos',
#  'crowdsourc',
#  'base',
#  'framework',
#  'myopic',
#  'target',
#  'track',
#  'design',
#  'optim',
#  'incent',
#  'compat',
#  'mechan',
#  'wireless',
#  'sensor',
#  'network',
#  'contain',
#  'sensor',
#  'selfish',
#  'profit',
#  'motiv',
#  'typic',
#  'wsns',
#  'limit',
#  'bandwidth',
#  'fusion',
#  'center',
#  'distribut',
#  'total',
#  'number',
#  'bit',
#  'transmit',
#  'sensor',
#  'sensor',
#  'formul',
#  'consid',
#  'conduct',
#  'auction',
#  'solicit',
#  'bid',
#  'selfish',
#  'sensor',
#  'reflect',
#  'valu',
#  'energi',
#  'cost',
#  'furthermor',
#  'ration',
#  'truth',
#  'sensor',
#  'guarante',
#  'model',
#  'final',
#  'problem',
#  'formul',
#  'multipl',
#  'choic',
#  'knapsack',
#  'problem',
#  'mckp',
#  'solv',
#  'dynam',
#  'program',
#  'method',
#  'pseudo',
#  'polynomi',
#  'time',
#  'simul',
#  'result',
#  'effect',
#  'propos',
#  'approach',
#  'term',
#  'track',
#  'perform',
#  'lifetim',
#  'sensor',
#  'network',
#  'present',
#  'joint',
#  'channel',
#  'power',
#  'alloc',
#  'framework',
#  'downlink',
#  'transmiss',
#  'orthogon',
#  'frequenc',
#  'divis',
#  'multipl',
#  'access',
#  'ofdma',
#  'base',
#  'cellular',
#  'network',
#  'compos',
#  'macrocel',
#  'overlay',
#  'small',
#  'cell',
#  'framework',
#  'resourc',
#  'alloc',
#  'problem',
#  'macrocel',
#  'small',
#  'cell',
#  'formul',
#  'optim',
#  'problem',
#  'macrocel',
#  'formul',
#  'problem',
#  'awar',
#  'exist',
#  'small',
#  'cell',
#  'tier',
#  'problem',
#  'macrocel',
#  'perform',
#  'satisfi',
#  'data',
#  'rate',
#  'requir',
#  'macro',
#  'user',
#  'equip',
#  'mue',
#  'maxim',
#  'toler',
#  'interfer',
#  'small',
#  'cell',
#  'tier',
#  'alloc',
#  'channel',
#  'problem',
#  'macrocel',
#  'show',
#  'mix',
#  'integ',
#  'nonlinear',
#  'problem',
#  'minlp',
#  'prove',
#  'macrocel',
#  'solv',
#  'altern',
#  'optim',
#  'problem',
#  'yield',
#  'optim',
#  'solut',
#  'reduc',
#  'complex',
#  'small',
#  'cell',
#  'follow',
#  'idea',
#  'tier',
#  'awar',
#  'formul',
#  'optim',
#  'problem',
#  'account',
#  'admiss',
#  'control',
#  'aim',
#  'maxim',
#  'number',
#  'admit',
#  'user',
#  'simultan',
#  'minim',
#  'consum',
#  'bandwidth',
#  'similar',
#  'macrocel',
#  'optim',
#  'problem',
#  'small',
#  'cell',
#  'problem',
#  'show',
#  'minlp',
#  'obtain',
#  'optim',
#  'solut',
#  'minlp',
#  'problem',
#  'reli',
#  'convex',
#  'relax',
#  'addit',
#  'employ',
#  'dual',
#  'decomposit',
#  'techniqu',
#  'distribut',
#  'solut',
#  'small',
#  'cell',
#  'tier',
#  'numer',
#  'result',
#  'confirm',
#  'perform',
#  'gain',
#  'propos',
#  'formul',
#  'macrocel',
#  'tradit',
#  'resourc',
#  'alloc',
#  'base',
#  'minim',
#  'transmiss',
#  'power',
#  'show',
#  'formul',
#  'base',
#  'convex',
#  'relax',
#  'yield',
#  'similar',
#  'behavior',
#  'minlp',
#  'formul',
#  'distribut',
#  'solut',
#  'converg',
#  'solut',
#  'obtain',
#  'solv',
#  'correspond',
#  'convex',
#  'optim',
#  'problem',
#  'central',
#  'fashion',
#  'cellular',
#  'network',
#  'model',
#  'base',
#  'station',
#  'usual',
#  'assum',
#  'form',
#  'lattic',
#  'poisson',
#  'point',
#  'process',
#  'realiti',
#  'deploy',
#  'fulli',
#  'regular',
#  'complet',
#  'random',
#  'accord',
#  'paper',
#  'consid',
#  'general',
#  'class',
#  'motion',
#  'invari',
#  'model',
#  'analyz',
#  'behavior',
#  'outag',
#  'probabl',
#  'probabl',
#  'signal',
#  'interfer',
#  'plus',
#  'nois',
#  'ratio',
#  'sinr',
#  'smaller',
#  'threshold',
#  'threshold',
#  'go',
#  'zero',
#  'remark',
#  'slope',
#  'outag',
#  'probabl',
#  'function',
#  'threshold',
#  'essenti',
#  'motion',
#  'invari',
#  'point',
#  'process',
#  'slope',
#  'mere',
#  'depend',
#  'fade',
#  'statist',
#  'result',
#  'introduc',
#  'notion',
#  'asymptot',
#  'deploy',
#  'gain',
#  'character',
#  'horizont',
#  'success',
#  'probabl',
#  'point',
#  'process',
#  'high',
#  'reliabl',
#  'regim',
#  'success',
#  'probabl',
#  'near',
#  'demonstr',
#  'use',
#  'sinr',
#  'distribut',
#  'investig',
#  'outag',
#  'probabl',
#  'adg',
#  'differ',
#  'point',
#  'process',
#  'fade',
#  'statist',
#  'simul',
#  'molecular',
#  'communic',
#  'network',
#  'realis',
#  'communic',
#  'nanoscal',
#  'devic',
#  'molecular',
#  'communic',
#  'network',
#  'transmitt',
#  'receiv',
#  'communic',
#  'signal',
#  'molecul',
#  'receiv',
#  'signal',
#  'molecul',
#  'react',
#  'chain',
#  'chemic',
#  'reaction',
#  'produc',
#  'output',
#  'molecul',
#  'count',
#  'output',
#  'molecul',
#  'time',
#  'output',
#  'signal',
#  'receiv',
#  'output',
#  'signal',
#  'noisi',
#  'stochast',
#  'natur',
#  'diffus',
#  'chemic',
#  'reaction',
#  'paper',
#  'aim',
#  'characteris',
#  'properti',
#  'output',
#  'signal',
#  'model',
#  'transmiss',
#  'medium',
#  'transmitt',
#  'receiv',
#  'order',
#  'simplifi',
#  'analysi',
#  'model',
#  'transmitt',
#  'sequenc',
#  'specifi',
#  'number',
#  'molecul',
#  'emit',
#  'transmitt',
#  'time',
#  'paper',
#  'consid',
#  'receiv',
#  'reaction',
#  'mechan',
#  'revers',
#  'convers',
#  'linear',
#  'catalyt',
#  'approxim',
#  'respect',
#  'ligand',
#  'receptor',
#  'bind',
#  'enzymat',
#  'reaction',
#  'mechan',
#  'choos',
#  'consid',
#  'transmitt',
#  'diffus',
#  'ordinari',
#  'differenti',
#  'equat',
#  'describ',
#  'mean',
#  'behaviour',
#  'reaction',
#  'mechan',
#  'form',
#  'consid',
#  'behaviour',
#  'transmitt',
#  'signal',
#  'mean',
#  'varianc',
#  'number',
#  'output',
#  'molecul',
#  'receiv',
#  'reaction',
#  'mechan',
#  'differ',
#  'behaviour',
#  'deriv',
#  'analyt',
#  'express',
#  'mean',
#  'varianc',
#  'frequenc',
#  'properti',
#  'number',
#  'output',
#  'molecul',
#  'receiv',
#  'reaction',
#  'mechan',
#  'addit',
#  'revers',
#  'convers',
#  'abl',
#  'deriv',
#  'exact',
#  'probabl',
#  'distribut',
#  'number',
#  'output',
#  'molecul',
#  'model',
#  'allow',
#  'studi',
#  'impact',
#  'design',
#  'paramet',
#  'communic',
#  'perform',
#  'exampl',
#  'assum',
#  'receiv',
#  'enclos',
#  'membran',
#  'studi',
#  'impact',
#  'diffus',
#  'molecul',
#  'membran',
#  'communic',
#  'rformanc',
#  'paper',
#  'present',
#  'statist',
#  'chatter',
#  'detect',
#  'method',
#  'methodolog',
#  'base',
#  'studi',
#  'discret',
#  'wavelet',
#  'transform',
#  'scheme',
#  'statist',
#  'analysi',
#  'wavelet',
#  'transform',
#  'modulus',
#  'maxima',
#  'wtmm',
#  'wavelet',
#  'transform',
#  'modulus',
#  'maxima',
#  'point',
#  'wavelet',
#  'transform',
#  'signal',
#  'local',
#  'maxim',
#  'correspond',
#  'time',
#  'locat',
#  'noisi',
#  'machin',
#  'environ',
#  'wavelet',
#  'base',
#  'nois',
#  'method',
#  'includ',
#  'hybrid',
#  'threshold',
#  'function',
#  'level',
#  'depend',
#  'univers',
#  'threshold',
#  'rule',
#  'propos',
#  'dimension',
#  'chatter',
#  'index',
#  'vari',
#  'design',
#  'base',
#  'statist',
#  'analysi',
#  'wtmm',
#  'main',
#  'advantag',
#  'propos',
#  'chatter',
#  'index',
#  'includ',
#  'variat',
#  'rang',
#  'independ',
#  'process',
#  'paramet',
#  'machin',
#  'system',
#  'threshold',
#  'valu',
#  'suscept',
#  'cut',
#  'condit',
#  'chang',
#  'valu',
#  'relat',
#  'term',
#  'result',
#  'chatter',
#  'index',
#  'differ',
#  'machin',
#  'process',
#  'time',
#  'consum',
#  'recalibr',
#  'process',
#  'present',
#  'multipl',
#  'person',
#  'track',
#  'algorithm',
#  'base',
#  'combin',
#  'particl',
#  'filter',
#  'reciproc',
#  'veloc',
#  'obstacl',
#  'agent',
#  'base',
#  'crowd',
#  'model',
#  'infer',
#  'collis',
#  'free',
#  'veloc',
#  'predict',
#  'pedestrian',
#  'motion',
#  'addit',
#  'posit',
#  'veloc',
#  'track',
#  'algorithm',
#  'estim',
#  'intern',
#  'goal',
#  'desir',
#  'destin',
#  'desir',
#  'veloc',
#  'track',
#  'pedestrian',
#  'onlin',
#  'manner',
#  'remov',
#  'need',
#  'specifi',
#  'inform',
#  'furthermor',
#  'leverag',
#  'longer',
#  'term',
#  'predict',
#  'deriv',
#  'higher',
#  'order',
#  'aggreg',
#  'multipl',
#  'predict',
#  'differ',
#  'prior',
#  'time',
#  'step',
#  'yield',
#  'tracker',
#  'recov',
#  'short',
#  'term',
#  'occlus',
#  'spurious',
#  'nois',
#  'appear',
#  'model',
#  'experiment',
#  'result',
#  'track',
#  'algorithm',
#  'suitabl',
#  'predict',
#  'pedestrian',
#  'behavior',
#  'onlin',
#  'need',
#  'scene',
#  'prior',
#  'hand',
#  'annot',
#  'goal',
#  'inform',
#  'improv',
#  'track',
#  'real',
#  'world',
#  'crowd',
#  'scene',
#  'frame',
#  'rat',
#  'extract',
#  'latent',
#  'dimension',
#  'structur',
#  'high',
#  'dimension',
#  'data',
#  'paramount',
#  'import',
#  'time',
#  'infer',
#  'task',
#  'encount',
#  'data',
#  'analyt',
#  'increas',
#  'noisi',
#  'heterogen',
#  'incomplet',
#  'dataset',
#  'need',
#  'real',
#  'time',
#  'process',
#  'stream',
#  'data',
#  'pose',
#  'major',
#  'challeng',
#  'context',
#  'present',
#  'paper',
#  'permeat',
#  'benefit',
#  'rank',
#  'minim',
#  'scalabl',
#  'imput',
#  'miss',
#  'data',
#  'track',
#  'dimension',
#  'subspac',
#  'unravel',
#  'latent',
#  'possibl',
#  'multi',
#  'structur',
#  'incomplet',
#  'stream',
#  'data',
#  'rank',
#  'matrix',
#  'data',
#  'subspac',
#  'estim',
#  'propos',
#  ...]

# %%
dictionary = gensim.corpora.Dictionary(processed_docs) 
#Dictionary encapsulates the mapping between normalized words and their integer ids.

# %%
count = 0
for k, v in dictionary.iteritems():
    print(k, v)
    count += 1
    if count > 30:
        break
# Out:
# 0 aaet
# 1 aakr
# 2 aapoaii
# 3 ababa
# 4 abandon
# 5 abas
# 6 abcc
# 7 abdomen
# 8 abdomin
# 9 abduct
# 10 aberr
# 11 abil
# 12 abiogen
# 13 abiot
# 14 abl
# 15 ablat
# 16 abmd
# 17 abnorm
# 18 abolish
# 19 abort
# 20 abound
# 21 abras
# 22 abrog
# 23 abrupt
# 24 abscis
# 25 absenc
# 26 absent
# 27 absentia
# 28 absolut
# 29 absorb
# 30 absorpt

# %%
# dictionary.filter_extremes(no_below=15, no_above=0.5, keep_n=100000)
# How should we limit?

# %%
bow_corpus = [dictionary.doc2bow(doc) for doc in processed_docs]
# for each subject, create a dictionary reporting words and how many times those words appear

# %%
bow_corpus[11] #（id in dict, how many times of appearance
# Out:
# [(8, 4),
#  (10, 6),
#  (11, 184),
#  (13, 2),
#  (14, 172),
#  (15, 12),
#  (17, 20),
#  (21, 11),
#  (23, 10),
#  (25, 42),
#  (26, 6),
#  (28, 35),
#  (29, 105),
#  (30, 154),
#  (32, 9),
#  (34, 17),
#  (35, 1),
#  (38, 1),
#  (39, 7),
#  (41, 86),
#  (42, 52),
#  (43, 13),
#  (44, 214),
#  (45, 4),
#  (47, 20),
#  (48, 16),
#  (49, 36),
#  (50, 200),
#  (51, 154),
#  (56, 86),
#  (57, 338),
#  (58, 330),
#  (62, 14),
#  (67, 17),
#  (68, 1),
#  (71, 1144),
#  (73, 203),
#  (74, 1),
#  (76, 1),
#  (81, 68),
#  (83, 48),
#  (84, 32),
#  (86, 11),
#  (87, 50),
#  (90, 8),
#  (93, 3),
#  (94, 49),
#  (95, 758),
#  (96, 3),
#  (99, 5),
#  (100, 1),
#  (102, 63),
#  (103, 130),
#  (104, 7),
#  (110, 349),
#  (111, 1),
#  (113, 111),
#  (114, 12),
#  (117, 711),
#  (118, 216),
#  (119, 1),
#  (120, 2),
#  (121, 3),
#  (122, 2),
#  (126, 25),
#  (128, 119),
#  (130, 2),
#  (131, 3),
#  (132, 10),
#  (133, 45),
#  (134, 150),
#  (135, 5),
#  (137, 12),
#  (138, 25),
#  (140, 9),
#  (141, 8),
#  (533, 1),
#  (536, 628),
#  (537, 1393),
#  (541, 1),
#  (542, 2),
#  (543, 6),
#  (544, 1066),
#  (545, 128),
#  (546, 11),
#  (547, 283),
#  (549, 4),
#  (550, 2),
#  (552, 4),
#  (553, 39),
#  (555, 1),
#  (557, 2),
#  (559, 4),
#  (560, 84),
#  (561, 17),
#  (562, 1),
#  (566, 2),
#  (568, 1),
#  (571, 1),
#  (572, 242),
#  (575, 1),
#  (577, 454),
#  (578, 1),
#  (579, 1),
#  (581, 3),
#  (582, 3),
#  (583, 8),
#  (585, 54),
#  (588, 25),
#  (592, 10),
#  (594, 2),
#  (595, 87),
#  (596, 815),
#  (597, 10),
#  (599, 6),
#  (601, 1),
#  (603, 52),
#  (606, 3),
#  (609, 23),
#  (617, 57),
#  (618, 7),
#  (619, 5),
#  (621, 20),
#  (622, 91),
#  (628, 1),
#  (632, 1),
#  (633, 5),
#  (636, 7),
#  (637, 7),
#  (639, 1),
#  (642, 3),
#  (643, 4),
#  (647, 2),
#  (648, 102),
#  (652, 2),
#  (654, 83),
#  (655, 275),
#  (657, 2),
#  (658, 185),
#  (659, 47),
#  (661, 112),
#  (662, 208),
#  (664, 106),
#  (665, 81),
#  (667, 1),
#  (669, 2),
#  (670, 2),
#  (674, 95),
#  (675, 12),
#  (677, 35),
#  (680, 3),
#  (682, 6),
#  (683, 3),
#  (687, 3),
#  (689, 31),
#  (691, 179),
#  (692, 14),
#  (699, 1),
#  (700, 84),
#  (701, 100),
#  (702, 46),
#  (703, 24),
#  (705, 86),
#  (706, 69),
#  (707, 1),
#  (708, 25),
#  (709, 118),
#  (711, 98),
#  (715, 12),
#  (716, 5),
#  (717, 30),
#  (720, 22),
#  (725, 1),
#  (726, 3),
#  (728, 41),
#  (730, 111),
#  (734, 12),
#  (738, 1),
#  (741, 4),
#  (742, 50),
#  (743, 86),
#  (744, 2),
#  (745, 40),
#  (751, 4),
#  (755, 44),
#  (757, 200),
#  (759, 7),
#  (760, 346),
#  (762, 2),
#  (764, 2),
#  (765, 149),
#  (767, 34),
#  (768, 11),
#  (769, 16),
#  (770, 85),
#  (771, 106),
#  (773, 7),
#  (775, 7),
#  (779, 4),
#  (785, 3),
#  (786, 5),
#  (788, 83),
#  (789, 22),
#  (791, 59),
#  (792, 49),
#  (793, 10),
#  (794, 2),
#  (795, 1),
#  (796, 5),
#  (806, 2),
#  (809, 171),
#  (810, 1),
#  (817, 824),
#  (818, 569),
#  (820, 7),
#  (824, 28),
#  (825, 29),
#  (833, 1),
#  (834, 103),
#  (835, 7),
#  (837, 2695),
#  (838, 10),
#  (840, 169),
#  (841, 78),
#  (842, 1),
#  (847, 18),
#  (849, 1),
#  (851, 235),
#  (852, 1),
#  (853, 5),
#  (854, 28),
#  (862, 1),
#  (863, 281),
#  (864, 118),
#  (865, 58),
#  (866, 10),
#  (873, 9),
#  (875, 22),
#  (876, 13),
#  (877, 381),
#  (878, 62),
#  (880, 1),
#  (882, 11),
#  (883, 24),
#  (884, 11),
#  (887, 46),
#  (888, 79),
#  (1867, 15),
#  (1869, 775),
#  (1870, 596),
#  (1871, 26),
#  (1873, 5),
#  (1874, 11),
#  (1875, 275),
#  (1876, 62),
#  (1877, 238),
#  (1878, 24),
#  (1879, 20),
#  (1880, 74),
#  (1881, 1),
#  (1882, 3),
#  (1885, 1),
#  (1889, 2),
#  (1890, 21),
#  (1891, 3),
#  (1892, 4),
#  (1894, 50),
#  (1895, 24),
#  (1897, 334),
#  (1902, 1),
#  (1903, 16),
#  (1904, 50),
#  (1906, 100),
#  (1907, 3),
#  (1908, 26),
#  (1909, 593),
#  (1910, 154),
#  (1911, 394),
#  (1912, 5),
#  (1913, 1),
#  (1915, 2),
#  (1917, 215),
#  (1918, 15),
#  (1919, 13),
#  (1920, 45),
#  (1921, 60),
#  (1922, 230),
#  (1923, 3),
#  (1924, 247),
#  (1927, 108),
#  (1928, 183),
#  (1929, 177),
#  (1932, 173),
#  (1933, 31),
#  (1934, 2),
#  (1935, 2),
#  (1936, 155),
#  (1937, 56),
#  (1938, 3),
#  (1940, 1),
#  (1941, 1),
#  (1943, 3),
#  (1944, 212),
#  (1945, 11),
#  (1946, 35),
#  (1948, 21),
#  (1949, 4),
#  (1950, 7),
#  (1953, 18),
#  (1954, 153),
#  (1955, 172),
#  (1956, 2),
#  (1957, 2347),
#  (1958, 5),
#  (1961, 19),
#  (1962, 38),
#  (1963, 561),
#  (1964, 144),
#  (1965, 210),
#  (1966, 1011),
#  (1967, 76),
#  (1968, 3),
#  (1969, 3),
#  (1970, 3),
#  (1971, 7),
#  (1973, 4),
#  (1974, 61),
#  (1975, 144),
#  (1976, 99),
#  (1979, 14),
#  (1982, 11),
#  (1983, 1),
#  (1984, 1),
#  (1985, 95),
#  (1987, 1),
#  (1988, 1),
#  (1989, 9),
#  (1990, 339),
#  (1999, 11),
#  (2001, 1),
#  (2002, 35),
#  (2003, 7),
#  (2005, 1),
#  (2006, 2),
#  (2007, 191),
#  (2008, 222),
#  (2009, 213),
#  (2010, 15),
#  (2011, 85),
#  (2012, 13),
#  (2015, 6),
#  (2016, 13),
#  (2019, 1),
#  (2026, 1),
#  (2027, 1),
#  (2029, 483),
#  (2030, 4),
#  (2036, 4),
#  (2038, 6),
#  (2039, 7),
#  (2042, 33),
#  (2043, 19),
#  (2044, 3),
#  (2047, 5),
#  (2048, 56),
#  ...]

# %%
# bag of words example in Economics, Econometrics and Finance
bow_doc_11 = bow_corpus[11]

for i in range(len(bow_doc_2)):
    print("Word {} (\"{}\") appears {} time.".format(bow_doc_11[i][0], 
                                                     dictionary[bow_doc_11[i][0]], 
                                                     bow_doc_11[i][1]))
# Out:
# Word 8 ("abdomin") appears 4 time.
# Word 10 ("aberr") appears 6 time.
# Word 11 ("abil") appears 184 time.
# Word 13 ("abiot") appears 2 time.
# Word 14 ("abl") appears 172 time.
# Word 15 ("ablat") appears 12 time.
# Word 17 ("abnorm") appears 20 time.
# Word 21 ("abras") appears 11 time.
# Word 23 ("abrupt") appears 10 time.
# Word 25 ("absenc") appears 42 time.
# Word 26 ("absent") appears 6 time.
# Word 28 ("absolut") appears 35 time.
# Word 29 ("absorb") appears 105 time.
# Word 30 ("absorpt") appears 154 time.
# Word 32 ("abstract") appears 9 time.
# Word 34 ("abund") appears 17 time.
# Word 35 ("abus") appears 1 time.
# Word 38 ("acad") appears 1 time.
# Word 39 ("academ") appears 7 time.
# Word 41 ("acceler") appears 86 time.
# Word 42 ("accept") appears 52 time.
# Word 43 ("acceptor") appears 13 time.
# Word 44 ("access") appears 214 time.
# Word 45 ("accid") appears 4 time.
# Word 47 ("accommod") appears 20 time.
# Word 48 ("accompani") appears 16 time.
# Word 49 ("accomplish") appears 36 time.
# Word 50 ("accord") appears 200 time.
# Word 51 ("account") appears 154 time.
# Word 56 ("accumul") appears 86 time.
# Word 57 ("accur") appears 338 time.
# Word 58 ("accuraci") appears 330 time.
# Word 62 ("acet") appears 14 time.
# Word 67 ("acetyl") appears 17 time.
# Word 68 ("acetylcholin") appears 1 time.
# Word 71 ("achiev") appears 1144 time.
# Word 73 ("acid") appears 203 time.
# Word 74 ("acidif") appears 1 time.
# Word 76 ("acidifi") appears 1 time.
# Word 81 ("acoust") appears 68 time.
# Word 83 ("acquir") appears 48 time.
# Word 84 ("acquisit") appears 32 time.
# Word 86 ("acryl") appears 11 time.
# Word 87 ("act") appears 50 time.
# Word 90 ("actin") appears 8 time.
# Word 93 ("actinomycet") appears 3 time.
# Word 94 ("action") appears 49 time.
# Word 95 ("activ") appears 758 time.
# Word 96 ("activat") appears 3 time.
# Word 99 ("actomyosin") appears 5 time.
# Word 100 ("actor") appears 1 time.
# Word 102 ("actual") appears 63 time.
# Word 103 ("actuat") appears 130 time.
# Word 104 ("acut") appears 7 time.
# Word 110 ("adapt") appears 349 time.
# Word 111 ("adaptor") appears 1 time.
# Word 113 ("add") appears 111 time.
# Word 114 ("adder") appears 12 time.
# Word 117 ("addit") appears 711 time.
# Word 118 ("address") appears 216 time.
# Word 119 ("adductor") appears 1 time.
# Word 120 ("adenin") appears 2 time.
# Word 121 ("adenocarcinoma") appears 3 time.
# Word 122 ("adenosin") appears 2 time.
# Word 126 ("adequ") appears 25 time.
# Word 128 ("adhes") appears 119 time.
# Word 130 ("adiabat") appears 2 time.
# Word 131 ("adipocyt") appears 3 time.
# Word 132 ("adipos") appears 10 time.
# Word 133 ("adjac") appears 45 time.
# Word 134 ("adjust") appears 150 time.
# Word 135 ("adjuv") appears 5 time.
# Word 137 ("administ") appears 12 time.
# Word 138 ("administr") appears 25 time.
# Word 140 ("admiss") appears 9 time.
# Word 141 ("admit") appears 8 time.
# Word 144 ("adopt") appears 172 time.
# Word 147 ("adrenerg") appears 1 time.
# Word 149 ("adsorb") appears 22 time.
# Word 150 ("adsorpt") appears 70 time.
# Word 151 ("adult") appears 2 time.
# Word 153 ("advanc") appears 171 time.
# Word 154 ("advantag") appears 293 time.
# Word 155 ("advent") appears 6 time.
# Word 156 ("advers") appears 31 time.
# Word 158 ("advis") appears 1 time.
# Word 163 ("aerial") appears 7 time.
# Word 164 ("aerob") appears 2 time.
# Word 166 ("aerodynam") appears 4 time.
# Word 168 ("aerosol") appears 1 time.
# Word 169 ("aeruginosa") appears 4 time.
# Word 170 ("aesthet") appears 4 time.
# Word 172 ("affect") appears 195 time.
# Word 175 ("affin") appears 41 time.
# Word 178 ("afford") appears 15 time.
# Word 190 ("aforement") appears 12 time.
# Word 192 ("africa") appears 2 time.
# Word 194 ("agar") appears 4 time.
# Word 195 ("agaros") appears 4 time.
# Word 198 ("age") appears 108 time.
# Word 199 ("agenc") appears 11 time.
# Word 202 ("agent") appears 125 time.
# Word 203 ("agglutinin") appears 1 time.
# Word 204 ("aggrav") appears 2 time.
# Word 205 ("aggreg") appears 91 time.
# Word 207 ("aggress") appears 4 time.
# Word 208 ("agil") appears 6 time.
# Word 213 ("agre") appears 42 time.
# Word 214 ("agreeabl") appears 1 time.
# Word 215 ("agreement") appears 173 time.
# Word 216 ("agricultur") appears 4 time.
# Word 221 ("ahead") appears 6 time.
# Word 224 ("aid") appears 47 time.
# Word 226 ("aim") appears 115 time.
# Word 228 ("airborn") appears 8 time.
# Word 229 ("airflow") appears 1 time.
# Word 231 ("airway") appears 3 time.
# Word 232 ("akin") appears 2 time.
# Word 234 ("alanin") appears 1 time.
# Word 236 ("alarm") appears 40 time.
# Word 239 ("alba") appears 4 time.
# Word 241 ("alcohol") appears 24 time.
# Word 246 ("alert") appears 7 time.
# Word 249 ("alga") appears 1 time.
# Word 251 ("algin") appears 29 time.
# Word 252 ("algorithm") appears 1116 time.
# Word 253 ("align") appears 98 time.
# Word 255 ("alik") appears 4 time.
# Word 256 ("aliphat") appears 1 time.
# Word 257 ("aliv") appears 3 time.
# Word 260 ("alkalin") appears 30 time.
# Word 264 ("alkyl") appears 5 time.
# Word 271 ("allevi") appears 32 time.
# Word 275 ("allo") appears 2 time.
# Word 277 ("alloc") appears 153 time.
# Word 279 ("allogen") appears 2 time.
# Word 283 ("alloster") appears 2 time.
# Word 284 ("allotrop") appears 4 time.
# Word 285 ("allow") appears 462 time.
# Word 288 ("alongsid") appears 1 time.
# Word 292 ("alpaca") appears 1 time.
# Word 293 ("alpha") appears 3 time.
# Word 299 ("alter") appears 52 time.
# Word 300 ("altern") appears 199 time.
# Word 303 ("altitud") appears 7 time.
# Word 304 ("altogeth") appears 1 time.
# Word 308 ("aluminum") appears 36 time.
# Word 310 ("alveolar") appears 2 time.
# Word 311 ("alzheim") appears 1 time.
# Word 313 ("amalgam") appears 1 time.
# Word 315 ("ambient") appears 40 time.
# Word 316 ("ambigu") appears 32 time.
# Word 320 ("amelior") appears 1 time.
# Word 321 ("amen") appears 6 time.
# Word 322 ("amend") appears 3 time.
# Word 324 ("american") appears 2 time.
# Word 325 ("amid") appears 9 time.
# Word 326 ("amin") appears 15 time.
# Word 327 ("amino") appears 32 time.
# Word 328 ("aminoacyl") appears 3 time.
# Word 330 ("aminoglycosid") appears 2 time.
# Word 333 ("ammonia") appears 1 time.
# Word 335 ("ammonium") appears 7 time.
# Word 340 ("amorph") appears 57 time.
# Word 341 ("amount") appears 26 time.
# Word 342 ("amp") appears 6 time.
# Word 350 ("amphiphil") appears 17 time.
# Word 354 ("ampl") appears 4 time.
# Word 356 ("amplif") appears 25 time.
# Word 357 ("amplifi") appears 197 time.
# Word 358 ("amplitud") appears 146 time.
# Word 364 ("amyloid") appears 7 time.
# Word 368 ("anabol") appears 1 time.
# Word 370 ("anaerob") appears 1 time.
# Word 372 ("analog") appears 105 time.
# Word 373 ("analogu") appears 28 time.
# Word 374 ("analys") appears 208 time.
# Word 375 ("analysi") appears 976 time.
# Word 376 ("analyt") appears 354 time.
# Word 377 ("analyz") appears 453 time.
# Word 381 ("anatom") appears 14 time.
# Word 382 ("anatomi") appears 1 time.
# Word 387 ("anchor") appears 32 time.
# Word 388 ("anchorag") appears 2 time.
# Word 390 ("ancillari") appears 1 time.
# Word 394 ("anderson") appears 1 time.
# Word 396 ("android") appears 3 time.
# Word 397 ("anemia") appears 2 time.
# Word 402 ("angina") appears 1 time.
# Word 404 ("angiogen") appears 3 time.
# Word 405 ("angiogenesi") appears 3 time.
# Word 406 ("angiographi") appears 2 time.
# Word 410 ("angl") appears 260 time.
# Word 412 ("angular") appears 59 time.
# Word 416 ("anim") appears 22 time.
# Word 417 ("anion") appears 14 time.
# Word 421 ("anisotrop") appears 46 time.
# Word 422 ("anisotropi") appears 45 time.
# Word 423 ("ankl") appears 5 time.
# Word 424 ("anneal") appears 42 time.
# Word 426 ("annot") appears 6 time.
# Word 428 ("annual") appears 3 time.
# Word 430 ("anod") appears 94 time.
# Word 433 ("anomal") appears 19 time.
# Word 434 ("anomali") appears 8 time.
# Word 438 ("anova") appears 1 time.
# Word 440 ("answer") appears 6 time.
# Word 442 ("antagon") appears 2 time.
# Word 443 ("antagonist") appears 1 time.
# Word 447 ("antenna") appears 1783 time.
# Word 448 ("anterior") appears 2 time.
# Word 450 ("anthocyanin") appears 4 time.
# Word 454 ("anthropometr") appears 1 time.
# Word 455 ("anti") appears 58 time.
# Word 459 ("antiapoptot") appears 1 time.
# Word 460 ("antibacteri") appears 53 time.
# Word 461 ("antibiot") appears 18 time.
# Word 462 ("antibodi") appears 42 time.
# Word 463 ("anticanc") appears 16 time.
# Word 465 ("anticip") appears 13 time.
# Word 474 ("antifung") appears 2 time.
# Word 475 ("antigen") appears 23 time.
# Word 477 ("antimicrobi") appears 32 time.
# Word 480 ("antioxid") appears 14 time.
# Word 481 ("antiparallel") appears 7 time.
# Word 483 ("antireflect") appears 5 time.
# Word 487 ("antisens") appears 7 time.
# Word 490 ("antitoxin") appears 2 time.
# Word 491 ("antitumor") appears 8 time.
# Word 493 ("antivir") appears 1 time.
# Word 495 ("anxieti") appears 3 time.
# Word 498 ("aortic") appears 1 time.
# Word 499 ("apart") appears 16 time.
# Word 500 ("apatit") appears 18 time.
# Word 504 ("apertur") appears 135 time.
# Word 506 ("apex") appears 5 time.
# Word 510 ("apic") appears 3 time.
# Word 514 ("apo") appears 1 time.
# Word 520 ("apolar") appears 1 time.
# Word 521 ("apolipoprotein") appears 1 time.
# Word 527 ("apoptosi") appears 16 time.
# Word 528 ("apoptot") appears 6 time.
# Word 529 ("appar") appears 29 time.
# Word 530 ("apparatus") appears 7 time.
# Word 531 ("appeal") appears 14 time.
# Word 532 ("appear") appears 76 time.
# Word 533 ("appendag") appears 1 time.
# Word 536 ("appli") appears 628 time.
# Word 537 ("applic") appears 1393 time.
# Word 541 ("apposit") appears 1 time.
# Word 542 ("apprais") appears 2 time.
# Word 543 ("appreci") appears 6 time.
# Word 544 ("approach") appears 1066 time.
# Word 545 ("appropri") appears 128 time.
# Word 546 ("approv") appears 11 time.
# Word 547 ("approxim") appears 283 time.
# Word 549 ("april") appears 4 time.
# Word 550 ("aqua") appears 2 time.
# Word 552 ("aquat") appears 4 time.
# Word 553 ("aqueous") appears 39 time.
# Word 555 ("arab") appears 1 time.
# Word 557 ("arabidopsi") appears 2 time.
# Word 559 ("aragonit") appears 4 time.
# Word 560 ("arbitrari") appears 84 time.
# Word 561 ("arbitrarili") appears 17 time.
# Word 562 ("arbor") appears 1 time.
# Word 566 ("arch") appears 2 time.
# Word 568 ("archaeal") appears 1 time.
# Word 571 ("archetyp") appears 1 time.
# Word 572 ("architectur") appears 242 time.
# Word 575 ("arctic") appears 1 time.
# Word 577 ("area") appears 454 time.
# Word 578 ("areal") appears 1 time.
# Word 579 ("arena") appears 1 time.
# Word 581 ("argu") appears 3 time.
# Word 582 ("arguabl") appears 3 time.
# Word 583 ("argument") appears 8 time.
# Word 585 ("aris") appears 54 time.
# Word 588 ("arm") appears 25 time.
# Word 592 ("aromat") appears 10 time.
# Word 594 ("arous") appears 2 time.
# Word 595 ("arrang") appears 87 time.
# Word 596 ("array") appears 815 time.
# Word 597 ("arrest") appears 10 time.
# Word 599 ("arrhenius") appears 6 time.
# Word 601 ("arrhythmia") appears 1 time.
# Word 603 ("arriv") appears 52 time.
# Word 606 ("arsenid") appears 3 time.
# Word 609 ("arteri") appears 23 time.
# Word 617 ("articl") appears 57 time.
# Word 618 ("articul") appears 7 time.
# Word 619 ("articular") appears 5 time.
# Word 621 ("artifact") appears 20 time.
# Word 622 ("artifici") appears 91 time.
# Word 628 ("aryl") appears 1 time.
# Word 632 ("ascend") appears 1 time.
# Word 633 ("ascertain") appears 5 time.
# Word 636 ("ascorb") appears 7 time.
# Word 637 ("ascrib") appears 7 time.
# Word 639 ("asia") appears 1 time.
# Word 642 ("asid") appears 3 time.
# Word 643 ("ask") appears 4 time.
# Word 647 ("aspart") appears 2 time.
# Word 648 ("aspect") appears 102 time.
# Word 652 ("aspir") appears 2 time.
# Word 654 ("assay") appears 83 time.
# Word 655 ("assembl") appears 275 time.
# Word 657 ("assert") appears 2 time.
# Word 658 ("assess") appears 185 time.
# Word 659 ("assign") appears 47 time.
# Word 661 ("assist") appears 112 time.
# Word 662 ("associ") appears 208 time.
# Word 664 ("assum") appears 106 time.
# Word 665 ("assumpt") appears 81 time.
# Word 667 ("asthma") appears 1 time.
# Word 669 ("astrocyt") appears 2 time.
# Word 670 ("astronom") appears 2 time.
# Word 674 ("asymmetr") appears 95 time.
# Word 675 ("asymmetri") appears 12 time.
# Word 677 ("asynchron") appears 35 time.
# Word 680 ("atcc") appears 3 time.
# Word 682 ("atherosclerosi") appears 6 time.
# Word 683 ("atherosclerot") appears 3 time.
# Word 687 ("atlas") appears 3 time.
# Word 689 ("atmospher") appears 31 time.
# Word 691 ("atom") appears 179 time.
# Word 692 ("atomist") appears 14 time.
# Word 699 ("atrial") appears 1 time.
# Word 700 ("attach") appears 84 time.
# Word 701 ("attack") appears 100 time.
# Word 702 ("attain") appears 46 time.
# Word 703 ("attempt") appears 24 time.
# Word 705 ("attent") appears 86 time.
# Word 706 ("attenu") appears 69 time.
# Word 707 ("attest") appears 1 time.
# Word 708 ("attitud") appears 25 time.
# Word 709 ("attract") appears 118 time.
# Word 711 ("attribut") appears 98 time.
# Word 715 ("audit") appears 12 time.
# Word 716 ("auditori") appears 5 time.
# Word 717 ("augment") appears 30 time.
# Word 720 ("aureus") appears 22 time.
# Word 725 ("australia") appears 1 time.
# Word 726 ("australian") appears 3 time.
# Word 728 ("authent") appears 41 time.
# Word 730 ("author") appears 111 time.
# Word 734 ("auto") appears 12 time.
# Word 738 ("autogen") appears 1 time.
# Word 741 ("autolog") appears 4 time.
# Word 742 ("autom") appears 50 time.
# Word 743 ("automat") appears 86 time.
# Word 744 ("automata") appears 2 time.
# Word 745 ("autonom") appears 40 time.
# Word 751 ("autoregul") appears 4 time.
# Word 755 ("auxiliari") appears 44 time.
# Word 757 ("avail") appears 200 time.
# Word 759 ("avenu") appears 7 time.
# Word 760 ("averag") appears 346 time.
# Word 762 ("avert") appears 2 time.
# Word 764 ("avid") appears 2 time.
# Word 765 ("avoid") appears 149 time.
# Word 767 ("awar") appears 34 time.
# Word 768 ("away") appears 11 time.
# Word 769 ("ax") appears 16 time.
# Word 770 ("axi") appears 85 time.
# Word 771 ("axial") appears 106 time.
# Word 773 ("axillari") appears 7 time.
# Word 775 ("axon") appears 7 time.
# Word 779 ("azobenzen") appears 4 time.
# Word 785 ("bacillus") appears 3 time.
# Word 786 ("backbon") appears 5 time.
# Word 788 ("background") appears 83 time.
# Word 789 ("backward") appears 22 time.
# Word 791 ("bacteri") appears 59 time.
# Word 792 ("bacteria") appears 49 time.
# Word 793 ("bactericid") appears 10 time.
# Word 794 ("bacteriophag") appears 2 time.
# Word 795 ("bacteriostat") appears 1 time.
# Word 796 ("bacterium") appears 5 time.
# Word 806 ("bake") appears 2 time.
# Word 809 ("balanc") appears 171 time.
# Word 810 ("balb") appears 1 time.
# Word 817 ("band") appears 824 time.
# Word 818 ("bandwidth") appears 569 time.
# Word 820 ("bank") appears 7 time.
# Word 824 ("barcod") appears 28 time.
# Word 825 ("bare") appears 29 time.
# Word 833 ("barrel") appears 1 time.
# Word 834 ("barrier") appears 103 time.
# Word 835 ("basal") appears 7 time.
# Word 837 ("base") appears 2695 time.
# Word 838 ("baselin") appears 10 time.
# Word 840 ("basi") appears 169 time.
# Word 841 ("basic") appears 78 time.
# Word 842 ("basin") appears 1 time.
# Word 847 ("batch") appears 18 time.
# Word 849 ("bath") appears 1 time.
# Word 851 ("batteri") appears 235 time.
# Word 852 ("battlefield") appears 1 time.
# Word 853 ("bay") appears 5 time.
# Word 854 ("bayesian") appears 28 time.
# Word 862 ("beak") appears 1 time.
# Word 863 ("beam") appears 281 time.
# Word 864 ("beamform") appears 118 time.
# Word 865 ("bear") appears 58 time.
# Word 866 ("beat") appears 10 time.
# Word 873 ("beer") appears 9 time.
# Word 875 ("begin") appears 22 time.
# Word 876 ("behav") appears 13 time.
# Word 877 ("behavior") appears 381 time.
# Word 878 ("behaviour") appears 62 time.
# Word 880 ("beij") appears 1 time.
# Word 882 ("belief") appears 11 time.
# Word 883 ("believ") appears 24 time.
# Word 884 ("belong") appears 11 time.
# Word 887 ("benchmark") appears 46 time.
# Word 888 ("bend") appears 79 time.
# Word 889 ("beneath") appears 2 time.
# Word 890 ("benefici") appears 40 time.
# Word 892 ("benefit") appears 136 time.
# Word 894 ("benign") appears 8 time.
# Word 898 ("benthic") appears 1 time.
# Word 900 ("benzen") appears 3 time.
# Word 904 ("best") appears 112 time.
# Word 906 ("beta") appears 7 time.
# Word 908 ("better") appears 276 time.
# Word 915 ("bias") appears 205 time.
# Word 918 ("bidirect") appears 61 time.
# Word 921 ("bifunct") appears 5 time.
# Word 922 ("bifurc") appears 2 time.
# Word 926 ("bilater") appears 16 time.
# Word 928 ("bilay") appears 48 time.
# Word 931 ("bill") appears 1 time.
# Word 932 ("billion") appears 3 time.
# Word 933 ("bimod") appears 7 time.
# Word 934 ("bimolecular") appears 1 time.
# Word 936 ("binari") appears 82 time.
# Word 937 ("binaur") appears 1 time.
# Word 938 ("bind") appears 213 time.
# Word 940 ("bioactiv") appears 69 time.
# Word 941 ("bioartifici") appears 3 time.
# Word 942 ("bioassay") appears 2 time.
# Word 943 ("bioavail") appears 5 time.
# Word 945 ("biochem") appears 14 time.
# Word 946 ("biochemistri") appears 4 time.
# Word 947 ("biocompat") appears 44 time.
# Word 950 ("biodegrad") appears 41 time.
# Word 951 ("biodistribut") appears 13 time.
# Word 957 ("biofilm") appears 28 time.
# Word 958 ("biofuel") appears 3 time.
# Word 960 ("biogen") appears 9 time.
# Word 961 ("biogenesi") appears 1 time.
# Word 971 ("biolog") appears 197 time.
# Word 973 ("bioluminesc") appears 3 time.
# Word 975 ("biomark") appears 14 time.
# Word 976 ("biomass") appears 6 time.
# Word 977 ("biomateri") appears 46 time.
# Word 978 ("biomechan") appears 11 time.
# Word 979 ("biomed") appears 95 time.
# Word 981 ("biomimet") appears 25 time.
# Word 982 ("biominer") appears 1 time.
# Word 983 ("biomolecul") appears 23 time.
# Word 984 ("biophys") appears 6 time.
# Word 985 ("biopolym") appears 7 time.
# Word 986 ("bioprocess") appears 2 time.
# Word 988 ("biopsi") appears 6 time.
# Word 989 ("bioreactor") appears 5 time.
# Word 990 ("bioremedi") appears 1 time.
# Word 991 ("biosens") appears 19 time.
# Word 992 ("biosensor") appears 50 time.
# Word 999 ("biosynthes") appears 2 time.
# Word 1000 ("biosynthesi") appears 12 time.
# Word 1001 ("biosynthet") appears 6 time.
# Word 1002 ("biosystem") appears 1 time.
# Word 1003 ("biotechnolog") appears 7 time.
# Word 1005 ("biotin") appears 5 time.
# Word 1007 ("biphas") appears 4 time.
# Word 1009 ("bipolar") appears 47 time.
# Word 1012 ("bird") appears 3 time.
# Word 1015 ("birth") appears 6 time.
# Word 1017 ("bismuth") appears 1 time.
# Word 1018 ("bisphenol") appears 2 time.
# Word 1019 ("bit") appears 31 time.
# Word 1021 ("bival") appears 1 time.
# Word 1022 ("bivalv") appears 1 time.
# Word 1024 ("black") appears 20 time.
# Word 1025 ("bladder") appears 4 time.
# Word 1026 ("blade") appears 1 time.
# Word 1028 ("blast") appears 7 time.
# Word 1033 ("bleach") appears 2 time.
# Word 1036 ("blend") appears 42 time.
# Word 1041 ("blind") appears 32 time.
# Word 1042 ("block") appears 202 time.
# Word 1043 ("blockad") appears 3 time.
# Word 1045 ("blocker") appears 8 time.
# Word 1046 ("blog") appears 2 time.
# Word 1047 ("blood") appears 69 time.
# Word 1051 ("blot") appears 2 time.
# Word 1053 ("blue") appears 41 time.
# Word 1055 ("blunt") appears 1 time.
# Word 1059 ("board") appears 67 time.
# Word 1062 ("bodi") appears 214 time.
# Word 1066 ("bold") appears 1 time.
# Word 1073 ("bond") appears 117 time.
# Word 1074 ("bone") appears 200 time.
# Word 1077 ("bonus") appears 3 time.
# Word 1078 ("boolean") appears 8 time.
# Word 1079 ("boost") appears 151 time.
# Word 1080 ("bootstrap") appears 1 time.
# Word 1081 ("border") appears 8 time.
# Word 1084 ("boron") appears 25 time.
# Word 1086 ("bose") appears 1 time.
# Word 1090 ("bottl") appears 1 time.
# Word 1091 ("bottleneck") appears 25 time.
# Word 1092 ("boundari") appears 184 time.
# Word 1096 ("bovin") appears 23 time.
# Word 1097 ("bowel") appears 1 time.
# Word 1098 ("box") appears 6 time.
# Word 1103 ("brace") appears 1 time.
# Word 1108 ("braid") appears 5 time.
# Word 1109 ("brain") appears 50 time.
# Word 1113 ("branch") appears 71 time.
# Word 1115 ("brand") appears 2 time.
# Word 1121 ("bread") appears 8 time.
# Word 1122 ("breadth") appears 2 time.
# Word 1123 ("break") appears 48 time.
# Word 1124 ("breakdown") appears 119 time.
# Word 1126 ("breakup") appears 3 time.
# Word 1127 ("breast") appears 50 time.
# Word 1130 ("bret") appears 5 time.
# Word 1133 ("bridg") appears 156 time.
# Word 1134 ("brief") appears 83 time.
# Word 1135 ("briefli") appears 13 time.
# Word 1136 ("bright") appears 29 time.
# Word 1137 ("brighter") appears 2 time.
# Word 1139 ("brillouin") appears 5 time.
# Word 1140 ("brine") appears 1 time.
# Word 1141 ("bring") appears 32 time.
# Word 1144 ("britain") appears 1 time.
# Word 1146 ("broad") appears 68 time.
# Word 1147 ("broadband") appears 117 time.
# Word 1148 ("broaden") appears 16 time.
# Word 1149 ("broader") appears 8 time.
# Word 1151 ("broker") appears 1 time.
# Word 1154 ("bronchoalveolar") appears 2 time.
# Word 1158 ("brown") appears 1 time.
# Word 1159 ("brownian") appears 12 time.
# Word 1168 ("bubbl") appears 24 time.
# Word 1172 ("budget") appears 20 time.
# Word 1174 ("buffer") appears 94 time.
# Word 1176 ("build") appears 217 time.
# Word 1177 ("buildup") appears 1 time.
# Word 1178 ("bulb") appears 2 time.
# Word 1179 ("bulk") appears 105 time.
# Word 1180 ("bulki") appears 18 time.
# Word 1184 ("bundl") appears 22 time.
# Word 1190 ("burden") appears 23 time.
# Word 1192 ("buri") appears 19 time.
# Word 1197 ("burrow") appears 1 time.
# Word 1198 ("burst") appears 30 time.
# Word 1199 ("bursti") appears 1 time.
# Word 1200 ("bus") appears 2 time.
# Word 1202 ("busi") appears 4 time.
# Word 1206 ("butyr") appears 2 time.
# Word 1210 ("bypass") appears 13 time.
# Word 1211 ("byproduct") appears 5 time.
# Word 1215 ("cabl") appears 93 time.
# Word 1219 ("cadav") appears 1 time.
# Word 1222 ("cadmium") appears 6 time.
# Word 1224 ("caffeic") appears 2 time.
# Word 1226 ("cage") appears 19 time.
# Word 1230 ("calcif") appears 3 time.
# Word 1234 ("calcit") appears 3 time.
# Word 1236 ("calcium") appears 35 time.
# Word 1238 ("calcul") appears 401 time.
# Word 1239 ("calendar") appears 3 time.
# Word 1240 ("calibr") appears 90 time.
# Word 1241 ("california") appears 1 time.
# Word 1243 ("call") appears 121 time.
# Word 1250 ("calorimetri") appears 15 time.
# Word 1258 ("camara") appears 10 time.
# Word 1262 ("camera") appears 71 time.
# Word 1268 ("campaign") appears 6 time.
# Word 1272 ("canada") appears 5 time.
# Word 1273 ("canadian") appears 1 time.
# Word 1274 ("canal") appears 6 time.
# Word 1276 ("cancel") appears 72 time.
# Word 1277 ("cancer") appears 155 time.
# Word 1278 ("candid") appears 89 time.
# Word 1280 ("canin") appears 4 time.
# Word 1284 ("canon") appears 10 time.
# Word 1285 ("canopi") appears 2 time.
# Word 1288 ("canyon") appears 5 time.
# Word 1289 ("cap") appears 24 time.
# Word 1291 ("capabl") appears 384 time.
# Word 1292 ("capac") appears 219 time.
# Word 1293 ("capacit") appears 226 time.
# Word 1294 ("capacitor") appears 312 time.
# Word 1296 ("capillar") appears 1 time.
# Word 1297 ("capillari") appears 15 time.
# Word 1298 ("capit") appears 3 time.
# Word 1305 ("capsid") appears 1 time.
# Word 1306 ("capsul") appears 25 time.
# Word 1309 ("captur") appears 118 time.
# Word 1312 ("carbid") appears 17 time.
# Word 1314 ("carbohydr") appears 1 time.
# Word 1315 ("carbon") appears 238 time.
# Word 1317 ("carboxi") appears 1 time.
# Word 1319 ("carboxyl") appears 21 time.
# Word 1320 ("carcinogen") appears 1 time.
# Word 1322 ("carcinoma") appears 9 time.
# Word 1323 ("card") appears 8 time.
# Word 1324 ("cardiac") appears 13 time.
# Word 1325 ("cardin") appears 1 time.
# Word 1331 ("cardiomyocyt") appears 6 time.
# Word 1332 ("cardiomyopathi") appears 1 time.
# Word 1333 ("cardiopulmonari") appears 2 time.
# Word 1336 ("cardiovascular") appears 25 time.
# Word 1337 ("care") appears 41 time.
# Word 1341 ("cargo") appears 21 time.
# Word 1342 ("cari") appears 3 time.
# Word 1344 ("cariogen") appears 2 time.
# Word 1351 ("carotenoid") appears 1 time.
# Word 1352 ("carotid") appears 3 time.
# Word 1355 ("carri") appears 206 time.
# Word 1356 ("carrier") appears 220 time.
# Word 1358 ("cartilag") appears 17 time.
# Word 1359 ("cartridg") appears 2 time.
# Word 1361 ("cascad") appears 79 time.
# Word 1363 ("case") appears 432 time.
# Word 1367 ("caspas") appears 2 time.
# Word 1370 ("cassett") appears 5 time.
# Word 1373 ("cast") appears 37 time.
# Word 1375 ("catabol") appears 2 time.
# Word 1378 ("catalysi") appears 15 time.
# Word 1379 ("catalyst") appears 66 time.
# Word 1380 ("catalyt") appears 66 time.
# Word 1381 ("catalyz") appears 10 time.
# Word 1382 ("cataract") appears 1 time.
# Word 1384 ("catastroph") appears 3 time.
# Word 1385 ("catch") appears 1 time.
# Word 1388 ("catecholamin") appears 1 time.
# Word 1389 ("categor") appears 20 time.
# Word 1390 ("categori") appears 20 time.
# Word 1393 ("caterpillar") appears 1 time.
# Word 1396 ("cathet") appears 8 time.
# Word 1397 ("cathod") appears 46 time.
# Word 1398 ("cation") appears 23 time.
# Word 1402 ("caudal") appears 1 time.
# Word 1404 ("caus") appears 320 time.
# Word 1405 ("causal") appears 16 time.
# Word 1406 ("causat") appears 1 time.
# Word 1410 ("caviti") appears 172 time.
# Word 1419 ("cdna") appears 2 time.
# Word 1421 ("cdrs") appears 1 time.
# Word 1422 ("cdse") appears 23 time.
# Word 1433 ("cell") appears 1433 time.
# Word 1434 ("cellular") appears 142 time.
# Word 1435 ("cellulos") appears 16 time.
# Word 1437 ("cement") appears 12 time.
# Word 1439 ("censor") appears 5 time.
# Word 1442 ("center") appears 159 time.
# Word 1444 ("centr") appears 48 time.
# Word 1445 ("central") appears 75 time.
# Word 1446 ("centrifug") appears 5 time.
# Word 1447 ("centromer") appears 1 time.
# Word 1448 ("centuri") appears 3 time.
# Word 1450 ("ceram") appears 42 time.
# Word 1452 ("cerebellar") appears 4 time.
# Word 1455 ("cerebr") appears 2 time.
# Word 1456 ("cerebrospin") appears 2 time.
# Word 1461 ("cerevisia") appears 17 time.
# Word 1464 ("cerium") appears 1 time.
# Word 1467 ("certain") appears 93 time.
# Word 1468 ("certainti") appears 2 time.
# Word 1469 ("certifi") appears 2 time.
# Word 1480 ("chain") appears 88 time.
# Word 1481 ("chalcogenid") appears 5 time.
# Word 1482 ("challeng") appears 281 time.
# Word 1483 ("chamber") appears 37 time.
# Word 1485 ("chanc") appears 5 time.
# Word 1486 ("chang") appears 498 time.
# Word 1488 ("channel") appears 892 time.
# Word 1491 ("chao") appears 4 time.
# Word 1492 ("chaotic") appears 7 time.
# Word 1497 ("charact") appears 21 time.
# Word 1498 ("character") appears 281 time.
# Word 1499 ("characteris") appears 26 time.
# Word 1500 ("characterist") appears 645 time.
# Word 1502 ("charg") appears 550 time.
# Word 1504 ("chart") appears 4 time.
# Word 1505 ("chase") appears 3 time.
# Word 1507 ("cheaper") appears 2 time.
# Word 1511 ("check") appears 34 time.
# Word 1512 ("checkpoint") appears 1 time.
# Word 1514 ("chelat") appears 1 time.
# Word 1516 ("chemic") appears 255 time.
# Word 1519 ("chemistri") appears 38 time.
# Word 1520 ("chemo") appears 1 time.
# Word 1521 ("chemoattract") appears 1 time.
# Word 1524 ("chemokin") appears 1 time.
# Word 1531 ("chemotherapi") appears 19 time.
# Word 1533 ("chest") appears 1 time.
# Word 1538 ("chief") appears 1 time.
# Word 1539 ("chiefli") appears 4 time.
# Word 1544 ("children") appears 1 time.
# Word 1545 ("chill") appears 3 time.
# Word 1546 ("chimer") appears 2 time.
# Word 1550 ("china") appears 17 time.
# Word 1552 ("chines") appears 8 time.
# Word 1553 ("chip") appears 192 time.
# Word 1554 ("chiral") appears 7 time.
# Word 1556 ("chitin") appears 12 time.
# Word 1558 ("chitosan") appears 89 time.
# Word 1560 ("chlorid") appears 17 time.
# Word 1561 ("chloroform") appears 2 time.
# Word 1562 ("chlorophyl") appears 1 time.
# Word 1566 ("choic") appears 63 time.
# Word 1567 ("chol") appears 2 time.
# Word 1568 ("cholera") appears 2 time.
# Word 1569 ("cholesterol") appears 8 time.
# Word 1573 ("chondrocyt") appears 6 time.
# Word 1576 ("choos") appears 77 time.
# Word 1583 ("chromatin") appears 1 time.
# Word 1584 ("chromatographi") appears 13 time.
# Word 1585 ("chromium") appears 3 time.
# Word 1588 ("chromophor") appears 6 time.
# Word 1590 ("chromosom") appears 6 time.
# Word 1591 ("chronic") appears 9 time.
# Word 1592 ("chronolog") appears 2 time.
# Word 1600 ("cilia") appears 1 time.
# Word 1615 ("circl") appears 15 time.
# Word 1616 ("circuit") appears 753 time.
# Word 1617 ("circuitri") appears 18 time.
# Word 1618 ("circul") appears 47 time.
# Word 1619 ("circular") appears 182 time.
# Word 1620 ("circulatori") appears 5 time.
# Word 1624 ("circumst") appears 9 time.
# Word 1625 ("circumv") appears 11 time.
# Word 1627 ("cisplatin") appears 8 time.
# Word 1633 ("citi") appears 15 time.
# Word 1634 ("citizen") appears 1 time.
# Word 1638 ("civil") appears 3 time.
# Word 1642 ("claim") appears 6 time.
# Word 1643 ("clamp") appears 54 time.
# Word 1645 ("clarifi") appears 23 time.
# Word 1646 ("class") appears 160 time.
# Word 1647 ("classic") appears 71 time.
# Word 1648 ("classif") appears 109 time.
# Word 1649 ("classifi") appears 84 time.
# Word 1653 ("claw") appears 3 time.
# Word 1654 ("clay") appears 8 time.
# Word 1655 ("clean") appears 35 time.
# Word 1656 ("clear") appears 79 time.
# Word 1657 ("clearanc") appears 9 time.
# Word 1659 ("cleav") appears 3 time.
# Word 1660 ("cleavabl") appears 1 time.
# Word 1661 ("cleavag") appears 4 time.
# Word 1662 ("click") appears 8 time.
# Word 1663 ("client") appears 17 time.
# Word 1665 ("climat") appears 4 time.
# Word 1667 ("climb") appears 4 time.
# Word 1668 ("clinic") appears 105 time.
# Word 1670 ("clinician") appears 3 time.
# Word 1673 ("clip") appears 6 time.
# Word 1674 ("cloak") appears 27 time.
# Word 1675 ("clock") appears 62 time.
# Word 1676 ("clockwis") appears 1 time.
# Word 1678 ("clonal") appears 1 time.
# Word 1679 ("clone") appears 9 time.
# Word 1680 ("close") appears 342 time.
# Word 1681 ("closer") appears 9 time.
# Word 1684 ("closur") appears 11 time.
# Word 1685 ("cloth") appears 8 time.
# Word 1687 ("cloud") appears 69 time.
# Word 1693 ("clue") appears 2 time.
# Word 1694 ("clump") appears 2 time.
# Word 1695 ("cluster") appears 106 time.
# Word 1696 ("clutch") appears 5 time.
# Word 1698 ("cmax") appears 2 time.
# Word 1699 ("cmos") appears 179 time.
# Word 1702 ("cnps") appears 7 time.
# Word 1709 ("coagul") appears 5 time.
# Word 1710 ("coal") appears 2 time.
# Word 1712 ("coars") appears 11 time.
# Word 1713 ("coassembl") appears 1 time.
# Word 1714 ("coast") appears 1 time.
# Word 1717 ("coat") appears 304 time.
# Word 1722 ("cochlear") appears 2 time.
# Word 1726 ("cod") appears 255 time.
# Word 1727 ("code") appears 118 time.
# Word 1731 ("codon") appears 4 time.
# Word 1732 ("coeffici") appears 215 time.
# Word 1734 ("coenzym") appears 1 time.
# Word 1739 ("coexist") appears 11 time.
# Word 1740 ("coexpress") appears 1 time.
# Word 1741 ("cofactor") appears 1 time.
# Word 1743 ("coffe") appears 1 time.
# Word 1746 ("cognit") appears 60 time.
# Word 1748 ("coher") appears 63 time.
# Word 1749 ("cohes") appears 4 time.
# Word 1751 ("cohort") appears 1 time.
# Word 1752 ("coil") appears 179 time.
# Word 1754 ("coincid") appears 6 time.
# Word 1757 ("cold") appears 31 time.
# Word 1760 ("coli") appears 53 time.
# Word 1763 ("collabor") appears 15 time.
# Word 1764 ("collagen") appears 94 time.
# Word 1765 ("collar") appears 2 time.
# Word 1766 ("collater") appears 1 time.
# Word 1767 ("collect") appears 100 time.
# Word 1770 ("collid") appears 3 time.
# Word 1771 ("collim") appears 5 time.
# Word 1772 ("collis") appears 40 time.
# Word 1775 ("colloid") appears 60 time.
# Word 1776 ("coloc") appears 1 time.
# Word 1778 ("colon") appears 5 time.
# Word 1779 ("coloni") appears 5 time.
# Word 1780 ("color") appears 92 time.
# Word 1781 ("colorect") appears 8 time.
# Word 1782 ("coloss") appears 1 time.
# Word 1786 ("column") appears 31 time.
# Word 1787 ("columnar") appears 5 time.
# Word 1789 ("comb") appears 8 time.
# Word 1790 ("combat") appears 5 time.
# Word 1791 ("combin") appears 586 time.
# Word 1792 ("combinatori") appears 17 time.
# Word 1794 ("combust") appears 1 time.
# Word 1795 ("come") appears 27 time.
# Word 1797 ("command") appears 19 time.
# Word 1798 ("commenc") appears 2 time.
# Word 1799 ("commensur") appears 3 time.
# Word 1800 ("commerci") appears 125 time.
# Word 1801 ("commiss") appears 4 time.
# Word 1802 ("commit") appears 2 time.
# Word 1803 ("commod") appears 1 time.
# Word 1804 ("common") appears 242 time.
# Word 1808 ("communic") appears 489 time.
# Word 1809 ("communiti") appears 25 time.
# Word 1811 ("compact") appears 249 time.
# Word 1816 ("compar") appears 1216 time.
# Word 1817 ("comparison") appears 272 time.
# Word 1818 ("compart") appears 12 time.
# Word 1820 ("compass") appears 1 time.
# Word 1821 ("compat") appears 85 time.
# Word 1822 ("compel") appears 4 time.
# Word 1823 ("compens") appears 251 time.
# Word 1825 ("compet") appears 16 time.
# Word 1826 ("competit") appears 37 time.
# Word 1827 ("competitor") appears 5 time.
# Word 1828 ("compil") appears 2 time.
# Word 1830 ("complement") appears 12 time.
# Word 1831 ("complementar") appears 2 time.
# Word 1832 ("complementari") appears 75 time.
# Word 1833 ("complet") appears 167 time.
# Word 1834 ("complex") appears 551 time.
# Word 1835 ("compli") appears 5 time.
# Word 1836 ("compliant") appears 14 time.
# Word 1837 ("complic") appears 53 time.
# Word 1839 ("compon") appears 428 time.
# Word 1840 ("compos") appears 143 time.
# Word 1841 ("composit") appears 385 time.
# Word 1843 ("compound") appears 58 time.
# Word 1844 ("comprehens") appears 94 time.
# Word 1845 ("compress") appears 200 time.
# Word 1846 ("compression") appears 1 time.
# Word 1847 ("compris") appears 89 time.
# Word 1848 ("compromis") appears 38 time.
# Word 1850 ("comput") appears 603 time.
# Word 1852 ("concav") appears 15 time.
# Word 1853 ("conceiv") appears 6 time.
# Word 1854 ("concentr") appears 297 time.
# Word 1855 ("concept") appears 235 time.
# Word 1856 ("conceptu") appears 11 time.
# Word 1857 ("concern") appears 77 time.
# Word 1858 ("concert") appears 1 time.
# Word 1860 ("concis") appears 8 time.
# Word 1861 ("conclud") appears 58 time.
# Word 1862 ("conclus") appears 38 time.
# Word 1863 ("concomit") appears 5 time.
# Word 1864 ("concord") appears 5 time.
# Word 1866 ("concurr") appears 23 time.
# Word 1867 ("condens") appears 15 time.
# Word 1869 ("condit") appears 775 time.
# Word 1870 ("conduct") appears 596 time.
# Word 1871 ("cone") appears 26 time.
# Word 1873 ("confer") appears 5 time.
# Word 1874 ("confid") appears 11 time.
# Word 1875 ("configur") appears 275 time.
# Word 1876 ("confin") appears 62 time.
# Word 1877 ("confirm") appears 238 time.
# Word 1878 ("conflict") appears 24 time.
# Word 1879 ("confoc") appears 20 time.
# Word 1880 ("conform") appears 74 time.
# Word 1881 ("confound") appears 1 time.
# Word 1882 ("confront") appears 3 time.
# Word 1885 ("congenit") appears 1 time.
# Word 1889 ("congruent") appears 2 time.
# Word 1890 ("conic") appears 21 time.
# Word 1891 ("conif") appears 3 time.
# Word 1892 ("conjectur") appears 4 time.
# Word 1894 ("conjug") appears 50 time.
# Word 1895 ("conjunct") appears 24 time.
# Word 1897 ("connect") appears 334 time.
# Word 1902 ("conscious") appears 1 time.
# Word 1903 ("consecut") appears 16 time.
# Word 1904 ("consensus") appears 50 time.
# Word 1906 ("consequ") appears 100 time.
# Word 1907 ("consequenti") appears 3 time.
# Word 1908 ("conserv") appears 26 time.
# Word 1909 ("consid") appears 593 time.
# Word 1910 ("consider") appears 154 time.
# Word 1911 ("consist") appears 394 time.
# Word 1912 ("consolid") appears 5 time.
# Word 1913 ("consortia") appears 1 time.
# Word 1915 ("conspicu") appears 2 time.
# Word 1917 ("constant") appears 215 time.
# Word 1918 ("constel") appears 15 time.
# Word 1919 ("constitu") appears 13 time.
# Word 1920 ("constitut") appears 45 time.
# Word 1921 ("constrain") appears 60 time.
# Word 1922 ("constraint") appears 230 time.
# Word 1923 ("constrict") appears 3 time.
# Word 1924 ("construct") appears 247 time.
# Word 1927 ("consum") appears 108 time.
# Word 1928 ("consumpt") appears 183 time.
# Word 1929 ("contact") appears 177 time.
# Word 1932 ("contain") appears 173 time.
# Word 1933 ("contamin") appears 31 time.
# Word 1934 ("contemporari") appears 2 time.
# Word 1935 ("contend") appears 2 time.
# Word 1936 ("content") appears 155 time.
# Word 1937 ("context") appears 56 time.
# Word 1938 ("contextu") appears 3 time.
# Word 1940 ("contigu") appears 1 time.
# Word 1941 ("contin") appears 1 time.
# Word 1943 ("conting") appears 3 time.
# Word 1944 ("continu") appears 212 time.
# Word 1945 ("continuum") appears 11 time.
# Word 1946 ("contour") appears 35 time.
# Word 1948 ("contract") appears 21 time.
# Word 1949 ("contractil") appears 4 time.
# Word 1950 ("contradict") appears 7 time.
# Word 1953 ("contrari") appears 18 time.
# Word 1954 ("contrast") appears 153 time.
# Word 1955 ("contribut") appears 172 time.
# Word 1956 ("contributor") appears 2 time.
# Word 1957 ("control") appears 2347 time.
# Word 1958 ("controversi") appears 5 time.
# Word 1961 ("convect") appears 19 time.
# Word 1962 ("conveni") appears 38 time.
# Word 1963 ("convent") appears 561 time.
# Word 1964 ("converg") appears 144 time.
# Word 1965 ("convers") appears 210 time.
# Word 1966 ("convert") appears 1011 time.
# Word 1967 ("convex") appears 76 time.
# Word 1968 ("convey") appears 3 time.
# Word 1969 ("conveyor") appears 3 time.
# Word 1970 ("convinc") appears 3 time.
# Word 1971 ("convolut") appears 7 time.
# Word 1973 ("cook") appears 4 time.
# Word 1974 ("cool") appears 61 time.
# Word 1975 ("cooper") appears 144 time.
# Word 1976 ("coordin") appears 99 time.
# Word 1979 ("cope") appears 14 time.
# Word 1982 ("copi") appears 11 time.
# Word 1983 ("copious") appears 1 time.
# Word 1984 ("copolymer") appears 1 time.
# Word 1985 ("copper") appears 95 time.
# Word 1987 ("coral") appears 1 time.
# Word 1988 ("corallin") appears 1 time.
# Word 1989 ("cord") appears 9 time.
# Word 1990 ("core") appears 339 time.
# Word 1999 ("corneal") appears 11 time.
# Word 2001 ("cornerston") appears 1 time.
# Word 2002 ("corona") appears 35 time.
# Word 2003 ("coronari") appears 7 time.
# Word 2005 ("corpor") appears 1 time.
# Word 2006 ("corpus") appears 2 time.
# Word 2007 ("correct") appears 191 time.
# Word 2008 ("correl") appears 222 time.
# Word 2009 ("correspond") appears 213 time.
# Word 2010 ("corrobor") appears 15 time.
# Word 2011 ("corros") appears 85 time.
# Word 2012 ("corrupt") appears 13 time.
# Word 2015 ("cortex") appears 6 time.
# Word 2016 ("cortic") appears 13 time.
# Word 2019 ("corticosteroid") appears 1 time.
# Word 2026 ("cosmet") appears 1 time.
# Word 2027 ("cosmic") appears 1 time.
# Word 2029 ("cost") appears 483 time.
# Word 2030 ("costa") appears 4 time.
# Word 2036 ("cotton") appears 4 time.
# Word 2038 ("cough") appears 6 time.
# Word 2039 ("coulomb") appears 7 time.
# Word 2042 ("count") appears 33 time.
# Word 2043 ("counter") appears 19 time.
# Word 2044 ("counteract") appears 3 time.
# Word 2047 ("countermeasur") appears 5 time.
# Word 2048 ("counterpart") appears 56 time.
# Word 2050 ("countri") appears 11 time.
# Word 2053 ("coupl") appears 622 time.
# Word 2054 ("cours") appears 6 time.
# Word 2057 ("coval") appears 21 time.
# Word 2058 ("covari") appears 36 time.
# Word 2059 ("cover") appears 133 time.
# Word 2060 ("coverag") appears 79 time.
# Word 2072 ("crank") appears 3 time.
# Word 2077 ("creat") appears 159 time.
# Word 2080 ("creation") appears 13 time.
# Word 2081 ("creativ") appears 2 time.
# Word 2083 ("credibl") appears 2 time.
# Word 2088 ("crest") appears 1 time.
# Word 2091 ("crime") appears 1 time.
# Word 2092 ("crimin") appears 1 time.
# Word 2096 ("crisi") appears 3 time.
# Word 2097 ("crispr") appears 6 time.
# Word 2098 ("criteria") appears 43 time.
# Word 2099 ("criterion") appears 69 time.
# Word 2100 ("critic") appears 181 time.
# Word 2102 ("crop") appears 2 time.
# Word 2104 ("cross") appears 336 time.
# Word 2105 ("crosslink") appears 34 time.
# Word 2107 ("crossov") appears 11 time.
# Word 2109 ("crowd") appears 17 time.
# Word 2110 ("crown") appears 5 time.
# Word 2112 ("crucial") appears 63 time.
# Word 2113 ("crude") appears 3 time.
# Word 2114 ("cruis") appears 3 time.
# Word 2119 ("cryo") appears 1 time.
# Word 2122 ("cryogen") appears 14 time.
# Word 2126 ("cryostat") appears 4 time.
# Word 2130 ("crystal") appears 187 time.
# Word 2131 ("crystallin") appears 66 time.
# Word 2133 ("crystallographi") appears 1 time.
# Word 2135 ("ctcs") appears 18 time.
# Word 2144 ("cubic") appears 15 time.
# Word 2146 ("cue") appears 11 time.
# Word 2153 ("cultiv") appears 8 time.
# Word 2155 ("cultur") appears 137 time.
# Word 2156 ("cumbersom") appears 5 time.
# Word 2157 ("cumul") appears 22 time.
# Word 2162 ("cure") appears 10 time.
# Word 2164 ("current") appears 1617 time.
# Word 2165 ("curtail") appears 2 time.
# Word 2166 ("curv") appears 130 time.
# Word 2167 ("curvatur") appears 28 time.
# Word 2170 ("custom") appears 25 time.
# Word 2171 ("cut") appears 17 time.
# Word 2176 ("cutoff") appears 20 time.
# Word 2179 ("cxcr") appears 1 time.
# Word 2183 ("cyanobacteri") appears 2 time.
# Word 2184 ("cyanobacteria") appears 1 time.
# Word 2185 ("cyanobacterium") appears 1 time.
# Word 2189 ("cycl") appears 232 time.
# Word 2191 ("cyclic") appears 47 time.
# Word 2192 ("cyclin") appears 1 time.
# Word 2193 ("cyclo") appears 1 time.
# Word 2195 ("cyclooxygenas") appears 1 time.
# Word 2201 ("cylind") appears 44 time.
# Word 2202 ("cylindr") appears 66 time.
# Word 2207 ("cystein") appears 8 time.
# Word 2211 ("cytidin") appears 1 time.
# Word 2213 ("cytochrom") appears 3 time.
# Word 2214 ("cytocompat") appears 6 time.
# Word 2216 ("cytokin") appears 14 time.
# Word 2220 ("cytometri") appears 11 time.
# Word 2222 ("cytoplasm") appears 8 time.
# Word 2224 ("cytoskelet") appears 1 time.
# Word 2225 ("cytoskeleton") appears 1 time.
# Word 2227 ("cytotox") appears 83 time.
# Word 2230 ("daili") appears 10 time.
# Word 2231 ("dairi") appears 2 time.
# Word 2233 ("damag") appears 68 time.
# Word 2235 ("damp") appears 89 time.
# Word 2236 ("dampen") appears 1 time.
# Word 2238 ("danger") appears 5 time.
# Word 2243 ("dark") appears 30 time.
# Word 2246 ("darwin") appears 1 time.
# Word 2249 ("data") appears 890 time.
# Word 2250 ("databas") appears 71 time.
# Word 2251 ("dataset") appears 50 time.
# Word 2252 ("date") appears 29 time.
# Word 2255 ("daughter") appears 1 time.
# Word 2258 ("day") appears 87 time.
# Word 2260 ("dcas") appears 3 time.
# Word 2266 ("dead") appears 26 time.
# Word 2268 ("deadlock") appears 3 time.
# Word 2270 ("deal") appears 88 time.
# Word 2271 ("deaminas") appears 1 time.
# Word 2273 ("death") appears 22 time.
# Word 2274 ("debat") appears 4 time.
# Word 2275 ("debilit") appears 3 time.
# Word 2276 ("debri") appears 22 time.
# Word 2279 ("decad") appears 51 time.
# Word 2281 ("decap") appears 2 time.
# Word 2282 ("decay") appears 49 time.
# Word 2286 ("decentr") appears 15 time.
# Word 2288 ("decid") appears 20 time.
# Word 2289 ("decidu") appears 2 time.
# Word 2291 ("decis") appears 94 time.
# Word 2292 ("declar") appears 2 time.
# Word 2293 ("declin") appears 7 time.
# Word 2294 ("decod") appears 130 time.
# Word 2296 ("decompos") appears 31 time.
# Word 2297 ("decomposit") appears 64 time.
# Word 2298 ("decompress") appears 3 time.
# Word 2300 ("deconvolut") appears 3 time.
# Word 2301 ("decor") appears 22 time.
# Word 2302 ("decorrel") appears 2 time.
# Word 2303 ("decoupl") appears 72 time.
# Word 2305 ("decreas") appears 263 time.
# Word 2306 ("dedic") appears 38 time.
# Word 2307 ("deduc") appears 21 time.
# Word 2308 ("deep") appears 56 time.
# Word 2310 ("deeper") appears 12 time.
# Word 2312 ("deepli") appears 10 time.
# Word 2314 ("default") appears 1 time.
# Word 2315 ("defect") appears 153 time.
# Word 2317 ("defens") appears 12 time.
# Word 2319 ("defici") appears 14 time.
# Word 2320 ("deficit") appears 9 time.
# Word 2321 ("defin") appears 172 time.
# Word 2322 ("definit") appears 38 time.
# Word 2323 ("deflect") appears 19 time.
# Word 2326 ("deform") appears 66 time.
# Word 2327 ("degener") appears 14 time.
# Word 2329 ("degrad") appears 310 time.
# Word 2331 ("degre") appears 130 time.
# Word 2333 ("dehydr") appears 2 time.
# Word 2335 ("dehydrogenas") appears 3 time.
# Word 2337 ("delay") appears 309 time.
# Word 2338 ("delet") appears 6 time.
# Word 2339 ("deleteri") appears 2 time.
# Word 2341 ("deliber") appears 5 time.
# Word 2343 ("delin") appears 3 time.
# Word 2344 ("deliv") appears 100 time.
# Word 2345 ("deliveri") appears 226 time.
# Word 2346 ("deloc") appears 5 time.
# Word 2347 ("delta") appears 18 time.
# Word 2348 ("demand") appears 116 time.
# Word 2352 ("democrat") appears 1 time.
# Word 2354 ("demonstr") appears 1144 time.
# Word 2356 ("dendrim") appears 13 time.
# Word 2357 ("dendrit") appears 17 time.
# Word 2359 ("deni") appears 4 time.
# Word 2362 ("denois") appears 10 time.
# Word 2363 ("denomin") appears 2 time.
# Word 2364 ("denot") appears 11 time.
# Word 2365 ("dens") appears 42 time.
# Word 2366 ("densif") appears 1 time.
# Word 2367 ("densiti") appears 448 time.
# Word 2368 ("dental") appears 25 time.
# Word 2370 ("deoxi") appears 1 time.
# Word 2373 ("depart") appears 2 time.
# Word 2374 ("depend") appears 548 time.
# Word 2376 ("depict") appears 6 time.
# Word 2377 ("deplet") appears 31 time.
# Word 2378 ("deploy") appears 81 time.
# Word 2379 ("depolar") appears 7 time.
# Word 2380 ("depolaris") appears 2 time.
# Word 2382 ("deposit") appears 138 time.
# Word 2385 ("depress") appears 9 time.
# Word 2387 ("deproton") appears 1 time.
# Word 2388 ("depth") appears 110 time.
# Word 2389 ("derail") appears 1 time.
# Word 2391 ("deregul") appears 1 time.
# Word 2393 ("deriv") appears 505 time.
# Word 2394 ("derivat") appears 1 time.
# Word 2395 ("dermal") appears 6 time.
# Word 2397 ("dermi") appears 1 time.
# Word 2398 ("desatur") appears 1 time.
# Word 2399 ("descend") appears 3 time.
# Word 2400 ("descent") appears 17 time.
# Word 2401 ("describ") appears 217 time.
# Word 2402 ("descript") appears 45 time.
# Word 2403 ("desensit") appears 1 time.
# Word 2409 ("design") appears 2176 time.
# Word 2410 ("desir") appears 175 time.
# Word 2418 ("desorpt") appears 11 time.
# Word 2420 ("despit") appears 54 time.
# Word 2422 ("destabil") appears 6 time.
# Word 2423 ("destroy") appears 6 time.
# Word 2424 ("destruct") appears 21 time.
# Word 2425 ("detach") appears 8 time.
# Word 2426 ("detail") appears 160 time.
# Word 2427 ("detect") appears 712 time.
# Word 2428 ("detector") appears 85 time.
# Word 2429 ("deterior") appears 35 time.
# Word 2430 ("determin") appears 425 time.
# Word 2431 ("determinist") appears 38 time.
# Word 2434 ("detriment") appears 12 time.
# Word 2438 ("deuterium") appears 5 time.
# Word 2441 ("develop") appears 1034 time.
# Word 2442 ("development") appears 2 time.
# Word 2444 ("deviat") appears 66 time.
# Word 2445 ("devic") appears 1105 time.
# Word 2446 ("devis") appears 21 time.
# Word 2447 ("devoid") appears 1 time.
# Word 2448 ("devot") appears 8 time.
# Word 2450 ("diabet") appears 5 time.
# Word 2454 ("diagnos") appears 18 time.
# Word 2455 ("diagnosi") appears 75 time.
# Word 2456 ("diagnost") appears 44 time.
# Word 2457 ("diagon") appears 23 time.
# Word 2458 ("diagram") appears 30 time.
# Word 2459 ("dialysi") appears 1 time.
# Word 2461 ("diamet") appears 173 time.
# Word 2462 ("diamond") appears 17 time.
# Word 2466 ("diastol") appears 2 time.
# Word 2469 ("dicarboxyl") appears 1 time.
# Word 2470 ("dice") appears 1 time.
# Word 2472 ("dichalcogenid") appears 18 time.
# Word 2473 ("dichroism") appears 6 time.
# Word 2475 ("dick") appears 2 time.
# Word 2478 ("dictat") appears 10 time.
# Word 2481 ("die") appears 7 time.
# Word 2484 ("diet") appears 4 time.
# Word 2485 ("dietari") appears 1 time.
# Word 2486 ("differ") appears 1420 time.
# Word 2487 ("differenti") appears 280 time.
# Word 2488 ("difficult") appears 89 time.
# Word 2489 ("difficulti") appears 34 time.
# Word 2490 ("diffract") appears 105 time.
# Word 2491 ("diffus") appears 130 time.
# Word 2493 ("digest") appears 2 time.
# Word 2494 ("digit") appears 236 time.
# Word 2502 ("dilat") appears 2 time.
# Word 2504 ("dilemma") appears 3 time.
# Word 2506 ("dimens") appears 185 time.
# Word 2507 ("dimension") appears 273 time.
# Word 2508 ("dimer") appears 16 time.
# Word 2509 ("dimethyl") appears 3 time.
# Word 2510 ("diminish") appears 7 time.
# Word 2512 ("dinucleotid") appears 1 time.
# Word 2514 ("diod") appears 205 time.
# Word 2517 ("dioxid") appears 18 time.
# Word 2519 ("dip") appears 10 time.
# Word 2521 ("diphenyl") appears 1 time.
# Word 2525 ("diploid") appears 1 time.
# Word 2526 ("dipol") appears 141 time.
# Word 2527 ("dipolar") appears 4 time.
# Word 2530 ("dirac") appears 8 time.
# Word 2532 ("direct") appears 788 time.
# Word 2533 ("director") appears 2 time.
# Word 2535 ("disabl") appears 5 time.
# Word 2537 ("disadvantag") appears 23 time.
# Word 2543 ("disappear") appears 4 time.
# Word 2544 ("disassembl") appears 18 time.
# Word 2545 ("disassoci") appears 1 time.
# Word 2546 ("disast") appears 4 time.
# Word 2547 ("disc") appears 29 time.
# Word 2548 ("discard") appears 2 time.
# Word 2549 ("discern") appears 2 time.
# Word 2550 ("discharg") appears 137 time.
# Word 2551 ("disciplin") appears 3 time.
# Word 2552 ("disclin") appears 1 time.
# Word 2553 ("disclos") appears 4 time.
# Word 2555 ("discontinu") appears 49 time.
# Word 2556 ("discord") appears 1 time.
# Word 2560 ("discov") appears 24 time.
# Word 2561 ("discoveri") appears 25 time.
# Word 2562 ("discrep") appears 10 time.
# ...
# Word 7353 ("polysaccharid") appears 12 time.
# Word 7363 ("pool") appears 11 time.
# Word 7364 ("poor") appears 56 time.
# Word 7365 ("poorer") appears 3 time.
# Word 7369 ("popul") appears 48 time.
# Word 7370 ("popular") appears 58 time.
# Word 7376 ("porcin") appears 2 time.
# Word 7377 ("pore") appears 119 time.
# Word 7380 ("porous") appears 117 time.
# Word 7382 ("porphyrin") appears 7 time.
# Word 7384 ("port") appears 94 time.
# Word 7385 ("portabl") appears 29 time.
# Word 7388 ("portfolio") appears 1 time.
# Word 7389 ("portion") appears 18 time.
# Word 7392 ("pose") appears 55 time.
# Word 7393 ("posit") appears 416 time.
# Word 7394 ("positron") appears 1 time.
# Word 7395 ("possess") appears 72 time.
# Word 7396 ("possibl") appears 276 time.
# Word 7397 ("post") appears 60 time.
# Word 7401 ("posterior") appears 7 time.
# Word 7406 ("postinject") appears 1 time.
# Word 7410 ("postmortem") appears 1 time.
# Word 7412 ("postop") appears 2 time.
# Word 7418 ("postul") appears 3 time.
# Word 7419 ("postur") appears 10 time.
# Word 7420 ("potassium") appears 5 time.
# Word 7421 ("potato") appears 2 time.
# Word 7422 ("potenc") appears 3 time.
# Word 7423 ("potent") appears 7 time.
# Word 7424 ("potenti") appears 580 time.
# Word 7427 ("powder") appears 38 time.
# Word 7428 ("power") appears 2367 time.
# Word 7432 ("pparγ") appears 2 time.
# Word 7436 ("practic") appears 267 time.
# Word 7437 ("practition") appears 4 time.
# Word 7443 ("preadipocyt") appears 6 time.
# Word 7448 ("preced") appears 2 time.
# Word 7450 ("precess") appears 3 time.
# Word 7452 ("precious") appears 1 time.
# Word 7453 ("precipit") appears 20 time.
# Word 7454 ("precis") appears 177 time.
# Word 7456 ("preclin") appears 11 time.
# Word 7457 ("preclud") appears 2 time.
# Word 7459 ("precoci") appears 1 time.
# Word 7463 ("precursor") appears 55 time.
# Word 7466 ("predefin") appears 11 time.
# Word 7467 ("predesign") appears 1 time.
# Word 7468 ("predetermin") appears 11 time.
# Word 7469 ("predict") appears 434 time.
# Word 7470 ("predictor") appears 9 time.
# Word 7474 ("predomin") appears 18 time.
# Word 7475 ("preempt") appears 2 time.
# Word 7480 ("prefer") appears 41 time.
# Word 7481 ("preferenti") appears 15 time.
# Word 7483 ("preform") appears 3 time.
# Word 7496 ("preliminari") appears 24 time.
# Word 7497 ("preload") appears 1 time.
# Word 7498 ("prematur") appears 6 time.
# Word 7502 ("premis") appears 7 time.
# Word 7506 ("preoper") appears 1 time.
# Word 7508 ("prepar") appears 240 time.
# Word 7515 ("prerequisit") appears 6 time.
# Word 7516 ("prescrib") appears 8 time.
# Word 7517 ("presenc") appears 231 time.
# Word 7519 ("present") appears 1965 time.
# Word 7520 ("preserv") appears 78 time.
# Word 7521 ("prespecifi") appears 2 time.
# Word 7522 ("press") appears 5 time.
# Word 7523 ("pressur") appears 128 time.
# Word 7527 ("presum") appears 1 time.
# Word 7529 ("presuppos") appears 1 time.
# Word 7532 ("pretest") appears 1 time.
# Word 7533 ("pretreat") appears 4 time.
# Word 7534 ("prevail") appears 6 time.
# Word 7535 ("preval") appears 6 time.
# Word 7536 ("prevent") appears 87 time.
# Word 7537 ("previous") appears 238 time.
# Word 7538 ("prey") appears 4 time.
# Word 7541 ("price") appears 37 time.
# Word 7542 ("prim") appears 1 time.
# Word 7544 ("primari") appears 128 time.
# Word 7545 ("primarili") appears 24 time.
# Word 7548 ("prime") appears 5 time.
# Word 7549 ("primer") appears 1 time.
# Word 7550 ("primit") appears 5 time.
# Word 7552 ("princip") appears 24 time.
# Word 7553 ("principl") appears 166 time.
# Word 7554 ("print") appears 127 time.
# Word 7556 ("prior") appears 65 time.
# Word 7557 ("priori") appears 17 time.
# Word 7558 ("priorit") appears 4 time.
# Word 7559 ("prioriti") appears 15 time.
# Word 7560 ("prism") appears 4 time.
# Word 7562 ("pristin") appears 19 time.
# Word 7563 ("privaci") appears 18 time.
# Word 7564 ("privat") appears 14 time.
# Word 7565 ("privileg") appears 4 time.
# Word 7568 ("probabilist") appears 57 time.
# Word 7569 ("probabl") appears 232 time.
# Word 7570 ("probe") appears 183 time.
# Word 7571 ("problem") appears 876 time.
# Word 7572 ("problemat") appears 7 time.
# Word 7573 ("proc") appears 1 time.
# Word 7574 ("procedur") appears 227 time.
# Word 7575 ("proceed") appears 5 time.
# Word 7576 ("process") appears 1103 time.
# Word 7577 ("processor") appears 75 time.
# Word 7583 ("produc") appears 261 time.
# Word 7584 ("product") appears 260 time.
# Word 7585 ("profession") appears 4 time.
# Word 7587 ("profil") appears 181 time.
# Word 7588 ("profit") appears 3 time.
# Word 7589 ("profound") appears 5 time.
# Word 7591 ("progenitor") appears 9 time.
# Word 7592 ("progesteron") appears 1 time.
# Word 7594 ("prognosi") appears 5 time.
# Word 7595 ("prognost") appears 8 time.
# Word 7596 ("program") appears 131 time.
# Word 7597 ("programm") appears 58 time.
# Word 7598 ("progress") appears 62 time.
# Word 7599 ("prohibit") appears 4 time.
# Word 7602 ("project") appears 79 time.
# Word 7605 ("prolif") appears 1 time.
# Word 7606 ("prolifer") appears 92 time.
# Word 7607 ("prolin") appears 1 time.
# Word 7608 ("prolong") appears 22 time.
# Word 7609 ("prolyl") appears 1 time.
# Word 7612 ("promin") appears 20 time.
# Word 7613 ("promis") appears 315 time.
# Word 7614 ("promiscu") appears 1 time.
# Word 7616 ("promot") appears 86 time.
# Word 7617 ("prompt") appears 7 time.
# Word 7618 ("prone") appears 17 time.
# Word 7620 ("pronounc") appears 23 time.
# Word 7621 ("proof") appears 48 time.
# Word 7622 ("propag") appears 210 time.
# Word 7623 ("propanediol") appears 3 time.
# Word 7624 ("propel") appears 15 time.
# Word 7625 ("propens") appears 2 time.
# Word 7626 ("proper") appears 108 time.
# Word 7627 ("properti") appears 854 time.
# Word 7628 ("prophylact") appears 2 time.
# Word 7631 ("proport") appears 75 time.
# Word 7632 ("propos") appears 4235 time.
# Word 7634 ("propuls") appears 23 time.
# Word 7637 ("prospect") appears 34 time.
# Word 7638 ("prostat") appears 2 time.
# Word 7641 ("proteas") appears 8 time.
# Word 7642 ("proteasom") appears 1 time.
# Word 7643 ("protect") appears 137 time.
# Word 7644 ("protein") appears 256 time.
# Word 7645 ("proteinac") appears 3 time.
# Word 7646 ("proteinas") appears 1 time.
# Word 7651 ("proteolysi") appears 1 time.
# Word 7652 ("proteolyt") appears 1 time.
# Word 7653 ("proteom") appears 3 time.
# Word 7661 ("protocol") appears 148 time.
# Word 7664 ("proton") appears 20 time.
# Word 7666 ("prototyp") appears 373 time.
# Word 7669 ("protrud") appears 5 time.
# Word 7672 ("prove") appears 187 time.
# Word 7673 ("provid") appears 1102 time.
# Word 7674 ("provinc") appears 1 time.
# Word 7678 ("provis") appears 9 time.
# Word 7680 ("provok") appears 1 time.
# Word 7681 ("proxi") appears 4 time.
# Word 7682 ("proxim") appears 45 time.
# Word 7684 ("prune") appears 8 time.
# Word 7685 ("pscs") appears 2 time.
# Word 7692 ("pseudomona") appears 4 time.
# Word 7698 ("psnr") appears 3 time.
# Word 7700 ("psychiatr") appears 2 time.
# Word 7705 ("psycholog") appears 3 time.
# Word 7707 ("psychophys") appears 2 time.
# Word 7718 ("public") appears 37 time.
# Word 7719 ("publish") appears 31 time.
# Word 7723 ("pull") appears 22 time.
# Word 7724 ("pulmonari") appears 7 time.
# Word 7725 ("puls") appears 285 time.
# Word 7726 ("pulsatil") appears 5 time.
# Word 7727 ("pump") appears 76 time.
# Word 7731 ("punctur") appears 1 time.
# Word 7732 ("punish") appears 2 time.
# Word 7736 ("purchas") appears 3 time.
# Word 7737 ("pure") appears 73 time.
# Word 7739 ("purif") appears 14 time.
# Word 7740 ("purifi") appears 6 time.
# Word 7746 ("purpos") appears 103 time.
# Word 7747 ("pursu") appears 12 time.
# Word 7748 ("push") appears 14 time.
# Word 7751 ("putat") appears 4 time.
# Word 7752 ("puzzl") appears 16 time.
# Word 7757 ("pyramid") appears 16 time.
# Word 7765 ("pyrolysi") appears 5 time.
# Word 7769 ("pyruv") appears 1 time.
# Word 7773 ("qpcr") appears 1 time.
# Word 7777 ("quadrant") appears 6 time.
# Word 7778 ("quadrat") appears 42 time.
# Word 7779 ("quadrupl") appears 3 time.
# Word 7780 ("quadruplex") appears 1 time.
# Word 7781 ("qualif") appears 1 time.
# Word 7782 ("qualifi") appears 6 time.
# Word 7783 ("qualit") appears 26 time.
# Word 7784 ("qualiti") appears 327 time.
# Word 7787 ("quantif") appears 22 time.
# Word 7788 ("quantifi") appears 84 time.
# Word 7789 ("quantit") appears 100 time.
# Word 7790 ("quantiti") appears 34 time.
# Word 7791 ("quantiz") appears 22 time.
# Word 7792 ("quantum") appears 181 time.
# Word 7793 ("quarter") appears 19 time.
# Word 7794 ("quartz") appears 5 time.
# Word 7796 ("quasi") appears 81 time.
# Word 7797 ("quaternari") appears 2 time.
# Word 7798 ("qubit") appears 6 time.
# Word 7802 ("quench") appears 36 time.
# Word 7803 ("quencher") appears 6 time.
# Word 7804 ("quercetin") appears 15 time.
# Word 7805 ("queri") appears 18 time.
# Word 7806 ("quest") appears 1 time.
# Word 7807 ("question") appears 24 time.
# Word 7809 ("queue") appears 29 time.
# Word 7810 ("quick") appears 23 time.
# Word 7812 ("quiescent") appears 6 time.
# Word 7813 ("quiet") appears 1 time.
# Word 7814 ("quinon") appears 1 time.
# Word 7815 ("quorum") appears 4 time.
# Word 7819 ("rabbit") appears 11 time.
# Word 7822 ("race") appears 2 time.
# Word 7828 ("radar") appears 228 time.
# Word 7829 ("radial") appears 61 time.
# Word 7831 ("radiat") appears 528 time.
# Word 7833 ("radic") appears 17 time.
# Word 7835 ("radio") appears 201 time.
# Word 7839 ("radiolabel") appears 1 time.
# Word 7841 ("radiolog") appears 2 time.
# Word 7844 ("radiotherapi") appears 1 time.
# Word 7845 ("radius") appears 38 time.
# Word 7846 ("raft") appears 4 time.
# Word 7848 ("rais") appears 20 time.
# Word 7850 ("raman") appears 116 time.
# Word 7853 ("random") appears 181 time.
# Word 7856 ("rang") appears 829 time.
# Word 7857 ("rank") appears 46 time.
# Word 7858 ("rankl") appears 1 time.
# Word 7861 ("rapid") appears 154 time.
# Word 7862 ("rare") appears 19 time.
# Word 7863 ("rariti") appears 1 time.
# Word 7864 ("rash") appears 1 time.
# Word 7865 ("rat") appears 214 time.
# Word 7866 ("rate") appears 611 time.
# Word 7867 ("ratio") appears 509 time.
# Word 7868 ("ration") appears 44 time.
# Word 7869 ("rational") appears 4 time.
# Word 7871 ("ray") appears 15 time.
# Word 7876 ("rcas") appears 1 time.
# Word 7881 ("reach") appears 115 time.
# Word 7882 ("reachabl") appears 1 time.
# Word 7883 ("react") appears 7 time.
# Word 7884 ("reactant") appears 4 time.
# Word 7885 ("reaction") appears 157 time.
# Word 7886 ("reactiv") appears 107 time.
# Word 7887 ("reactor") appears 17 time.
# Word 7888 ("read") appears 37 time.
# Word 7890 ("readi") appears 8 time.
# Word 7891 ("readili") appears 28 time.
# Word 7893 ("readout") appears 16 time.
# Word 7895 ("reaffirm") appears 1 time.
# Word 7896 ("reagent") appears 9 time.
# Word 7897 ("real") appears 371 time.
# Word 7899 ("realis") appears 55 time.
# Word 7900 ("realist") appears 77 time.
# Word 7901 ("realiti") appears 10 time.
# Word 7902 ("realiz") appears 216 time.
# Word 7903 ("realize") appears 44 time.
# Word 7905 ("realm") appears 1 time.
# Word 7908 ("rear") appears 7 time.
# Word 7909 ("rearrang") appears 3 time.
# Word 7910 ("reason") appears 102 time.
# Word 7914 ("rebuild") appears 1 time.
# Word 7916 ("recal") appears 11 time.
# Word 7917 ("recalcitr") appears 1 time.
# Word 7918 ("recapitul") appears 1 time.
# Word 7919 ("receiv") appears 425 time.
# Word 7920 ("recent") appears 280 time.
# Word 7921 ("recept") appears 24 time.
# Word 7923 ("receptor") appears 43 time.
# Word 7924 ("recess") appears 10 time.
# Word 7926 ("recipi") appears 1 time.
# Word 7927 ("reciproc") appears 12 time.
# Word 7929 ("recogn") appears 34 time.
# Word 7930 ("recognis") appears 5 time.
# Word 7931 ("recognit") appears 126 time.
# Word 7933 ("recombin") appears 47 time.
# Word 7935 ("recommend") appears 21 time.
# Word 7936 ("reconcil") appears 1 time.
# Word 7937 ("reconfigur") appears 134 time.
# Word 7939 ("reconstitut") appears 4 time.
# Word 7940 ("reconstruct") appears 160 time.
# Word 7941 ("record") appears 115 time.
# Word 7943 ("recov") appears 38 time.
# Word 7944 ("recoveri") appears 92 time.
# Word 7948 ("recruit") appears 4 time.
# Word 7951 ("rectangl") appears 1 time.
# Word 7952 ("rectangular") appears 71 time.
# Word 7953 ("rectif") appears 14 time.
# Word 7954 ("rectifi") appears 117 time.
# Word 7958 ("recur") appears 5 time.
# Word 7959 ("recurr") appears 16 time.
# Word 7960 ("recurs") appears 30 time.
# Word 7961 ("recycl") appears 16 time.
# Word 7962 ("redefin") appears 1 time.
# Word 7963 ("redesign") appears 3 time.
# Word 7964 ("redirect") appears 4 time.
# Word 7966 ("redistribut") appears 11 time.
# Word 7968 ("redox") appears 33 time.
# Word 7969 ("reduc") appears 993 time.
# Word 7970 ("reduct") appears 318 time.
# Word 7972 ("redund") appears 31 time.
# Word 7977 ("reevalu") appears 1 time.
# Word 7980 ("refer") appears 251 time.
# Word 7983 ("refin") appears 23 time.
# Word 7984 ("reflect") appears 232 time.
# Word 7985 ("reflex") appears 3 time.
# Word 7989 ("reform") appears 9 time.
# Word 7990 ("refract") appears 39 time.
# Word 7991 ("refractori") appears 1 time.
# Word 7994 ("refut") appears 1 time.
# Word 7995 ("regard") appears 42 time.
# Word 7996 ("regardless") appears 35 time.
# Word 7997 ("regen") appears 42 time.
# Word 7998 ("regener") appears 53 time.
# Word 7999 ("regia") appears 1 time.
# Word 8000 ("regim") appears 67 time.
# Word 8001 ("regimen") appears 2 time.
# Word 8003 ("region") appears 353 time.
# Word 8004 ("regist") appears 14 time.
# Word 8005 ("registr") appears 15 time.
# Word 8006 ("registri") appears 1 time.
# Word 8008 ("regress") appears 18 time.
# Word 8009 ("regul") appears 184 time.
# Word 8010 ("regular") appears 68 time.
# Word 8011 ("regulatori") appears 12 time.
# Word 8012 ("regurgit") appears 1 time.
# Word 8013 ("rehabilit") appears 6 time.
# Word 8018 ("reinforc") appears 30 time.
# Word 8019 ("reintroduct") appears 1 time.
# Word 8020 ("reject") appears 68 time.
# Word 8022 ("relaps") appears 3 time.
# Word 8023 ("relat") appears 467 time.
# Word 8024 ("relationship") appears 119 time.
# Word 8026 ("relax") appears 107 time.
# Word 8027 ("relay") appears 255 time.
# Word 8028 ("releas") appears 277 time.
# Word 8029 ("relev") appears 82 time.
# Word 8030 ("reli") appears 89 time.
# Word 8031 ("reliabl") appears 311 time.
# Word 8033 ("reliant") appears 2 time.
# Word 8035 ("relief") appears 4 time.
# Word 8036 ("reliev") appears 5 time.
# Word 8038 ("reloc") appears 3 time.
# Word 8039 ("remain") appears 143 time.
# Word 8040 ("remaind") appears 3 time.
# Word 8041 ("remark") appears 81 time.
# Word 8044 ("reminisc") appears 4 time.
# Word 8046 ("remnant") appears 2 time.
# Word 8048 ("remodel") appears 7 time.
# Word 8049 ("remot") appears 55 time.
# Word 8051 ("remov") appears 112 time.
# Word 8054 ("renal") appears 9 time.
# Word 8056 ("render") appears 27 time.
# Word 8057 ("rendezv") appears 13 time.
# Word 8058 ("renew") appears 47 time.
# Word 8060 ("renorm") appears 3 time.
# Word 8062 ("reorgan") appears 6 time.
# Word 8063 ("reorient") appears 3 time.
# Word 8064 ("repair") appears 31 time.
# Word 8067 ("repeat") appears 55 time.
# Word 8068 ("repel") appears 8 time.
# Word 8069 ("repercuss") appears 1 time.
# Word 8071 ("repertoir") appears 4 time.
# Word 8072 ("repetit") appears 39 time.
# Word 8073 ("replac") appears 78 time.
# Word 8074 ("replan") appears 2 time.
# Word 8075 ("replenish") appears 2 time.
# Word 8076 ("replic") appears 12 time.
# Word 8080 ("report") appears 444 time.
# Word 8081 ("repositori") appears 5 time.
# Word 8082 ("repres") appears 172 time.
# Word 8083 ("represent") appears 91 time.
# Word 8084 ("repress") appears 11 time.
# Word 8086 ("reproduc") appears 41 time.
# Word 8087 ("reproduct") appears 1 time.
# Word 8088 ("reprogram") appears 7 time.
# Word 8091 ("repuls") appears 4 time.
# Word 8092 ("reput") appears 6 time.
# Word 8093 ("requir") appears 733 time.
# Word 8094 ("requisit") appears 5 time.
# Word 8097 ("resampl") appears 3 time.
# Word 8098 ("rescu") appears 3 time.
# Word 8099 ("research") appears 271 time.
# Word 8101 ("resembl") appears 8 time.
# Word 8103 ("reserv") appears 11 time.
# Word 8104 ("reservoir") appears 1 time.
# Word 8106 ("resid") appears 15 time.
# Word 8107 ("residenti") appears 5 time.
# Word 8108 ("residu") appears 98 time.
# Word 8109 ("resili") appears 17 time.
# Word 8110 ("resin") appears 26 time.
# Word 8111 ("resist") appears 394 time.
# Word 8112 ("resolut") appears 264 time.
# Word 8113 ("resolv") appears 62 time.
# Word 8114 ("reson") appears 695 time.

# %% [markdown]
# TF-IDF method

# %%
from gensim import corpora, models

tfidf = models.TfidfModel(bow_corpus)

# %%
corpus_tfidf = tfidf[bow_corpus]

# %%
from pprint import pprint

for doc in corpus_tfidf:
    pprint(doc)
    break
# Out:
# [(0, 0.010808341452570631),
#  (1, 0.010808341452570631),
#  (2, 0.010808341452570631),
#  (3, 0.004864395986776133),
#  (4, 0.006898295968474878),
#  (5, 0.004254454731539502),
#  (6, 0.002176509869467302),
#  (7, 0.00428042058482585),
#  (8, 0.004933245238394435),
#  (9, 0.0019550227420478757),
#  (10, 0.009884949871609882),
#  (11, 0.004488794144535665),
#  (12, 0.003581913988133879),
#  (13, 0.014107301985064784),
#  (15, 0.009759060083786093),
#  (16, 0.010745741964401636),
#  (17, 0.008312726005884107),
#  (18, 0.01733476625705189),
#  (19, 0.006160763248328936),
#  (20, 0.0027346128569436406),
#  (21, 0.0035193144999648876),
#  (22, 0.0085608411696517),
#  (23, 0.002737068356376615),
#  (24, 0.004864395986776133),
#  (25, 0.007700428225993526),
#  (26, 0.0056573512768761875),
#  (27, 0.0054041707262853155),
#  (28, 0.001194894035067961),
#  (29, 0.0026110852047120867),
#  (30, 0.0032537470749265654),
#  (31, 0.0017596572499824438),
#  (32, 0.0026110852047120867),
#  (33, 0.008508909463079004),
#  (34, 0.012191998141963355),
#  (35, 0.0036494244751688197),
#  (36, 0.02552672838923701),
#  (37, 0.004254454731539502),
#  (38, 0.0027346128569436406),
#  (39, 0.0028340250505269333),
#  (40, 0.004254454731539502),
#  (41, 0.0026553200779288024),
#  (42, 0.0026553200779288024),
#  (43, 0.007187557123050425),
#  (44, 0.002211869578466849),
#  (45, 0.0004351808674520144),
#  (46, 0.0012824819986422531),
#  (47, 0.003602181269216446),
#  (48, 0.0033191500974110023),
#  (49, 0.0010167959609145517),
#  (50, 0.0027323094792825785),
#  (51, 0.002341979553670781),
#  (52, 0.007038628999929775),
#  (53, 0.002853613723217233),
#  (54, 0.0035193144999648876),
#  (55, 0.0017596572499824438),
#  (56, 0.01101957832340453),
#  (58, 0.0011709897768353906),
#  (59, 0.010938451427774562),
# Topic: 18 Word: 0.000*"cell" + 0.000*"graphen" + 0.000*"antenna" + 0.000*"nanoparticl" + 0.000*"mimo" + 0.000*"protein" + 0.000*"polym" + 0.000*"nanowir" + 0.000*"fabric" + 0.000*"wireless"
# Topic: 19 Word: 0.000*"antenna" + 0.000*"graphen" + 0.000*"voltag" + 0.000*"mimo" + 0.000*"nanowir" + 0.000*"bandwidth" + 0.000*"slot" + 0.000*"microstrip" + 0.000*"transistor" + 0.000*"capacitor"

# %% [markdown]
# Classify sample document using LDA Bag of Words model

# %%
processed_docs[11]
# Out:
# ['consid',
#  'problem',
#  'estim',
#  'local',
#  'sensor',
#  'paramet',
#  'local',
#  'paramet',
#  'sensor',
#  'observ',
#  'relat',
#  'linear',
#  'stochast',
#  'model',
#  'studi',
#  'gaussian',
#  'product',
#  'algorithm',
#  'wireless',
#  'network',
#  'gspawn',
#  'procedur',
#  'compar',
#  'popular',
#  'diffus',
#  'strategi',
#  'perform',
#  'network',
#  'paramet',
#  'estim',
#  'communic',
#  'cost',
#  'sensor',
#  'increas',
#  'increas',
#  'network',
#  'densiti',
#  'gspawn',
#  'allow',
#  'sensor',
#  'broadcast',
#  'messag',
#  'size',
#  'depend',
#  'network',
#  'size',
#  'densiti',
#  'make',
#  'suitabl',
#  'applic',
#  'wireless',
#  'sensor',
#  'network',
#  'gspawn',
#  'converg',
#  'mean',
#  'mean',
#  'squar',
#  'stabil',
#  'technic',
#  'suffici',
#  'condit',
#  'applic',
#  'gspawn',
#  'network',
#  'local',
#  'problem',
#  'line',
#  'sight',
#  'environ',
#  'numer',
#  'result',
#  'suggest',
#  'gspawn',
#  'converg',
#  'faster',
#  'general',
#  'diffus',
#  'method',
#  'lower',
#  'communic',
#  'cost',
#  'sensor',
#  'compar',
#  'root',
#  'mean',
#  'squar',
#  'error',
#  'express',
#  'clone',
#  'play',
#  'import',
#  'role',
#  'facial',
#  'express',
#  'synthesi',
#  'paper',
#  'novel',
#  'algorithm',
#  'propos',
#  'facial',
#  'express',
#  'clone',
#  'propos',
#  'algorithm',
#  'introduc',
#  'elast',
#  'model',
#  'balanc',
#  'global',
#  'local',
#  'warp',
#  'effect',
#  'impact',
#  'facial',
#  'featur',
#  'divers',
#  'peopl',
#  'minim',
#  'effect',
#  'geometr',
#  'warp',
#  'result',
#  'achiev',
#  'furthermor',
#  'muscl',
#  'distribut',
#  'base',
#  'model',
#  'propos',
#  'util',
#  'muscl',
#  'distribut',
#  'human',
#  'face',
#  'result',
#  'accur',
#  'facial',
#  'illumin',
#  'detail',
#  'addit',
#  'propos',
#  'distanc',
#  'base',
#  'metric',
#  'automat',
#  'select',
#  'optim',
#  'paramet',
#  'global',
#  'local',
#  'warp',
#  'effect',
#  'elast',
#  'model',
#  'suitabl',
#  'balanc',
#  'experiment',
#  'result',
#  'propos',
#  'algorithm',
#  'outperform',
#  'exist',
#  'method',
#  'elsevi',
#  'right',
#  'reserv',
#  'paper',
#  'consid',
#  'wireless',
#  'power',
#  'cooper',
#  'communic',
#  'network',
#  'consist',
#  'hybrid',
#  'access',
#  'point',
#  'sourc',
#  'relay',
#  'contrast',
#  'convent',
#  'cooper',
#  'network',
#  'sourc',
#  'relay',
#  'consid',
#  'network',
#  'emb',
#  'energi',
#  'suppli',
#  'need',
#  'reli',
#  'energi',
#  'harvest',
#  'signal',
#  'broadcast',
#  'cooper',
#  'inform',
#  'transmiss',
#  'base',
#  'node',
#  'refer',
#  'model',
#  'propos',
#  'harvest',
#  'cooper',
#  'protocol',
#  'sourc',
#  'relay',
#  'harvest',
#  'energi',
#  'downlink',
#  'work',
#  'cooper',
#  'uplink',
#  'sourc',
#  'inform',
#  'transmiss',
#  'consid',
#  'delay',
#  'limit',
#  'transmiss',
#  'mode',
#  'approxim',
#  'close',
#  'form',
#  'express',
#  'averag',
#  'throughput',
#  'propos',
#  'protocol',
#  'deriv',
#  'rayleigh',
#  'fade',
#  'channel',
#  'subsequ',
#  'analysi',
#  'extend',
#  'multi',
#  'relay',
#  'scenario',
#  'approxim',
#  'throughput',
#  'protocol',
#  'popular',
#  'relay',
#  'select',
#  'scheme',
#  'deriv',
#  'asymptot',
#  'analys',
#  'throughput',
#  'perform',
#  'consid',
#  'scheme',
#  'high',
#  'signal',
#  'nois',
#  'radio',
#  'provid',
#  'theoret',
#  'result',
#  'valid',
#  'numer',
#  'simul',
#  'impact',
#  'paramet',
#  'time',
#  'alloc',
#  'relay',
#  'number',
#  'relay',
#  'posit',
#  'throughput',
#  'perform',
#  'extens',
#  'investig',
#  'paper',
#  'propos',
#  'crowdsourc',
#  'base',
#  'framework',
#  'myopic',
#  'target',
#  'track',
#  'design',
#  'optim',
#  'incent',
#  'compat',
#  'mechan',
#  'wireless',
#  'sensor',
#  'network',
#  'contain',
#  'sensor',
#  'selfish',
#  'profit',
#  'motiv',
#  'typic',
#  'wsns',
#  'limit',
#  'bandwidth',
#  'fusion',
#  'center',
#  'distribut',
#  'total',
#  'number',
#  'bit',
#  'transmit',
#  'sensor',
#  'sensor',
#  'formul',
#  'consid',
#  'conduct',
#  'auction',
#  'solicit',
#  'bid',
#  'selfish',
#  'sensor',
#  'reflect',
#  'valu',
#  'energi',
#  'cost',
#  'furthermor',
#  'ration',
#  'truth',
#  'sensor',
#  'guarante',
#  'model',
#  'final',
#  'problem',
#  'formul',
#  'multipl',
#  'choic',
#  'knapsack',
#  'problem',
#  'mckp',
#  'solv',
#  'dynam',
#  'program',
#  'method',
#  'pseudo',
#  'polynomi',
#  'time',
#  'simul',
#  'result',
#  'effect',
#  'propos',
#  'approach',
#  'term',
#  'track',
#  'perform',
#  'lifetim',
#  'sensor',
#  'network',
#  'present',
#  'joint',
#  'channel',
#  'power',
#  'alloc',
#  'framework',
#  'downlink',
#  'transmiss',
#  'orthogon',
#  'frequenc',
#  'divis',
#  'multipl',
#  'access',
#  'ofdma',
#  'base',
#  'cellular',
#  'network',
#  'compos',
#  'macrocel',
#  'overlay',
#  'small',
#  'cell',
#  'framework',
#  'resourc',
#  'alloc',
#  'problem',
#  'macrocel',
#  'small',
#  'cell',
#  'formul',
#  'optim',
#  'problem',
#  'macrocel',
#  'formul',
#  'problem',
#  'awar',
#  'exist',
#  'small',
#  'cell',
#  'tier',
#  'problem',
#  'macrocel',
#  'perform',
#  'satisfi',
#  'data',
#  'rate',
#  'requir',
#  'macro',
#  'user',
#  'equip',
#  'mue',
#  'maxim',
#  'toler',
#  'interfer',
#  'small',
#  'cell',
#  'tier',
#  'alloc',
#  'channel',
#  'problem',
#  'macrocel',
#  'show',
#  'mix',
#  'integ',
#  'nonlinear',
#  'problem',
#  'minlp',
#  'prove',
#  'macrocel',
#  'solv',
#  'altern',
#  'optim',
#  'problem',
#  'yield',
#  'optim',
#  'solut',
#  'reduc',
#  'complex',
#  'small',
#  'cell',
#  'follow',
#  'idea',
#  'tier',
#  'awar',
#  'formul',
#  'optim',
#  'problem',
#  'account',
#  'admiss',
#  'control',
#  'aim',
#  'maxim',
#  'number',
#  'admit',
#  'user',
#  'simultan',
#  'minim',
#  'consum',
#  'bandwidth',
#  'similar',
#  'macrocel',
#  'optim',
#  'problem',
#  'small',
#  'cell',
#  'problem',
#  'show',
#  'minlp',
#  'obtain',
#  'optim',
#  'solut',
#  'minlp',
#  'problem',
#  'reli',
#  'convex',
#  'relax',
#  'addit',
#  'employ',
#  'dual',
#  'decomposit',
#  'techniqu',
#  'distribut',
#  'solut',
#  'small',
#  'cell',
#  'tier',
#  'numer',
#  'result',
#  'confirm',
#  'perform',
#  'gain',
#  'propos',
#  'formul',
#  'macrocel',
#  'tradit',
#  'resourc',
#  'alloc',
#  'base',
#  'minim',
#  'transmiss',
#  'power',
#  'show',
#  'formul',
#  'base',
#  'convex',
#  'relax',
#  'yield',
#  'similar',
#  'behavior',
#  'minlp',
#  'formul',
#  'distribut',
#  'solut',
#  'converg',
#  'solut',
#  'obtain',
#  'solv',
#  'correspond',
#  'convex',
#  'optim',
#  'problem',
#  'central',
#  'fashion',
#  'cellular',
#  'network',
#  'model',
#  'base',
#  'station',
#  'usual',
#  'assum',
#  'form',
#  'lattic',
#  'poisson',
#  'point',
#  'process',
#  'realiti',
#  'deploy',
#  'fulli',
#  'regular',
#  'complet',
#  'random',
#  'accord',
#  'paper',
#  'consid',
#  'general',
#  'class',
#  'motion',
#  'invari',
#  'model',
#  'analyz',
#  'behavior',
#  'outag',
#  'probabl',
#  'probabl',
#  'signal',
#  'interfer',
#  'plus',
#  'nois',
#  'ratio',
#  'sinr',
#  'smaller',
#  'threshold',
#  'threshold',
#  'go',
#  'zero',
#  'remark',
#  'slope',
#  'outag',
#  'probabl',
#  'function',
#  'threshold',
#  'essenti',
#  'motion',
#  'invari',
#  'point',
#  'process',
#  'slope',
#  'mere',
#  'depend',
#  'fade',
#  'statist',
#  'result',
#  'introduc',
#  'notion',
#  'asymptot',
#  'deploy',
#  'gain',
#  'character',
#  'horizont',
#  'success',
#  'probabl',
#  'point',
#  'process',
#  'high',
#  'reliabl',
#  'regim',
#  'success',
#  'probabl',
#  'near',
#  'demonstr',
#  'use',
#  'sinr',
#  'distribut',
#  'investig',
#  'outag',
#  'probabl',
#  'adg',
#  'differ',
#  'point',
#  'process',
#  'fade',
#  'statist',
#  'simul',
#  'molecular',
#  'communic',
#  'network',
#  'realis',
#  'communic',
#  'nanoscal',
#  'devic',
#  'molecular',
#  'communic',
#  'network',
#  'transmitt',
#  'receiv',
#  'communic',
#  'signal',
#  'molecul',
#  'receiv',
#  'signal',
#  'molecul',
#  'react',
#  'chain',
#  'chemic',
#  'reaction',
#  'produc',
#  'output',
#  'molecul',
#  'count',
#  'output',
#  'molecul',
#  'time',
#  'output',
#  'signal',
#  'receiv',
#  'output',
#  'signal',
#  'noisi',
#  'stochast',
#  'natur',
#  'diffus',
#  'chemic',
#  'reaction',
#  'paper',
#  'aim',
#  'characteris',
#  'properti',
#  'output',
#  'signal',
#  'model',
#  'transmiss',
#  'medium',
#  'transmitt',
#  'receiv',
#  'order',
#  'simplifi',
#  'analysi',
#  'model',
#  'transmitt',
#  'sequenc',
#  'specifi',
#  'number',
#  'molecul',
#  'emit',
#  'transmitt',
#  'time',
#  'paper',
#  'consid',
#  'receiv',
#  'reaction',
#  'mechan',
#  'revers',
#  'convers',
#  'linear',
#  'catalyt',
#  'approxim',
#  'respect',
#  'ligand',
#  'receptor',
#  'bind',
#  'enzymat',
#  'reaction',
#  'mechan',
#  'choos',
#  'consid',
#  'transmitt',
#  'diffus',
#  'ordinari',
#  'differenti',
#  'equat',
#  'describ',
#  'mean',
#  'behaviour',
#  'reaction',
#  'mechan',
#  'form',
#  'consid',
#  'behaviour',
#  'transmitt',
#  'signal',
#  'mean',
#  'varianc',
#  'number',
#  'output',
#  'molecul',
#  'receiv',
#  'reaction',
#  'mechan',
#  'differ',
#  'behaviour',
#  'deriv',
#  'analyt',
#  'express',
#  'mean',
#  'varianc',
#  'frequenc',
#  'properti',
#  'number',
#  'output',
#  'molecul',
#  'receiv',
#  'reaction',
#  'mechan',
#  'addit',
#  'revers',
#  'convers',
#  'abl',
#  'deriv',
#  'exact',
#  'probabl',
#  'distribut',
#  'number',
#  'output',
#  'molecul',
#  'model',
#  'allow',
#  'studi',
#  'impact',
#  'design',
#  'paramet',
#  'communic',
#  'perform',
#  'exampl',
#  'assum',
#  'receiv',
#  'enclos',
#  'membran',
#  'studi',
#  'impact',
#  'diffus',
#  'molecul',
#  'membran',
#  'communic',
#  'rformanc',
#  'paper',
#  'present',
#  'statist',
#  'chatter',
#  'detect',
#  'method',
#  'methodolog',
#  'base',
#  'studi',
#  'discret',
#  'wavelet',
#  'transform',
#  'scheme',
#  'statist',
#  'analysi',
#  'wavelet',
#  'transform',
#  'modulus',
#  'maxima',
#  'wtmm',
#  'wavelet',
#  'transform',
#  'modulus',
#  'maxima',
#  'point',
#  'wavelet',
#  'transform',
#  'signal',
#  'local',
#  'maxim',
#  'correspond',
#  'time',
#  'locat',
#  'noisi',
#  'machin',
#  'environ',
#  'wavelet',
#  'base',
#  'nois',
#  'method',
#  'includ',
#  'hybrid',
#  'threshold',
#  'function',
#  'level',
#  'depend',
#  'univers',
#  'threshold',
#  'rule',
#  'propos',
#  'dimension',
#  'chatter',
#  'index',
#  'vari',
#  'design',
#  'base',
#  'statist',
#  'analysi',
#  'wtmm',
#  'main',
#  'advantag',
#  'propos',
#  'chatter',
#  'index',
#  'includ',
#  'variat',
#  'rang',
#  'independ',
#  'process',
#  'paramet',
#  'machin',
#  'system',
#  'threshold',
#  'valu',
#  'suscept',
#  'cut',
#  'condit',
#  'chang',
#  'valu',
#  'relat',
#  'term',
#  'result',
#  'chatter',
#  'index',
#  'differ',
#  'machin',
#  'process',
#  'time',
#  'consum',
#  'recalibr',
#  'process',
#  'present',
#  'multipl',
#  'person',
#  'track',
#  'algorithm',
#  'base',
#  'combin',
#  'particl',
#  'filter',
#  'reciproc',
#  'veloc',
#  'obstacl',
#  'agent',
#  'base',
#  'crowd',
#  'model',
#  'infer',
#  'collis',
#  'free',
#  'veloc',
#  'predict',
#  'pedestrian',
#  'motion',
#  'addit',
#  'posit',
#  'veloc',
#  'track',
#  'algorithm',
#  'estim',
#  'intern',
#  'goal',
#  'desir',
#  'destin',
#  'desir',
#  'veloc',
#  'track',
#  'pedestrian',
#  'onlin',
#  'manner',
#  'remov',
#  'need',
#  'specifi',
#  'inform',
#  'furthermor',
#  'leverag',
#  'longer',
#  'term',
#  'predict',
#  'deriv',
#  'higher',
#  'order',
#  'aggreg',
#  'multipl',
#  'predict',
#  'differ',
#  'prior',
#  'time',
#  'step',
#  'yield',
#  'tracker',
#  'recov',
#  'short',
#  'term',
#  'occlus',
#  'spurious',
#  'nois',
#  'appear',
#  'model',
#  'experiment',
#  'result',
#  'track',
#  'algorithm',
#  'suitabl',
#  'predict',
#  'pedestrian',
#  'behavior',
#  'onlin',
#  'need',
#  'scene',
#  'prior',
#  'hand',
#  'annot',
#  'goal',
#  'inform',
#  'improv',
#  'track',
#  'real',
#  'world',
#  'crowd',
#  'scene',
#  'frame',
#  'rat',
#  'extract',
#  'latent',
#  'dimension',
#  'structur',
#  'high',
#  'dimension',
#  'data',
#  'paramount',
#  'import',
#  'time',
#  'infer',
#  'task',
#  'encount',
#  'data',
#  'analyt',
#  'increas',
#  'noisi',
#  'heterogen',
#  'incomplet',
#  'dataset',
#  'need',
#  'real',
#  'time',
#  'process',
#  'stream',
#  'data',
#  'pose',
#  'major',
#  'challeng',
#  'context',
#  'present',
#  'paper',
#  'permeat',
#  'benefit',
#  'rank',
#  'minim',
#  'scalabl',
#  'imput',
#  'miss',
#  'data',
#  'track',
#  'dimension',
#  'subspac',
#  'unravel',
#  'latent',
#  'possibl',
#  'multi',
#  'structur',
#  'incomplet',
#  'stream',
#  'data',
#  'rank',
#  'matrix',
#  'data',
#  'subspac',
#  'estim',
#  'propos',
#  ...]

# %%
for index, score in sorted(lda_model[bow_corpus[11]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model.print_topic(index, 10)))
# Out:
# Score: 0.9999974370002747
# Topic: 0.009*"propos" + 0.007*"base" + 0.007*"result" + 0.007*"method" + 0.006*"model" + 0.006*"high" + 0.005*"perform" + 0.005*"power" + 0.005*"effect" + 0.005*"control"

# %%
for index, score in sorted(lda_model_tfidf[bow_corpus[11]], key=lambda tup: -1*tup[1]):
    print("\nScore: {}\t \nTopic: {}".format(score, lda_model_tfidf.print_topic(index, 10)))
# Out:
# Score: 0.9907759428024292
# Topic: 0.000*"cell" + 0.000*"graphen" + 0.000*"antenna" + 0.000*"nanoparticl" + 0.000*"mimo" + 0.000*"protein" + 0.000*"polym" + 0.000*"nanowir" + 0.000*"fabric" + 0.000*"wireless"
